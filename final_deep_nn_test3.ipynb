# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/quora_duplicate_questions_detection/
# Out:
# /content/drive/.shortcut-targets-by-id/1NfDfMFFEa6jbcf5EQ_tVWbvhytT96tlt/quora_duplicate_questions_detection

# %%
# !ls
# Out:
#  bert			  deep_nn_test3.ipynb	      predictions
#  classifier.py		  feature_engineering.ipynb   __pycache__
# 'Copy of deep_nn.ipynb'   graphs		      tfidf_model.ipynb
#  data			  __init__.py		      Untitled.ipynb
#  deep_nn.ipynb		  models		      utils.py
#  deep_nn_test1.ipynb	  nlp_features.ipynb
#  deep_nn_test2.ipynb	  non_nlp_features.ipynb

# %%
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import StratifiedKFold
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Dense, Input, LSTM, Embedding, Dropout
from keras.layers.core import Lambda
from keras.layers.merge import concatenate, add, multiply
from keras.models import Model
from keras.layers import BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers.noise import GaussianNoise
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
np.random.seed(0)
WNL = WordNetLemmatizer()
STOP_WORDS = set(stopwords.words('english'))
MAX_SEQUENCE_LENGTH = 30
MIN_WORD_OCCURRENCE = 100
REPLACE_WORD = "rare"
EMBEDDING_DIM = 300
NUM_FOLDS = 10
BATCH_SIZE = 128
EMBEDDING_FILE = "data/glove.840B.300d.txt"

# %%
def cutter(word):
    if len(word) < 4:
        return word
    return WNL.lemmatize(WNL.lemmatize(word, "n"), "v")

# %%
def preprocess(string):
    string = string.lower().replace(",000,000", "m").replace(",000", "k").replace("′", "'").replace("’", "'") \
        .replace("won't", "will not").replace("cannot", "can not").replace("can't", "can not") \
        .replace("n't", " not").replace("what's", "what is").replace("it's", "it is") \
        .replace("'ve", " have").replace("i'm", "i am").replace("'re", " are") \
        .replace("he's", "he is").replace("she's", "she is").replace("'s", " own") \
        .replace("%", " percent ").replace("₹", " rupee ").replace("$", " dollar ") \
        .replace("€", " euro ").replace("'ll", " will").replace("=", " equal ").replace("+", " plus ")
    string = re.sub('[“”\(\'…\)\!\^\"\.;:,\-\?？\{\}\[\]\\/\*@]', ' ', string)
    string = re.sub(r"([0-9]+)000000", r"\1m", string)
    string = re.sub(r"([0-9]+)000", r"\1k", string)
    string = ' '.join([cutter(w) for w in string.split()])
    return string

# %%
def get_embedding():
    embeddings_index = {}
    f = open(EMBEDDING_FILE, encoding="utf8")
    for line in f:
        values = line.split()
        word = values[0]
        if len(values) == EMBEDDING_DIM + 1 and word in top_words:
            coefs = np.asarray(values[1:], dtype="float32")
            embeddings_index[word] = coefs
    f.close()
    return embeddings_index

# %%
def is_numeric(s):
    return any(i.isdigit() for i in s)

# %%
def prepare(q):
    new_q = []
    surplus_q = []
    numbers_q = []
    new_rare = True
    for w in q.split()[::-1]:
        if w in top_words:
            new_q = [w] + new_q
            new_rare = True
        elif w not in STOP_WORDS:
            if new_rare:
                new_q = ["rare"] + new_q
                new_rare = False
            if is_numeric(w):
                numbers_q = [w] + numbers_q
            else:
                surplus_q = [w] + surplus_q
        else:
            new_rare = True
        if len(new_q) == MAX_SEQUENCE_LENGTH:
            break
    new_q = " ".join(new_q)
    return new_q, set(surplus_q), set(numbers_q)

# %%
def extract_features(df):
    q1s = np.array([""] * len(df), dtype=object)
    q2s = np.array([""] * len(df), dtype=object)
    features = np.zeros((len(df), 4))

    for i, (q1, q2) in enumerate(list(zip(df["question1"], df["question2"]))):
        q1s[i], surplus1, numbers1 = prepare(q1)
        q2s[i], surplus2, numbers2 = prepare(q2)
        features[i, 0] = len(surplus1.intersection(surplus2))
        features[i, 1] = len(surplus1.union(surplus2))
        features[i, 2] = len(numbers1.intersection(numbers2))
        features[i, 3] = len(numbers1.union(numbers2))

    return q1s, q2s, features

# %%
train = pd.read_csv("data/train.csv")
test = pd.read_csv("data/test.csv")

# %%
train["question1"] = train["question1"].fillna("").apply(preprocess)
train["question2"] = train["question2"].fillna("").apply(preprocess)

# %%
print("Creating the vocabulary of words occurred more than", MIN_WORD_OCCURRENCE)
all_questions = pd.Series(train["question1"].tolist() + train["question2"].tolist()).unique()
vectorizer = CountVectorizer(lowercase=False, token_pattern="\S+", min_df=MIN_WORD_OCCURRENCE)
vectorizer.fit(all_questions)
top_words = set(vectorizer.vocabulary_.keys())
top_words.add(REPLACE_WORD)
# Out:
# Creating the vocabulary of words occurred more than 100

# %%
embeddings_index = get_embedding()
print("Words are not found in the embedding:", top_words - embeddings_index.keys())
top_words = embeddings_index.keys()
# Out:
# Words are not found in the embedding: {'\\sqrt', 'oneplus', 'paytm', 'demonetisation', 'kvpy', 'redmi', 'quorans', 'iisc', 'c#', '\\frac', 'brexit'}

# %%
print("Train questions are being prepared for LSTM...")
q1s_train, q2s_train, train_q_features = extract_features(train)
# Out:
# Train questions are being prepared for LSTM...

# %%
tokenizer = Tokenizer(filters="")
tokenizer.fit_on_texts(np.append(q1s_train, q2s_train))
word_index = tokenizer.word_index

# %%
data_1 = pad_sequences(tokenizer.texts_to_sequences(q1s_train), maxlen=MAX_SEQUENCE_LENGTH)
data_2 = pad_sequences(tokenizer.texts_to_sequences(q2s_train), maxlen=MAX_SEQUENCE_LENGTH)
labels = np.array(train["is_duplicate"])

# %%
nb_words = len(word_index) + 1
embedding_matrix = np.zeros((nb_words, EMBEDDING_DIM))

# %%
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %%
print("Train features are being merged with NLP and Non-NLP features...")
train_nlp_features = pd.read_csv("data/nlp_features_train.csv")
train_non_nlp_features = pd.read_csv("data/non_nlp_features_train.csv")
features_train = np.hstack((train_q_features, train_nlp_features, train_non_nlp_features))
# Out:
# Train features are being merged with NLP and Non-NLP features...

# %%
print("Same steps are being applied for test...")
test["question1"] = test["question1"].fillna("").apply(preprocess)
test["question2"] = test["question2"].fillna("").apply(preprocess)

q1s_test, q2s_test, test_q_features = extract_features(test)

test_data_1 = pad_sequences(tokenizer.texts_to_sequences(q1s_test), maxlen=MAX_SEQUENCE_LENGTH)
test_data_2 = pad_sequences(tokenizer.texts_to_sequences(q2s_test), maxlen=MAX_SEQUENCE_LENGTH)

test_nlp_features = pd.read_csv("data/nlp_features_test.csv")
test_non_nlp_features = pd.read_csv("data/non_nlp_features_test.csv")
features_test = np.hstack((test_q_features, test_nlp_features, test_non_nlp_features))
# Out:
# Same steps are being applied for test...

# %%
stratified_kf = StratifiedKFold(n_splits=NUM_FOLDS, shuffle=True)
model_count = 0

# %%
'''With recurrent_dropout=0.2 get "not use cuDNN kernel" warning and time increases
to ~ 1 min per epoch & get following results for first fold:
validation loss: 0.20543508231639862
Wall time: 15min 58s - for complete run of 15 epochs & validation

with no recurrent_dropout cuDNN kernel is used ~ 9 seconds per epoch
validation loss: 0.20922143757343292
Wall time: 3min 10s'''
for idx_train, idx_val in stratified_kf.split(train["is_duplicate"], train["is_duplicate"]):
    print("MODEL:", model_count)
    data_1_train = data_1[idx_train]
    data_2_train = data_2[idx_train]
    labels_train = labels[idx_train]
    f_train = features_train[idx_train]

    data_1_val = data_1[idx_val]
    data_2_val = data_2[idx_val]
    labels_val = labels[idx_val]
    f_val = features_train[idx_val]

    embedding_layer = Embedding(nb_words,
                                EMBEDDING_DIM,
                                weights=[embedding_matrix],
                                input_length=MAX_SEQUENCE_LENGTH,
                                trainable=False)

    # lstm_layer = LSTM(75, recurrent_dropout=0.2)
    lstm_layer = LSTM(75)

    sequence_1_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype="int32")
    embedded_sequences_1 = embedding_layer(sequence_1_input)
    x1 = lstm_layer(embedded_sequences_1)

    sequence_2_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype="int32")
    embedded_sequences_2 = embedding_layer(sequence_2_input)
    y1 = lstm_layer(embedded_sequences_2)

    features_input = Input(shape=(f_train.shape[1],), dtype="float32")
    features_dense = BatchNormalization()(features_input)
    features_dense = Dense(200, activation="relu")(features_dense)
    features_dense = Dropout(0.2)(features_dense)

    addition = add([x1, y1])
    minus_y1 = Lambda(lambda x: -x)(y1)
    merged = add([x1, minus_y1])
    merged = multiply([merged, merged])
    merged = concatenate([merged, addition])
    merged = Dropout(0.4)(merged)

    merged = concatenate([merged, features_dense])
    merged = BatchNormalization()(merged)
    merged = GaussianNoise(0.1)(merged)

    merged = Dense(150, activation="relu")(merged)
    merged = Dropout(0.2)(merged)
    merged = BatchNormalization()(merged)

    out = Dense(1, activation="sigmoid")(merged)

    model = Model(inputs=[sequence_1_input, sequence_2_input, features_input], outputs=out)
    model.compile(loss="binary_crossentropy", optimizer="nadam", metrics=['accuracy'])
    model.summary()
    early_stopping = EarlyStopping(monitor="val_loss", patience=5)
    best_model_path = "models/test3/best_model" + str(model_count) + ".h5"
    model_checkpoint = ModelCheckpoint(best_model_path, save_best_only=True, save_weights_only=True)

    model_history = model.fit([data_1_train, data_2_train, f_train], labels_train, 
                     batch_size=BATCH_SIZE, epochs=25, shuffle=True,
                     validation_data=([data_1_val, data_2_val, f_val], labels_val),
                     callbacks=[early_stopping, model_checkpoint], verbose=1)

    model.load_weights(best_model_path)
    print(model_count, "validation loss:", min(model_history.history["val_loss"]))
    print(model_count, "validation accuracy:", max(model_history.history["val_accuracy"]))
    # Accuracy Graph
    fig = plt.figure(dpi = 100)
    plt.title("Accuracy")
    plt.plot(model_history.history["accuracy"], color = "g", label = "Train")
    plt.plot(model_history.history["val_accuracy"], color = "b", label = "Test")
    plt.legend(loc = "best")
    plt.savefig("graphs/test3/accuracyLSTM" + str(model_count) + ".png")
    # Loss Graph
    fig = plt.figure(dpi = 100)
    plt.title("Loss")
    plt.plot(model_history.history["loss"], color = "g", label = "Train")
    plt.plot(model_history.history["val_loss"], color = "b", label = "Test")
    plt.legend(loc = "best")
    plt.savefig("graphs/test3/lossLSTM" + str(model_count) + ".png")

    # Model prediction
    preds = model.predict([test_data_1, test_data_2, features_test], batch_size=BATCH_SIZE, verbose=1)
    
    submission = pd.DataFrame({"test_id": test["test_id"], "is_duplicate": preds.ravel()})
    submission.to_csv("predictions/test3/preds" + str(model_count) + ".csv", index=False)

    model_count += 1
# Out:
# MODEL: 0
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 30)]         0           []
#
#  input_2 (InputLayer)           [(None, 30)]         0           []
#
#  embedding (Embedding)          (None, 30, 300)      1159500     ['input_1[0][0]',
#                                                                   'input_2[0][0]']
#
#  lstm (LSTM)                    (None, 75)           112800      ['embedding[0][0]',
#                                                                   'embedding[1][0]']
#
#  lambda (Lambda)                (None, 75)           0           ['lstm[1][0]']
#
#  add_1 (Add)                    (None, 75)           0           ['lstm[0][0]',
#                                                                   'lambda[0][0]']
#
#  input_3 (InputLayer)           [(None, 25)]         0           []
#
#  multiply (Multiply)            (None, 75)           0           ['add_1[0][0]',
#                                                                   'add_1[0][0]']
#
#  add (Add)                      (None, 75)           0           ['lstm[0][0]',
#                                                                   'lstm[1][0]']
#
#  batch_normalization (BatchNorm  (None, 25)          100         ['input_3[0][0]']
#  alization)
#
#  concatenate (Concatenate)      (None, 150)          0           ['multiply[0][0]',
#                                                                   'add[0][0]']
#
#  dense (Dense)                  (None, 200)          5200        ['batch_normalization[0][0]']
#
#  dropout_1 (Dropout)            (None, 150)          0           ['concatenate[0][0]']
#
#  dropout (Dropout)              (None, 200)          0           ['dense[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 350)          0           ['dropout_1[0][0]',
#                                                                   'dropout[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 350)         1400        ['concatenate_1[0][0]']
#  rmalization)
#
#  gaussian_noise (GaussianNoise)  (None, 350)         0           ['batch_normalization_1[0][0]']
#
#  dense_1 (Dense)                (None, 150)          52650       ['gaussian_noise[0][0]']
#
#  dropout_2 (Dropout)            (None, 150)          0           ['dense_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 150)         600         ['dropout_2[0][0]']
#  rmalization)
#
#  dense_2 (Dense)                (None, 1)            151         ['batch_normalization_2[0][0]']
#
# ==================================================================================================
# Total params: 1,332,401
# Trainable params: 171,851
# Non-trainable params: 1,160,550
# __________________________________________________________________________________________________
# Epoch 1/25
# 2843/2843 [==============================] - 92s 29ms/step - loss: 0.2716 - accuracy: 0.8730 - val_loss: 0.2370 - val_accuracy: 0.8906
# Epoch 2/25
# 2843/2843 [==============================] - 76s 27ms/step - loss: 0.2411 - accuracy: 0.8906 - val_loss: 0.2205 - val_accuracy: 0.9016
# Epoch 3/25
# 2843/2843 [==============================] - 74s 26ms/step - loss: 0.2277 - accuracy: 0.8978 - val_loss: 0.2160 - val_accuracy: 0.9038
# Epoch 4/25
# 2843/2843 [==============================] - 74s 26ms/step - loss: 0.2188 - accuracy: 0.9024 - val_loss: 0.2090 - val_accuracy: 0.9078
# Epoch 5/25
# 2843/2843 [==============================] - 74s 26ms/step - loss: 0.2118 - accuracy: 0.9069 - val_loss: 0.2094 - val_accuracy: 0.9074
# Epoch 6/25
# 2843/2843 [==============================] - 74s 26ms/step - loss: 0.2056 - accuracy: 0.9093 - val_loss: 0.2049 - val_accuracy: 0.9100
# Epoch 7/25
# 2843/2843 [==============================] - 73s 26ms/step - loss: 0.2009 - accuracy: 0.9114 - val_loss: 0.2031 - val_accuracy: 0.9108
# Epoch 8/25
# 2843/2843 [==============================] - 73s 26ms/step - loss: 0.1949 - accuracy: 0.9149 - val_loss: 0.2017 - val_accuracy: 0.9118
# Epoch 9/25
# 2843/2843 [==============================] - 76s 27ms/step - loss: 0.1907 - accuracy: 0.9172 - val_loss: 0.2006 - val_accuracy: 0.9107
# Epoch 10/25
# 2843/2843 [==============================] - 74s 26ms/step - loss: 0.1863 - accuracy: 0.9189 - val_loss: 0.2022 - val_accuracy: 0.9116
# Epoch 11/25
# 2843/2843 [==============================] - 73s 26ms/step - loss: 0.1826 - accuracy: 0.9208 - val_loss: 0.1988 - val_accuracy: 0.9125
# Epoch 12/25
# 2843/2843 [==============================] - 73s 26ms/step - loss: 0.1790 - accuracy: 0.9228 - val_loss: 0.1990 - val_accuracy: 0.9132
# Epoch 13/25
# 2843/2843 [==============================] - 74s 26ms/step - loss: 0.1754 - accuracy: 0.9243 - val_loss: 0.2004 - val_accuracy: 0.9125
# Epoch 14/25
# 2843/2843 [==============================] - 74s 26ms/step - loss: 0.1717 - accuracy: 0.9264 - val_loss: 0.2021 - val_accuracy: 0.9121
# Epoch 15/25
# 2843/2843 [==============================] - 75s 27ms/step - loss: 0.1681 - accuracy: 0.9282 - val_loss: 0.2009 - val_accuracy: 0.9115
# Epoch 16/25
# 2843/2843 [==============================] - 74s 26ms/step - loss: 0.1650 - accuracy: 0.9293 - val_loss: 0.2011 - val_accuracy: 0.9120
# 0 validation loss: 0.19884446263313293
# 0 validation accuracy: 0.9132058620452881
# 18327/18327 [==============================] - 123s 7ms/step
# MODEL: 1
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 30)]         0           []
#
#  input_5 (InputLayer)           [(None, 30)]         0           []
#
#  embedding_1 (Embedding)        (None, 30, 300)      1159500     ['input_4[0][0]',
#                                                                   'input_5[0][0]']
#
#  lstm_1 (LSTM)                  (None, 75)           112800      ['embedding_1[0][0]',
#                                                                   'embedding_1[1][0]']
#
#  lambda_1 (Lambda)              (None, 75)           0           ['lstm_1[1][0]']
#
#  add_3 (Add)                    (None, 75)           0           ['lstm_1[0][0]',
#                                                                   'lambda_1[0][0]']
#
#  input_6 (InputLayer)           [(None, 25)]         0           []
#
#  multiply_1 (Multiply)          (None, 75)           0           ['add_3[0][0]',
#                                                                   'add_3[0][0]']
#
#  add_2 (Add)                    (None, 75)           0           ['lstm_1[0][0]',
#                                                                   'lstm_1[1][0]']
#
#  batch_normalization_3 (BatchNo  (None, 25)          100         ['input_6[0][0]']
#  rmalization)
#
#  concatenate_2 (Concatenate)    (None, 150)          0           ['multiply_1[0][0]',
#                                                                   'add_2[0][0]']
#
#  dense_3 (Dense)                (None, 200)          5200        ['batch_normalization_3[0][0]']
#
#  dropout_4 (Dropout)            (None, 150)          0           ['concatenate_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 200)          0           ['dense_3[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 350)          0           ['dropout_4[0][0]',
#                                                                   'dropout_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 350)         1400        ['concatenate_3[0][0]']
#  rmalization)
#
#  gaussian_noise_1 (GaussianNois  (None, 350)         0           ['batch_normalization_4[0][0]']
#  e)
#
#  dense_4 (Dense)                (None, 150)          52650       ['gaussian_noise_1[0][0]']
#
#  dropout_5 (Dropout)            (None, 150)          0           ['dense_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 150)         600         ['dropout_5[0][0]']
#  rmalization)
#
#  dense_5 (Dense)                (None, 1)            151         ['batch_normalization_5[0][0]']
#
# ==================================================================================================
# Total params: 1,332,401
# Trainable params: 171,851
# Non-trainable params: 1,160,550
# __________________________________________________________________________________________________
# Epoch 1/25
# 2843/2843 [==============================] - 86s 28ms/step - loss: 0.2703 - accuracy: 0.8744 - val_loss: 0.2347 - val_accuracy: 0.8941
# Epoch 2/25
# 2843/2843 [==============================] - 77s 27ms/step - loss: 0.2401 - accuracy: 0.8913 - val_loss: 0.2251 - val_accuracy: 0.8994
# Epoch 3/25
# 2843/2843 [==============================] - 78s 27ms/step - loss: 0.2276 - accuracy: 0.8986 - val_loss: 0.2160 - val_accuracy: 0.9041
# Epoch 4/25
# 2843/2843 [==============================] - 78s 27ms/step - loss: 0.2188 - accuracy: 0.9029 - val_loss: 0.2135 - val_accuracy: 0.9046
# Epoch 5/25
# 2843/2843 [==============================] - 78s 27ms/step - loss: 0.2115 - accuracy: 0.9073 - val_loss: 0.2112 - val_accuracy: 0.9055
# Epoch 6/25
# 2843/2843 [==============================] - 78s 27ms/step - loss: 0.2051 - accuracy: 0.9100 - val_loss: 0.2134 - val_accuracy: 0.9047
# Epoch 7/25
# 2843/2843 [==============================] - 80s 28ms/step - loss: 0.2001 - accuracy: 0.9128 - val_loss: 0.2071 - val_accuracy: 0.9083
# Epoch 8/25
# 2843/2843 [==============================] - 79s 28ms/step - loss: 0.1955 - accuracy: 0.9146 - val_loss: 0.2096 - val_accuracy: 0.9055
# Epoch 9/25
# 2843/2843 [==============================] - 77s 27ms/step - loss: 0.1902 - accuracy: 0.9177 - val_loss: 0.2072 - val_accuracy: 0.9075
# Epoch 10/25
# 2843/2843 [==============================] - 77s 27ms/step - loss: 0.1864 - accuracy: 0.9193 - val_loss: 0.2064 - val_accuracy: 0.9092
# Epoch 11/25
# 2843/2843 [==============================] - 77s 27ms/step - loss: 0.1823 - accuracy: 0.9215 - val_loss: 0.2097 - val_accuracy: 0.9074
# Epoch 12/25
# 2843/2843 [==============================] - 79s 28ms/step - loss: 0.1782 - accuracy: 0.9232 - val_loss: 0.2100 - val_accuracy: 0.9063
# Epoch 13/25
# 2843/2843 [==============================] - 78s 27ms/step - loss: 0.1745 - accuracy: 0.9253 - val_loss: 0.2089 - val_accuracy: 0.9065
# Epoch 14/25
# 2843/2843 [==============================] - 77s 27ms/step - loss: 0.1713 - accuracy: 0.9268 - val_loss: 0.2085 - val_accuracy: 0.9081
# Epoch 15/25
# 2843/2843 [==============================] - 76s 27ms/step - loss: 0.1678 - accuracy: 0.9285 - val_loss: 0.2082 - val_accuracy: 0.9091
# 1 validation loss: 0.20643696188926697
# 1 validation accuracy: 0.9091988205909729
# 18327/18327 [==============================] - 127s 7ms/step
# MODEL: 2
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 30)]         0           []
#
#  input_8 (InputLayer)           [(None, 30)]         0           []
#
#  embedding_2 (Embedding)        (None, 30, 300)      1159500     ['input_7[0][0]',
#                                                                   'input_8[0][0]']
#
#  lstm_2 (LSTM)                  (None, 75)           112800      ['embedding_2[0][0]',
#                                                                   'embedding_2[1][0]']
#
#  lambda_2 (Lambda)              (None, 75)           0           ['lstm_2[1][0]']
#
#  add_5 (Add)                    (None, 75)           0           ['lstm_2[0][0]',
#                                                                   'lambda_2[0][0]']
#
#  input_9 (InputLayer)           [(None, 25)]         0           []
#
#  multiply_2 (Multiply)          (None, 75)           0           ['add_5[0][0]',
#                                                                   'add_5[0][0]']
#
#  add_4 (Add)                    (None, 75)           0           ['lstm_2[0][0]',
#                                                                   'lstm_2[1][0]']
#
#  batch_normalization_6 (BatchNo  (None, 25)          100         ['input_9[0][0]']
#  rmalization)
#
#  concatenate_4 (Concatenate)    (None, 150)          0           ['multiply_2[0][0]',
#                                                                   'add_4[0][0]']
#
#  dense_6 (Dense)                (None, 200)          5200        ['batch_normalization_6[0][0]']
#
#  dropout_7 (Dropout)            (None, 150)          0           ['concatenate_4[0][0]']
#
#  dropout_6 (Dropout)            (None, 200)          0           ['dense_6[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 350)          0           ['dropout_7[0][0]',
#                                                                   'dropout_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 350)         1400        ['concatenate_5[0][0]']
#  rmalization)
#
#  gaussian_noise_2 (GaussianNois  (None, 350)         0           ['batch_normalization_7[0][0]']
#  e)
#
#  dense_7 (Dense)                (None, 150)          52650       ['gaussian_noise_2[0][0]']
#
#  dropout_8 (Dropout)            (None, 150)          0           ['dense_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 150)         600         ['dropout_8[0][0]']
#  rmalization)
#
#  dense_8 (Dense)                (None, 1)            151         ['batch_normalization_8[0][0]']
#
# ==================================================================================================
# Total params: 1,332,401
# Trainable params: 171,851
# Non-trainable params: 1,160,550
# __________________________________________________________________________________________________
# Epoch 1/25
# 2843/2843 [==============================] - 92s 30ms/step - loss: 0.2716 - accuracy: 0.8730 - val_loss: 0.2415 - val_accuracy: 0.8895
# Epoch 2/25
# 2843/2843 [==============================] - 83s 29ms/step - loss: 0.2407 - accuracy: 0.8911 - val_loss: 0.2285 - val_accuracy: 0.8963
# Epoch 3/25
# 2843/2843 [==============================] - 81s 28ms/step - loss: 0.2283 - accuracy: 0.8980 - val_loss: 0.2144 - val_accuracy: 0.9053
# Epoch 4/25
# 2843/2843 [==============================] - 80s 28ms/step - loss: 0.2201 - accuracy: 0.9020 - val_loss: 0.2119 - val_accuracy: 0.9052
# Epoch 5/25
# 2843/2843 [==============================] - 80s 28ms/step - loss: 0.2125 - accuracy: 0.9061 - val_loss: 0.2074 - val_accuracy: 0.9071
# Epoch 6/25
# 2843/2843 [==============================] - 81s 28ms/step - loss: 0.2068 - accuracy: 0.9089 - val_loss: 0.2079 - val_accuracy: 0.9070
# Epoch 7/25
# 2843/2843 [==============================] - 82s 29ms/step - loss: 0.2005 - accuracy: 0.9120 - val_loss: 0.2037 - val_accuracy: 0.9092
# Epoch 8/25
# 2843/2843 [==============================] - 81s 28ms/step - loss: 0.1965 - accuracy: 0.9147 - val_loss: 0.2034 - val_accuracy: 0.9102
# Epoch 9/25
# 2843/2843 [==============================] - 80s 28ms/step - loss: 0.1908 - accuracy: 0.9169 - val_loss: 0.2046 - val_accuracy: 0.9083
# Epoch 10/25
# 2843/2843 [==============================] - 84s 29ms/step - loss: 0.1864 - accuracy: 0.9194 - val_loss: 0.2032 - val_accuracy: 0.9092
# Epoch 11/25
# 2843/2843 [==============================] - 82s 29ms/step - loss: 0.1823 - accuracy: 0.9212 - val_loss: 0.2113 - val_accuracy: 0.9067
# Epoch 12/25
# 2843/2843 [==============================] - 81s 28ms/step - loss: 0.1786 - accuracy: 0.9231 - val_loss: 0.2060 - val_accuracy: 0.9089
# Epoch 13/25
# 2843/2843 [==============================] - 81s 28ms/step - loss: 0.1754 - accuracy: 0.9249 - val_loss: 0.2054 - val_accuracy: 0.9091
# Epoch 14/25
# 2843/2843 [==============================] - 81s 28ms/step - loss: 0.1718 - accuracy: 0.9263 - val_loss: 0.2080 - val_accuracy: 0.9099
# Epoch 15/25
# 2843/2843 [==============================] - 81s 28ms/step - loss: 0.1696 - accuracy: 0.9274 - val_loss: 0.2057 - val_accuracy: 0.9090
# 2 validation loss: 0.20317217707633972
# 2 validation accuracy: 0.9101882576942444
# 18327/18327 [==============================] - 133s 7ms/step
# MODEL: 3
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_10 (InputLayer)          [(None, 30)]         0           []
#
#  input_11 (InputLayer)          [(None, 30)]         0           []
#
#  embedding_3 (Embedding)        (None, 30, 300)      1159500     ['input_10[0][0]',
#                                                                   'input_11[0][0]']
#
#  lstm_3 (LSTM)                  (None, 75)           112800      ['embedding_3[0][0]',
#                                                                   'embedding_3[1][0]']
#
#  lambda_3 (Lambda)              (None, 75)           0           ['lstm_3[1][0]']
#
#  add_7 (Add)                    (None, 75)           0           ['lstm_3[0][0]',
#                                                                   'lambda_3[0][0]']
#
#  input_12 (InputLayer)          [(None, 25)]         0           []
#
#  multiply_3 (Multiply)          (None, 75)           0           ['add_7[0][0]',
#                                                                   'add_7[0][0]']
#
#  add_6 (Add)                    (None, 75)           0           ['lstm_3[0][0]',
#                                                                   'lstm_3[1][0]']
#
#  batch_normalization_9 (BatchNo  (None, 25)          100         ['input_12[0][0]']
#  rmalization)
#
#  concatenate_6 (Concatenate)    (None, 150)          0           ['multiply_3[0][0]',
#                                                                   'add_6[0][0]']
#
#  dense_9 (Dense)                (None, 200)          5200        ['batch_normalization_9[0][0]']
#
#  dropout_10 (Dropout)           (None, 150)          0           ['concatenate_6[0][0]']
#
#  dropout_9 (Dropout)            (None, 200)          0           ['dense_9[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 350)          0           ['dropout_10[0][0]',
#                                                                   'dropout_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 350)         1400        ['concatenate_7[0][0]']
#  ormalization)
#
#  gaussian_noise_3 (GaussianNois  (None, 350)         0           ['batch_normalization_10[0][0]']
#  e)
#
#  dense_10 (Dense)               (None, 150)          52650       ['gaussian_noise_3[0][0]']
#
#  dropout_11 (Dropout)           (None, 150)          0           ['dense_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 150)         600         ['dropout_11[0][0]']
#  ormalization)
#
#  dense_11 (Dense)               (None, 1)            151         ['batch_normalization_11[0][0]']
#
# ==================================================================================================
# Total params: 1,332,401
# Trainable params: 171,851
# Non-trainable params: 1,160,550
# __________________________________________________________________________________________________
# Epoch 1/25
# 2843/2843 [==============================] - 91s 30ms/step - loss: 0.2704 - accuracy: 0.8746 - val_loss: 0.2363 - val_accuracy: 0.8915
# Epoch 2/25
# 2843/2843 [==============================] - 84s 30ms/step - loss: 0.2390 - accuracy: 0.8923 - val_loss: 0.2203 - val_accuracy: 0.9007
# Epoch 3/25
# 2843/2843 [==============================] - 79s 28ms/step - loss: 0.2275 - accuracy: 0.8981 - val_loss: 0.2141 - val_accuracy: 0.9032
# Epoch 4/25
# 2843/2843 [==============================] - 85s 30ms/step - loss: 0.2183 - accuracy: 0.9033 - val_loss: 0.2119 - val_accuracy: 0.9035
# Epoch 5/25
# 2843/2843 [==============================] - 84s 30ms/step - loss: 0.2118 - accuracy: 0.9068 - val_loss: 0.2149 - val_accuracy: 0.9033
# Epoch 6/25
# 2843/2843 [==============================] - 83s 29ms/step - loss: 0.2049 - accuracy: 0.9104 - val_loss: 0.2081 - val_accuracy: 0.9065
# Epoch 7/25
# 2843/2843 [==============================] - 84s 30ms/step - loss: 0.1996 - accuracy: 0.9130 - val_loss: 0.2059 - val_accuracy: 0.9076
# Epoch 8/25
# 2843/2843 [==============================] - 83s 29ms/step - loss: 0.1946 - accuracy: 0.9153 - val_loss: 0.2079 - val_accuracy: 0.9056
# Epoch 9/25
# 2843/2843 [==============================] - 81s 29ms/step - loss: 0.1906 - accuracy: 0.9172 - val_loss: 0.2068 - val_accuracy: 0.9081
# Epoch 10/25
# 2843/2843 [==============================] - 83s 29ms/step - loss: 0.1865 - accuracy: 0.9193 - val_loss: 0.2066 - val_accuracy: 0.9076
# Epoch 11/25
# 2843/2843 [==============================] - 83s 29ms/step - loss: 0.1823 - accuracy: 0.9208 - val_loss: 0.2066 - val_accuracy: 0.9071
# Epoch 12/25
# 2843/2843 [==============================] - 86s 30ms/step - loss: 0.1781 - accuracy: 0.9230 - val_loss: 0.2071 - val_accuracy: 0.9072
# 3 validation loss: 0.20586644113063812
# 3 validation accuracy: 0.9081352353096008
# 18327/18327 [==============================] - 139s 8ms/step
# MODEL: 4
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_13 (InputLayer)          [(None, 30)]         0           []
#
#  input_14 (InputLayer)          [(None, 30)]         0           []
#
#  embedding_4 (Embedding)        (None, 30, 300)      1159500     ['input_13[0][0]',
#                                                                   'input_14[0][0]']
#
#  lstm_4 (LSTM)                  (None, 75)           112800      ['embedding_4[0][0]',
#                                                                   'embedding_4[1][0]']
#
#  lambda_4 (Lambda)              (None, 75)           0           ['lstm_4[1][0]']
#
#  add_9 (Add)                    (None, 75)           0           ['lstm_4[0][0]',
#                                                                   'lambda_4[0][0]']
#
#  input_15 (InputLayer)          [(None, 25)]         0           []
#
#  multiply_4 (Multiply)          (None, 75)           0           ['add_9[0][0]',
#                                                                   'add_9[0][0]']
#
#  add_8 (Add)                    (None, 75)           0           ['lstm_4[0][0]',
#                                                                   'lstm_4[1][0]']
#
#  batch_normalization_12 (BatchN  (None, 25)          100         ['input_15[0][0]']
#  ormalization)
#
#  concatenate_8 (Concatenate)    (None, 150)          0           ['multiply_4[0][0]',
#                                                                   'add_8[0][0]']
#
#  dense_12 (Dense)               (None, 200)          5200        ['batch_normalization_12[0][0]']
#
#  dropout_13 (Dropout)           (None, 150)          0           ['concatenate_8[0][0]']
#
#  dropout_12 (Dropout)           (None, 200)          0           ['dense_12[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 350)          0           ['dropout_13[0][0]',
#                                                                   'dropout_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 350)         1400        ['concatenate_9[0][0]']
#  ormalization)
#
#  gaussian_noise_4 (GaussianNois  (None, 350)         0           ['batch_normalization_13[0][0]']
#  e)
#
#  dense_13 (Dense)               (None, 150)          52650       ['gaussian_noise_4[0][0]']
#
#  dropout_14 (Dropout)           (None, 150)          0           ['dense_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 150)         600         ['dropout_14[0][0]']
#  ormalization)
#
#  dense_14 (Dense)               (None, 1)            151         ['batch_normalization_14[0][0]']
#
# ==================================================================================================
# Total params: 1,332,401
# Trainable params: 171,851
# Non-trainable params: 1,160,550
# __________________________________________________________________________________________________
# Epoch 1/25
# 2843/2843 [==============================] - 94s 31ms/step - loss: 0.2716 - accuracy: 0.8742 - val_loss: 0.2300 - val_accuracy: 0.8963
# Epoch 2/25
# 2843/2843 [==============================] - 85s 30ms/step - loss: 0.2401 - accuracy: 0.8915 - val_loss: 0.2190 - val_accuracy: 0.9000
# Epoch 3/25
# 2843/2843 [==============================] - 84s 30ms/step - loss: 0.2279 - accuracy: 0.8979 - val_loss: 0.2241 - val_accuracy: 0.8955
# Epoch 4/25
# 2843/2843 [==============================] - 88s 31ms/step - loss: 0.2201 - accuracy: 0.9022 - val_loss: 0.2128 - val_accuracy: 0.9037
# Epoch 5/25
# 2843/2843 [==============================] - 86s 30ms/step - loss: 0.2130 - accuracy: 0.9061 - val_loss: 0.2054 - val_accuracy: 0.9090
# Epoch 6/25
# 2843/2843 [==============================] - 86s 30ms/step - loss: 0.2068 - accuracy: 0.9091 - val_loss: 0.2042 - val_accuracy: 0.9091
# Epoch 7/25
# 2843/2843 [==============================] - 84s 30ms/step - loss: 0.2013 - accuracy: 0.9121 - val_loss: 0.2055 - val_accuracy: 0.9092
# Epoch 8/25
# 2843/2843 [==============================] - 85s 30ms/step - loss: 0.1949 - accuracy: 0.9154 - val_loss: 0.2034 - val_accuracy: 0.9097
# Epoch 9/25
# 2843/2843 [==============================] - 84s 30ms/step - loss: 0.1910 - accuracy: 0.9168 - val_loss: 0.2042 - val_accuracy: 0.9091
# Epoch 10/25
# 2843/2843 [==============================] - 84s 30ms/step - loss: 0.1872 - accuracy: 0.9191 - val_loss: 0.2042 - val_accuracy: 0.9083
# Epoch 11/25
# 2843/2843 [==============================] - 84s 30ms/step - loss: 0.1838 - accuracy: 0.9208 - val_loss: 0.2027 - val_accuracy: 0.9091
# Epoch 12/25
# 2843/2843 [==============================] - 88s 31ms/step - loss: 0.1790 - accuracy: 0.9228 - val_loss: 0.2031 - val_accuracy: 0.9089
# Epoch 13/25
# 2843/2843 [==============================] - 85s 30ms/step - loss: 0.1750 - accuracy: 0.9249 - val_loss: 0.2035 - val_accuracy: 0.9091
# Epoch 14/25
# 2843/2843 [==============================] - 88s 31ms/step - loss: 0.1718 - accuracy: 0.9262 - val_loss: 0.2044 - val_accuracy: 0.9093
# Epoch 15/25
# 2843/2843 [==============================] - 85s 30ms/step - loss: 0.1692 - accuracy: 0.9276 - val_loss: 0.2050 - val_accuracy: 0.9089
# Epoch 16/25
# 2843/2843 [==============================] - 85s 30ms/step - loss: 0.1657 - accuracy: 0.9293 - val_loss: 0.2063 - val_accuracy: 0.9086
# 4 validation loss: 0.2027083933353424
# 4 validation accuracy: 0.9096688032150269
# 18327/18327 [==============================] - 140s 8ms/step
# MODEL: 5
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_16 (InputLayer)          [(None, 30)]         0           []
#
#  input_17 (InputLayer)          [(None, 30)]         0           []
#
#  embedding_5 (Embedding)        (None, 30, 300)      1159500     ['input_16[0][0]',
#                                                                   'input_17[0][0]']
#
#  lstm_5 (LSTM)                  (None, 75)           112800      ['embedding_5[0][0]',
#                                                                   'embedding_5[1][0]']
#
#  lambda_5 (Lambda)              (None, 75)           0           ['lstm_5[1][0]']
#
#  add_11 (Add)                   (None, 75)           0           ['lstm_5[0][0]',
#                                                                   'lambda_5[0][0]']
#
#  input_18 (InputLayer)          [(None, 25)]         0           []
#
#  multiply_5 (Multiply)          (None, 75)           0           ['add_11[0][0]',
#                                                                   'add_11[0][0]']
#
#  add_10 (Add)                   (None, 75)           0           ['lstm_5[0][0]',
#                                                                   'lstm_5[1][0]']
#
#  batch_normalization_15 (BatchN  (None, 25)          100         ['input_18[0][0]']
#  ormalization)
#
#  concatenate_10 (Concatenate)   (None, 150)          0           ['multiply_5[0][0]',
#                                                                   'add_10[0][0]']
#
#  dense_15 (Dense)               (None, 200)          5200        ['batch_normalization_15[0][0]']
#
#  dropout_16 (Dropout)           (None, 150)          0           ['concatenate_10[0][0]']
#
#  dropout_15 (Dropout)           (None, 200)          0           ['dense_15[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 350)          0           ['dropout_16[0][0]',
#                                                                   'dropout_15[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 350)         1400        ['concatenate_11[0][0]']
#  ormalization)
#
#  gaussian_noise_5 (GaussianNois  (None, 350)         0           ['batch_normalization_16[0][0]']
#  e)
#
#  dense_16 (Dense)               (None, 150)          52650       ['gaussian_noise_5[0][0]']
#
#  dropout_17 (Dropout)           (None, 150)          0           ['dense_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 150)         600         ['dropout_17[0][0]']
#  ormalization)
#
#  dense_17 (Dense)               (None, 1)            151         ['batch_normalization_17[0][0]']
#
# ==================================================================================================
# Total params: 1,332,401
# Trainable params: 171,851
# Non-trainable params: 1,160,550
# __________________________________________________________________________________________________
# Epoch 1/25
# 2843/2843 [==============================] - 98s 32ms/step - loss: 0.2709 - accuracy: 0.8737 - val_loss: 0.2372 - val_accuracy: 0.8909
# Epoch 2/25
# 2843/2843 [==============================] - 95s 33ms/step - loss: 0.2393 - accuracy: 0.8914 - val_loss: 0.2259 - val_accuracy: 0.8989
# Epoch 3/25
# 2843/2843 [==============================] - 95s 33ms/step - loss: 0.2275 - accuracy: 0.8982 - val_loss: 0.2186 - val_accuracy: 0.9019
# Epoch 4/25
# 2843/2843 [==============================] - 95s 33ms/step - loss: 0.2190 - accuracy: 0.9032 - val_loss: 0.2138 - val_accuracy: 0.9044
# Epoch 5/25
# 2843/2843 [==============================] - 96s 34ms/step - loss: 0.2123 - accuracy: 0.9065 - val_loss: 0.2111 - val_accuracy: 0.9050
# Epoch 6/25
# 2843/2843 [==============================] - 95s 33ms/step - loss: 0.2057 - accuracy: 0.9097 - val_loss: 0.2102 - val_accuracy: 0.9053
# Epoch 7/25
# 2843/2843 [==============================] - 95s 33ms/step - loss: 0.2001 - accuracy: 0.9124 - val_loss: 0.2093 - val_accuracy: 0.9054
# Epoch 8/25
# 2843/2843 [==============================] - 95s 33ms/step - loss: 0.1956 - accuracy: 0.9148 - val_loss: 0.2119 - val_accuracy: 0.9055
# Epoch 9/25
# 2843/2843 [==============================] - 94s 33ms/step - loss: 0.1913 - accuracy: 0.9170 - val_loss: 0.2066 - val_accuracy: 0.9067
# Epoch 10/25
# ...
# 7 validation loss: 0.2023535519838333
# 7 validation accuracy: 0.9096935391426086
# 18327/18327 [==============================] - 153s 8ms/step
# MODEL: 8
# Model: "model_8"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_25 (InputLayer)          [(None, 30)]         0           []
#
#  input_26 (InputLayer)          [(None, 30)]         0           []
#
#  embedding_8 (Embedding)        (None, 30, 300)      1159500     ['input_25[0][0]',
#                                                                   'input_26[0][0]']
#
#  lstm_8 (LSTM)                  (None, 75)           112800      ['embedding_8[0][0]',
#                                                                   'embedding_8[1][0]']
#
#  lambda_8 (Lambda)              (None, 75)           0           ['lstm_8[1][0]']
#
#  add_17 (Add)                   (None, 75)           0           ['lstm_8[0][0]',
#                                                                   'lambda_8[0][0]']
#
#  input_27 (InputLayer)          [(None, 25)]         0           []
#
#  multiply_8 (Multiply)          (None, 75)           0           ['add_17[0][0]',
#                                                                   'add_17[0][0]']
#
#  add_16 (Add)                   (None, 75)           0           ['lstm_8[0][0]',
#                                                                   'lstm_8[1][0]']
#
#  batch_normalization_24 (BatchN  (None, 25)          100         ['input_27[0][0]']
#  ormalization)
#
#  concatenate_16 (Concatenate)   (None, 150)          0           ['multiply_8[0][0]',
#                                                                   'add_16[0][0]']
#
#  dense_24 (Dense)               (None, 200)          5200        ['batch_normalization_24[0][0]']
#
#  dropout_25 (Dropout)           (None, 150)          0           ['concatenate_16[0][0]']
#
#  dropout_24 (Dropout)           (None, 200)          0           ['dense_24[0][0]']
#
#  concatenate_17 (Concatenate)   (None, 350)          0           ['dropout_25[0][0]',
#                                                                   'dropout_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 350)         1400        ['concatenate_17[0][0]']
#  ormalization)
#
#  gaussian_noise_8 (GaussianNois  (None, 350)         0           ['batch_normalization_25[0][0]']
#  e)
#
#  dense_25 (Dense)               (None, 150)          52650       ['gaussian_noise_8[0][0]']
#
#  dropout_26 (Dropout)           (None, 150)          0           ['dense_25[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 150)         600         ['dropout_26[0][0]']
#  ormalization)
#
#  dense_26 (Dense)               (None, 1)            151         ['batch_normalization_26[0][0]']
#
# ==================================================================================================
# Total params: 1,332,401
# Trainable params: 171,851
# Non-trainable params: 1,160,550
# __________________________________________________________________________________________________
# Epoch 1/25
# 2843/2843 [==============================] - 104s 35ms/step - loss: 0.2699 - accuracy: 0.8746 - val_loss: 0.2393 - val_accuracy: 0.8892
# Epoch 2/25
# 2843/2843 [==============================] - 90s 32ms/step - loss: 0.2396 - accuracy: 0.8919 - val_loss: 0.2247 - val_accuracy: 0.8989
# Epoch 3/25
# 2843/2843 [==============================] - 94s 33ms/step - loss: 0.2272 - accuracy: 0.8981 - val_loss: 0.2176 - val_accuracy: 0.9038
# Epoch 4/25
# 2843/2843 [==============================] - 93s 33ms/step - loss: 0.2190 - accuracy: 0.9029 - val_loss: 0.2145 - val_accuracy: 0.9055
# Epoch 5/25
# 2843/2843 [==============================] - 90s 31ms/step - loss: 0.2118 - accuracy: 0.9069 - val_loss: 0.2108 - val_accuracy: 0.9067
# Epoch 6/25
# 2843/2843 [==============================] - 88s 31ms/step - loss: 0.2051 - accuracy: 0.9095 - val_loss: 0.2091 - val_accuracy: 0.9085
# Epoch 7/25
# 2843/2843 [==============================] - 88s 31ms/step - loss: 0.1996 - accuracy: 0.9128 - val_loss: 0.2125 - val_accuracy: 0.9072
# Epoch 8/25
# 2843/2843 [==============================] - 89s 31ms/step - loss: 0.1944 - accuracy: 0.9153 - val_loss: 0.2083 - val_accuracy: 0.9088
# Epoch 9/25
# 2843/2843 [==============================] - 88s 31ms/step - loss: 0.1901 - accuracy: 0.9175 - val_loss: 0.2095 - val_accuracy: 0.9079
# Epoch 10/25
# 2843/2843 [==============================] - 88s 31ms/step - loss: 0.1860 - accuracy: 0.9193 - val_loss: 0.2088 - val_accuracy: 0.9092
# Epoch 11/25
# 2843/2843 [==============================] - 88s 31ms/step - loss: 0.1818 - accuracy: 0.9217 - val_loss: 0.2097 - val_accuracy: 0.9093
# Epoch 12/25
# 2843/2843 [==============================] - 87s 31ms/step - loss: 0.1777 - accuracy: 0.9230 - val_loss: 0.2103 - val_accuracy: 0.9089
# Epoch 13/25
# 2843/2843 [==============================] - 86s 30ms/step - loss: 0.1745 - accuracy: 0.9249 - val_loss: 0.2115 - val_accuracy: 0.9083
# 8 validation loss: 0.2083277702331543
# 8 validation accuracy: 0.9092730283737183
# 18327/18327 [==============================] - 151s 8ms/step
# MODEL: 9
# Model: "model_9"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_28 (InputLayer)          [(None, 30)]         0           []
#
#  input_29 (InputLayer)          [(None, 30)]         0           []
#
#  embedding_9 (Embedding)        (None, 30, 300)      1159500     ['input_28[0][0]',
#                                                                   'input_29[0][0]']
#
#  lstm_9 (LSTM)                  (None, 75)           112800      ['embedding_9[0][0]',
#                                                                   'embedding_9[1][0]']
#
#  lambda_9 (Lambda)              (None, 75)           0           ['lstm_9[1][0]']
#
#  add_19 (Add)                   (None, 75)           0           ['lstm_9[0][0]',
#                                                                   'lambda_9[0][0]']
#
#  input_30 (InputLayer)          [(None, 25)]         0           []
#
#  multiply_9 (Multiply)          (None, 75)           0           ['add_19[0][0]',
#                                                                   'add_19[0][0]']
#
#  add_18 (Add)                   (None, 75)           0           ['lstm_9[0][0]',
#                                                                   'lstm_9[1][0]']
#
#  batch_normalization_27 (BatchN  (None, 25)          100         ['input_30[0][0]']
#  ormalization)
#
#  concatenate_18 (Concatenate)   (None, 150)          0           ['multiply_9[0][0]',
#                                                                   'add_18[0][0]']
#
#  dense_27 (Dense)               (None, 200)          5200        ['batch_normalization_27[0][0]']
#
#  dropout_28 (Dropout)           (None, 150)          0           ['concatenate_18[0][0]']
#
#  dropout_27 (Dropout)           (None, 200)          0           ['dense_27[0][0]']
#
#  concatenate_19 (Concatenate)   (None, 350)          0           ['dropout_28[0][0]',
#                                                                   'dropout_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 350)         1400        ['concatenate_19[0][0]']
#  ormalization)
#
#  gaussian_noise_9 (GaussianNois  (None, 350)         0           ['batch_normalization_28[0][0]']
#  e)
#
#  dense_28 (Dense)               (None, 150)          52650       ['gaussian_noise_9[0][0]']
#
#  dropout_29 (Dropout)           (None, 150)          0           ['dense_28[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 150)         600         ['dropout_29[0][0]']
#  ormalization)
#
#  dense_29 (Dense)               (None, 1)            151         ['batch_normalization_29[0][0]']
#
# ==================================================================================================
# Total params: 1,332,401
# Trainable params: 171,851
# Non-trainable params: 1,160,550
# __________________________________________________________________________________________________
# Epoch 1/25
# 2843/2843 [==============================] - 98s 32ms/step - loss: 0.2694 - accuracy: 0.8750 - val_loss: 0.2409 - val_accuracy: 0.8898
# Epoch 2/25
# 2843/2843 [==============================] - 90s 32ms/step - loss: 0.2389 - accuracy: 0.8921 - val_loss: 0.2280 - val_accuracy: 0.8971
# Epoch 3/25
# 2843/2843 [==============================] - 90s 32ms/step - loss: 0.2268 - accuracy: 0.8984 - val_loss: 0.2191 - val_accuracy: 0.9031
# Epoch 4/25
# 2843/2843 [==============================] - 91s 32ms/step - loss: 0.2183 - accuracy: 0.9027 - val_loss: 0.2155 - val_accuracy: 0.9034
# Epoch 5/25
# 2843/2843 [==============================] - 90s 32ms/step - loss: 0.2115 - accuracy: 0.9065 - val_loss: 0.2146 - val_accuracy: 0.9048
# Epoch 6/25
# 2843/2843 [==============================] - 89s 31ms/step - loss: 0.2046 - accuracy: 0.9099 - val_loss: 0.2139 - val_accuracy: 0.9065
# Epoch 7/25
# 2843/2843 [==============================] - 89s 31ms/step - loss: 0.1992 - accuracy: 0.9128 - val_loss: 0.2116 - val_accuracy: 0.9073
# Epoch 8/25
# 2843/2843 [==============================] - 89s 31ms/step - loss: 0.1947 - accuracy: 0.9148 - val_loss: 0.2088 - val_accuracy: 0.9075
# Epoch 9/25
# 2843/2843 [==============================] - 88s 31ms/step - loss: 0.1899 - accuracy: 0.9175 - val_loss: 0.2111 - val_accuracy: 0.9071
# Epoch 10/25
# 2843/2843 [==============================] - 91s 32ms/step - loss: 0.1855 - accuracy: 0.9196 - val_loss: 0.2094 - val_accuracy: 0.9076
# Epoch 11/25
# 2843/2843 [==============================] - 89s 31ms/step - loss: 0.1819 - accuracy: 0.9216 - val_loss: 0.2093 - val_accuracy: 0.9080
# Epoch 12/25
# 2843/2843 [==============================] - 88s 31ms/step - loss: 0.1779 - accuracy: 0.9234 - val_loss: 0.2120 - val_accuracy: 0.9067
# Epoch 13/25
# 2843/2843 [==============================] - 89s 31ms/step - loss: 0.1745 - accuracy: 0.9247 - val_loss: 0.2123 - val_accuracy: 0.9072
# 9 validation loss: 0.20878542959690094
# 9 validation accuracy: 0.9079620838165283
# 18327/18327 [==============================] - 209s 11ms/step
