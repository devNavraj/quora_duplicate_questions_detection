# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/quora_duplicate_questions_detection/
# Out:
# /content/drive/.shortcut-targets-by-id/1NfDfMFFEa6jbcf5EQ_tVWbvhytT96tlt/quora_duplicate_questions_detection

# %%
# !ls
# Out:
#  best_model0.h5   best_model9.h5	      __init__.py
#  best_model1.h5   classifier.py		      nlp_features.ipynb
#  best_model2.h5  'Copy of deep_nn.ipynb'      non_nlp_features.ipynb
#  best_model3.h5   data			      predictions
#  best_model4.h5   deep_nn-Copy1.ipynb	      __pycache__
#  best_model5.h5   deep_nn.ipynb		      tfidf_model.ipynb
#  best_model6.h5   deep_nn_test2.ipynb	      Untitled.ipynb
#  best_model7.h5   feature_engineering.ipynb   utils.py
#  best_model8.h5   graphs

# %%
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import StratifiedKFold
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Dense, Input, LSTM, Embedding, Dropout
from keras.layers.core import Lambda
from keras.layers.merge import concatenate, add, multiply
from keras.models import Model
from keras.layers import BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers.noise import GaussianNoise
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
np.random.seed(0)
WNL = WordNetLemmatizer()
STOP_WORDS = set(stopwords.words('english'))
MAX_SEQUENCE_LENGTH = 30
MIN_WORD_OCCURRENCE = 100
REPLACE_WORD = "rare"
EMBEDDING_DIM = 300
NUM_FOLDS = 10
BATCH_SIZE = 512
EMBEDDING_FILE = "data/glove.840B.300d.txt"

# %%
def cutter(word):
    if len(word) < 4:
        return word
    return WNL.lemmatize(WNL.lemmatize(word, "n"), "v")

# %%
def preprocess(string):
    string = string.lower().replace(",000,000", "m").replace(",000", "k").replace("′", "'").replace("’", "'") \
        .replace("won't", "will not").replace("cannot", "can not").replace("can't", "can not") \
        .replace("n't", " not").replace("what's", "what is").replace("it's", "it is") \
        .replace("'ve", " have").replace("i'm", "i am").replace("'re", " are") \
        .replace("he's", "he is").replace("she's", "she is").replace("'s", " own") \
        .replace("%", " percent ").replace("₹", " rupee ").replace("$", " dollar ") \
        .replace("€", " euro ").replace("'ll", " will").replace("=", " equal ").replace("+", " plus ")
    string = re.sub('[“”\(\'…\)\!\^\"\.;:,\-\?？\{\}\[\]\\/\*@]', ' ', string)
    string = re.sub(r"([0-9]+)000000", r"\1m", string)
    string = re.sub(r"([0-9]+)000", r"\1k", string)
    string = ' '.join([cutter(w) for w in string.split()])
    return string

# %%
def get_embedding():
    embeddings_index = {}
    f = open(EMBEDDING_FILE, encoding="utf8")
    for line in f:
        values = line.split()
        word = values[0]
        if len(values) == EMBEDDING_DIM + 1 and word in top_words:
            coefs = np.asarray(values[1:], dtype="float32")
            embeddings_index[word] = coefs
    f.close()
    return embeddings_index

# %%
def is_numeric(s):
    return any(i.isdigit() for i in s)

# %%
def prepare(q):
    new_q = []
    surplus_q = []
    numbers_q = []
    new_rare = True
    for w in q.split()[::-1]:
        if w in top_words:
            new_q = [w] + new_q
            new_rare = True
        elif w not in STOP_WORDS:
            if new_rare:
                new_q = ["rare"] + new_q
                new_rare = False
            if is_numeric(w):
                numbers_q = [w] + numbers_q
            else:
                surplus_q = [w] + surplus_q
        else:
            new_rare = True
        if len(new_q) == MAX_SEQUENCE_LENGTH:
            break
    new_q = " ".join(new_q)
    return new_q, set(surplus_q), set(numbers_q)

# %%
def extract_features(df):
    q1s = np.array([""] * len(df), dtype=object)
    q2s = np.array([""] * len(df), dtype=object)
    features = np.zeros((len(df), 4))

    for i, (q1, q2) in enumerate(list(zip(df["question1"], df["question2"]))):
        q1s[i], surplus1, numbers1 = prepare(q1)
        q2s[i], surplus2, numbers2 = prepare(q2)
        features[i, 0] = len(surplus1.intersection(surplus2))
        features[i, 1] = len(surplus1.union(surplus2))
        features[i, 2] = len(numbers1.intersection(numbers2))
        features[i, 3] = len(numbers1.union(numbers2))

    return q1s, q2s, features

# %%
train = pd.read_csv("data/train.csv")
test = pd.read_csv("data/test.csv")

# %%
train["question1"] = train["question1"].fillna("").apply(preprocess)
train["question2"] = train["question2"].fillna("").apply(preprocess)

# %%
print("Creating the vocabulary of words occurred more than", MIN_WORD_OCCURRENCE)
all_questions = pd.Series(train["question1"].tolist() + train["question2"].tolist()).unique()
vectorizer = CountVectorizer(lowercase=False, token_pattern="\S+", min_df=MIN_WORD_OCCURRENCE)
vectorizer.fit(all_questions)
top_words = set(vectorizer.vocabulary_.keys())
top_words.add(REPLACE_WORD)
# Out:
# Creating the vocabulary of words occurred more than 100

# %%
embeddings_index = get_embedding()
print("Words are not found in the embedding:", top_words - embeddings_index.keys())
top_words = embeddings_index.keys()
# Out:
# Words are not found in the embedding: {'iisc', 'demonetisation', 'oneplus', 'paytm', 'kvpy', 'c#', 'quorans', '\\sqrt', 'redmi', '\\frac', 'brexit'}

# %%
print("Train questions are being prepared for LSTM...")
q1s_train, q2s_train, train_q_features = extract_features(train)
# Out:
# Train questions are being prepared for LSTM...

# %%
tokenizer = Tokenizer(filters="")
tokenizer.fit_on_texts(np.append(q1s_train, q2s_train))
word_index = tokenizer.word_index

# %%
data_1 = pad_sequences(tokenizer.texts_to_sequences(q1s_train), maxlen=MAX_SEQUENCE_LENGTH)
data_2 = pad_sequences(tokenizer.texts_to_sequences(q2s_train), maxlen=MAX_SEQUENCE_LENGTH)
labels = np.array(train["is_duplicate"])

# %%
nb_words = len(word_index) + 1
embedding_matrix = np.zeros((nb_words, EMBEDDING_DIM))

# %%
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %%
print("Train features are being merged with NLP and Non-NLP features...")
train_nlp_features = pd.read_csv("data/nlp_features_train.csv")
train_non_nlp_features = pd.read_csv("data/non_nlp_features_train.csv")
features_train = np.hstack((train_q_features, train_nlp_features, train_non_nlp_features))
# Out:
# Train features are being merged with NLP and Non-NLP features...

# %%
print("Same steps are being applied for test...")
test["question1"] = test["question1"].fillna("").apply(preprocess)
test["question2"] = test["question2"].fillna("").apply(preprocess)

q1s_test, q2s_test, test_q_features = extract_features(test)

test_data_1 = pad_sequences(tokenizer.texts_to_sequences(q1s_test), maxlen=MAX_SEQUENCE_LENGTH)
test_data_2 = pad_sequences(tokenizer.texts_to_sequences(q2s_test), maxlen=MAX_SEQUENCE_LENGTH)

test_nlp_features = pd.read_csv("data/nlp_features_test.csv")
test_non_nlp_features = pd.read_csv("data/non_nlp_features_test.csv")
features_test = np.hstack((test_q_features, test_nlp_features, test_non_nlp_features))
# Out:
# Same steps are being applied for test...

# %%
stratified_kf = StratifiedKFold(n_splits=NUM_FOLDS, shuffle=True)
model_count = 0

# %%
'''With recurrent_dropout=0.2 get "not use cuDNN kernel" warning and time increases
to ~ 1 min per epoch & get following results for first fold:
validation loss: 0.20543508231639862
Wall time: 15min 58s - for complete run of 15 epochs & validation

with no recurrent_dropout cuDNN kernel is used ~ 9 seconds per epoch
validation loss: 0.20922143757343292
Wall time: 3min 10s'''
for idx_train, idx_val in stratified_kf.split(train["is_duplicate"], train["is_duplicate"]):
    print("MODEL:", model_count)
    data_1_train = data_1[idx_train]
    data_2_train = data_2[idx_train]
    labels_train = labels[idx_train]
    f_train = features_train[idx_train]

    data_1_val = data_1[idx_val]
    data_2_val = data_2[idx_val]
    labels_val = labels[idx_val]
    f_val = features_train[idx_val]

    embedding_layer = Embedding(nb_words,
                                EMBEDDING_DIM,
                                weights=[embedding_matrix],
                                input_length=MAX_SEQUENCE_LENGTH,
                                trainable=False)

    # lstm_layer = LSTM(75, recurrent_dropout=0.2)
    lstm_layer = LSTM(75)

    sequence_1_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype="int32")
    embedded_sequences_1 = embedding_layer(sequence_1_input)
    x1 = lstm_layer(embedded_sequences_1)

    sequence_2_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype="int32")
    embedded_sequences_2 = embedding_layer(sequence_2_input)
    y1 = lstm_layer(embedded_sequences_2)

    features_input = Input(shape=(f_train.shape[1],), dtype="float32")
    features_dense = BatchNormalization()(features_input)
    features_dense = Dense(200, activation="relu")(features_dense)
    features_dense = Dropout(0.2)(features_dense)

    addition = add([x1, y1])
    minus_y1 = Lambda(lambda x: -x)(y1)
    merged = add([x1, minus_y1])
    merged = multiply([merged, merged])
    merged = concatenate([merged, addition])
    merged = Dropout(0.4)(merged)

    merged = concatenate([merged, features_dense])
    merged = BatchNormalization()(merged)
    merged = GaussianNoise(0.1)(merged)

    merged = Dense(150, activation="relu")(merged)
    merged = Dropout(0.2)(merged)
    merged = BatchNormalization()(merged)

    out = Dense(1, activation="sigmoid")(merged)

    model = Model(inputs=[sequence_1_input, sequence_2_input, features_input], outputs=out)
    model.compile(loss="binary_crossentropy", optimizer="nadam", metrics=['accuracy'])
    model.summary()
    early_stopping = EarlyStopping(monitor="val_loss", patience=5)
    best_model_path = "models/test2/best_model" + str(model_count) + ".h5"
    model_checkpoint = ModelCheckpoint(best_model_path, save_best_only=True, save_weights_only=True)

    model_history = model.fit([data_1_train, data_2_train, f_train], labels_train, 
                     batch_size=BATCH_SIZE, epochs=25, shuffle=True,
                     validation_data=([data_1_val, data_2_val, f_val], labels_val),
                     callbacks=[early_stopping, model_checkpoint], verbose=1)

    model.load_weights(best_model_path)
    print(model_count, "validation loss:", min(model_history.history["val_loss"]))
    print(model_count, "validation accuracy:", max(model_history.history["val_accuracy"]))
    # Accuracy Graph
    fig = plt.figure(dpi = 100)
    plt.title("Accuracy")
    plt.plot(model_history.history["accuracy"], color = "g", label = "Train")
    plt.plot(model_history.history["val_accuracy"], color = "b", label = "Test")
    plt.legend(loc = "best")
    plt.savefig("graphs/accuracyLSTM" + str(model_count) + ".png")
    # Loss Graph
    fig = plt.figure(dpi = 100)
    plt.title("Loss")
    plt.plot(model_history.history["loss"], color = "g", label = "Train")
    plt.plot(model_history.history["val_loss"], color = "b", label = "Test")
    plt.legend(loc = "best")
    plt.savefig("graphs/test2/lossLSTM" + str(model_count) + ".png")

    # Model prediction
    preds = model.predict([test_data_1, test_data_2, features_test], batch_size=BATCH_SIZE, verbose=1)
    
    submission = pd.DataFrame({"test_id": test["test_id"], "is_duplicate": preds.ravel()})
    submission.to_csv("predictions/test2/preds" + str(model_count) + ".csv", index=False)

    model_count += 1
# Out:
# MODEL: 0
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_22 (InputLayer)          [(None, 30)]         0           []
#
#  input_23 (InputLayer)          [(None, 30)]         0           []
#
#  embedding_7 (Embedding)        (None, 30, 300)      1159500     ['input_22[0][0]',
#                                                                   'input_23[0][0]']
#
#  lstm_7 (LSTM)                  (None, 75)           112800      ['embedding_7[0][0]',
#                                                                   'embedding_7[1][0]']
#
#  lambda_7 (Lambda)              (None, 75)           0           ['lstm_7[1][0]']
#
#  add_15 (Add)                   (None, 75)           0           ['lstm_7[0][0]',
#                                                                   'lambda_7[0][0]']
#
#  input_24 (InputLayer)          [(None, 25)]         0           []
#
#  multiply_7 (Multiply)          (None, 75)           0           ['add_15[0][0]',
#                                                                   'add_15[0][0]']
#
#  add_14 (Add)                   (None, 75)           0           ['lstm_7[0][0]',
#                                                                   'lstm_7[1][0]']
#
#  batch_normalization_21 (BatchN  (None, 25)          100         ['input_24[0][0]']
#  ormalization)
#
#  concatenate_14 (Concatenate)   (None, 150)          0           ['multiply_7[0][0]',
#                                                                   'add_14[0][0]']
#
#  dense_21 (Dense)               (None, 200)          5200        ['batch_normalization_21[0][0]']
#
#  dropout_22 (Dropout)           (None, 150)          0           ['concatenate_14[0][0]']
#
#  dropout_21 (Dropout)           (None, 200)          0           ['dense_21[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 350)          0           ['dropout_22[0][0]',
#                                                                   'dropout_21[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 350)         1400        ['concatenate_15[0][0]']
#  ormalization)
#
#  gaussian_noise_7 (GaussianNois  (None, 350)         0           ['batch_normalization_22[0][0]']
#  e)
#
#  dense_22 (Dense)               (None, 150)          52650       ['gaussian_noise_7[0][0]']
#
#  dropout_23 (Dropout)           (None, 150)          0           ['dense_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 150)         600         ['dropout_23[0][0]']
#  ormalization)
#
#  dense_23 (Dense)               (None, 1)            151         ['batch_normalization_23[0][0]']
#
# ==================================================================================================
# Total params: 1,332,401
# Trainable params: 171,851
# Non-trainable params: 1,160,550
# __________________________________________________________________________________________________
# Epoch 1/25
# 711/711 [==============================] - 32s 37ms/step - loss: 0.2790 - accuracy: 0.8697 - val_loss: 0.2388 - val_accuracy: 0.8898
# Epoch 2/25
# 711/711 [==============================] - 26s 36ms/step - loss: 0.2428 - accuracy: 0.8888 - val_loss: 0.2268 - val_accuracy: 0.8968
# Epoch 3/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.2289 - accuracy: 0.8968 - val_loss: 0.2184 - val_accuracy: 0.8997
# Epoch 4/25
# 711/711 [==============================] - 26s 36ms/step - loss: 0.2199 - accuracy: 0.9019 - val_loss: 0.2130 - val_accuracy: 0.9037
# Epoch 5/25
# 711/711 [==============================] - 26s 36ms/step - loss: 0.2122 - accuracy: 0.9054 - val_loss: 0.2090 - val_accuracy: 0.9060
# Epoch 6/25
# 711/711 [==============================] - 26s 36ms/step - loss: 0.2062 - accuracy: 0.9085 - val_loss: 0.2075 - val_accuracy: 0.9071
# Epoch 7/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.2011 - accuracy: 0.9113 - val_loss: 0.2050 - val_accuracy: 0.9084
# Epoch 8/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.1965 - accuracy: 0.9135 - val_loss: 0.2037 - val_accuracy: 0.9095
# Epoch 9/25
# 711/711 [==============================] - 25s 36ms/step - loss: 0.1912 - accuracy: 0.9161 - val_loss: 0.2046 - val_accuracy: 0.9087
# Epoch 10/25
# 711/711 [==============================] - 25s 35ms/step - loss: 0.1873 - accuracy: 0.9179 - val_loss: 0.2051 - val_accuracy: 0.9084
# Epoch 11/25
# 711/711 [==============================] - 26s 36ms/step - loss: 0.1842 - accuracy: 0.9197 - val_loss: 0.2024 - val_accuracy: 0.9097
# Epoch 12/25
# 711/711 [==============================] - 26s 36ms/step - loss: 0.1802 - accuracy: 0.9217 - val_loss: 0.2032 - val_accuracy: 0.9088
# Epoch 13/25
# 711/711 [==============================] - 25s 36ms/step - loss: 0.1776 - accuracy: 0.9229 - val_loss: 0.2031 - val_accuracy: 0.9092
# Epoch 14/25
# 711/711 [==============================] - 26s 36ms/step - loss: 0.1741 - accuracy: 0.9248 - val_loss: 0.2034 - val_accuracy: 0.9099
# Epoch 15/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.1720 - accuracy: 0.9255 - val_loss: 0.2040 - val_accuracy: 0.9098
# Epoch 16/25
# 711/711 [==============================] - 26s 36ms/step - loss: 0.1677 - accuracy: 0.9274 - val_loss: 0.2047 - val_accuracy: 0.9104
# 0 validation loss: 0.20243507623672485
# 0 validation accuracy: 0.9103860855102539
# 4582/4582 [==============================] - 48s 10ms/step
# MODEL: 1
# Model: "model_8"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_25 (InputLayer)          [(None, 30)]         0           []
#
#  input_26 (InputLayer)          [(None, 30)]         0           []
#
#  embedding_8 (Embedding)        (None, 30, 300)      1159500     ['input_25[0][0]',
#                                                                   'input_26[0][0]']
#
#  lstm_8 (LSTM)                  (None, 75)           112800      ['embedding_8[0][0]',
#                                                                   'embedding_8[1][0]']
#
#  lambda_8 (Lambda)              (None, 75)           0           ['lstm_8[1][0]']
#
#  add_17 (Add)                   (None, 75)           0           ['lstm_8[0][0]',
#                                                                   'lambda_8[0][0]']
#
#  input_27 (InputLayer)          [(None, 25)]         0           []
#
#  multiply_8 (Multiply)          (None, 75)           0           ['add_17[0][0]',
#                                                                   'add_17[0][0]']
#
#  add_16 (Add)                   (None, 75)           0           ['lstm_8[0][0]',
#                                                                   'lstm_8[1][0]']
#
#  batch_normalization_24 (BatchN  (None, 25)          100         ['input_27[0][0]']
#  ormalization)
#
#  concatenate_16 (Concatenate)   (None, 150)          0           ['multiply_8[0][0]',
#                                                                   'add_16[0][0]']
#
#  dense_24 (Dense)               (None, 200)          5200        ['batch_normalization_24[0][0]']
#
#  dropout_25 (Dropout)           (None, 150)          0           ['concatenate_16[0][0]']
#
#  dropout_24 (Dropout)           (None, 200)          0           ['dense_24[0][0]']
#
#  concatenate_17 (Concatenate)   (None, 350)          0           ['dropout_25[0][0]',
#                                                                   'dropout_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 350)         1400        ['concatenate_17[0][0]']
#  ormalization)
#
#  gaussian_noise_8 (GaussianNois  (None, 350)         0           ['batch_normalization_25[0][0]']
#  e)
#
#  dense_25 (Dense)               (None, 150)          52650       ['gaussian_noise_8[0][0]']
#
#  dropout_26 (Dropout)           (None, 150)          0           ['dense_25[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 150)         600         ['dropout_26[0][0]']
#  ormalization)
#
#  dense_26 (Dense)               (None, 1)            151         ['batch_normalization_26[0][0]']
#
# ==================================================================================================
# Total params: 1,332,401
# Trainable params: 171,851
# Non-trainable params: 1,160,550
# __________________________________________________________________________________________________
# Epoch 1/25
# 711/711 [==============================] - 50s 39ms/step - loss: 0.2808 - accuracy: 0.8690 - val_loss: 0.2380 - val_accuracy: 0.8906
# Epoch 2/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.2425 - accuracy: 0.8897 - val_loss: 0.2285 - val_accuracy: 0.8966
# Epoch 3/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.2290 - accuracy: 0.8967 - val_loss: 0.2161 - val_accuracy: 0.9032
# Epoch 4/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.2201 - accuracy: 0.9015 - val_loss: 0.2104 - val_accuracy: 0.9056
# Epoch 5/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.2125 - accuracy: 0.9057 - val_loss: 0.2110 - val_accuracy: 0.9058
# Epoch 6/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.2067 - accuracy: 0.9086 - val_loss: 0.2066 - val_accuracy: 0.9086
# Epoch 7/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.2017 - accuracy: 0.9106 - val_loss: 0.2035 - val_accuracy: 0.9106
# Epoch 8/25
# 711/711 [==============================] - 27s 38ms/step - loss: 0.1969 - accuracy: 0.9135 - val_loss: 0.2088 - val_accuracy: 0.9081
# Epoch 9/25
# 711/711 [==============================] - 27s 38ms/step - loss: 0.1926 - accuracy: 0.9155 - val_loss: 0.2024 - val_accuracy: 0.9103
# Epoch 10/25
# 711/711 [==============================] - 27s 37ms/step - loss: 0.1874 - accuracy: 0.9177 - val_loss: 0.2022 - val_accuracy: 0.9121
# Epoch 11/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.1840 - accuracy: 0.9195 - val_loss: 0.2011 - val_accuracy: 0.9112
# Epoch 12/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.1805 - accuracy: 0.9215 - val_loss: 0.2021 - val_accuracy: 0.9105
# Epoch 13/25
# 711/711 [==============================] - 26s 36ms/step - loss: 0.1769 - accuracy: 0.9232 - val_loss: 0.2051 - val_accuracy: 0.9107
# Epoch 14/25
# 711/711 [==============================] - 26s 36ms/step - loss: 0.1737 - accuracy: 0.9253 - val_loss: 0.2024 - val_accuracy: 0.9121
# Epoch 15/25
# 711/711 [==============================] - 26s 36ms/step - loss: 0.1707 - accuracy: 0.9265 - val_loss: 0.2029 - val_accuracy: 0.9125
# Epoch 16/25
# 711/711 [==============================] - 26s 36ms/step - loss: 0.1688 - accuracy: 0.9272 - val_loss: 0.2043 - val_accuracy: 0.9118
# 1 validation loss: 0.20113806426525116
# 1 validation accuracy: 0.912488579750061
# 4582/4582 [==============================] - 48s 10ms/step
# MODEL: 2
# Model: "model_9"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_28 (InputLayer)          [(None, 30)]         0           []
#
#  input_29 (InputLayer)          [(None, 30)]         0           []
#
#  embedding_9 (Embedding)        (None, 30, 300)      1159500     ['input_28[0][0]',
#                                                                   'input_29[0][0]']
#
#  lstm_9 (LSTM)                  (None, 75)           112800      ['embedding_9[0][0]',
#                                                                   'embedding_9[1][0]']
#
#  lambda_9 (Lambda)              (None, 75)           0           ['lstm_9[1][0]']
#
#  add_19 (Add)                   (None, 75)           0           ['lstm_9[0][0]',
#                                                                   'lambda_9[0][0]']
#
#  input_30 (InputLayer)          [(None, 25)]         0           []
#
#  multiply_9 (Multiply)          (None, 75)           0           ['add_19[0][0]',
#                                                                   'add_19[0][0]']
#
#  add_18 (Add)                   (None, 75)           0           ['lstm_9[0][0]',
#                                                                   'lstm_9[1][0]']
#
#  batch_normalization_27 (BatchN  (None, 25)          100         ['input_30[0][0]']
#  ormalization)
#
#  concatenate_18 (Concatenate)   (None, 150)          0           ['multiply_9[0][0]',
#                                                                   'add_18[0][0]']
#
#  dense_27 (Dense)               (None, 200)          5200        ['batch_normalization_27[0][0]']
#
#  dropout_28 (Dropout)           (None, 150)          0           ['concatenate_18[0][0]']
#
#  dropout_27 (Dropout)           (None, 200)          0           ['dense_27[0][0]']
#
#  concatenate_19 (Concatenate)   (None, 350)          0           ['dropout_28[0][0]',
#                                                                   'dropout_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 350)         1400        ['concatenate_19[0][0]']
#  ormalization)
#
#  gaussian_noise_9 (GaussianNois  (None, 350)         0           ['batch_normalization_28[0][0]']
#  e)
#
#  dense_28 (Dense)               (None, 150)          52650       ['gaussian_noise_9[0][0]']
#
#  dropout_29 (Dropout)           (None, 150)          0           ['dense_28[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 150)         600         ['dropout_29[0][0]']
#  ormalization)
#
#  dense_29 (Dense)               (None, 1)            151         ['batch_normalization_29[0][0]']
#
# ==================================================================================================
# Total params: 1,332,401
# Trainable params: 171,851
# Non-trainable params: 1,160,550
# __________________________________________________________________________________________________
# Epoch 1/25
# 711/711 [==============================] - 34s 39ms/step - loss: 0.2796 - accuracy: 0.8695 - val_loss: 0.2427 - val_accuracy: 0.8880
# Epoch 2/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.2420 - accuracy: 0.8895 - val_loss: 0.2289 - val_accuracy: 0.8954
# Epoch 3/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.2286 - accuracy: 0.8968 - val_loss: 0.2200 - val_accuracy: 0.9002
# Epoch 4/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.2189 - accuracy: 0.9021 - val_loss: 0.2144 - val_accuracy: 0.9028
# Epoch 5/25
# 711/711 [==============================] - 27s 37ms/step - loss: 0.2111 - accuracy: 0.9058 - val_loss: 0.2128 - val_accuracy: 0.9049
# Epoch 6/25
# 711/711 [==============================] - 27s 38ms/step - loss: 0.2057 - accuracy: 0.9090 - val_loss: 0.2091 - val_accuracy: 0.9066
# Epoch 7/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.2003 - accuracy: 0.9117 - val_loss: 0.2085 - val_accuracy: 0.9061
# Epoch 8/25
# 711/711 [==============================] - 27s 37ms/step - loss: 0.1956 - accuracy: 0.9134 - val_loss: 0.2064 - val_accuracy: 0.9076
# Epoch 9/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.1905 - accuracy: 0.9168 - val_loss: 0.2061 - val_accuracy: 0.9076
# Epoch 10/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.1873 - accuracy: 0.9179 - val_loss: 0.2058 - val_accuracy: 0.9082
# Epoch 11/25
# 711/711 [==============================] - 26s 36ms/step - loss: 0.1829 - accuracy: 0.9199 - val_loss: 0.2049 - val_accuracy: 0.9088
# Epoch 12/25
# 711/711 [==============================] - 26s 36ms/step - loss: 0.1792 - accuracy: 0.9219 - val_loss: 0.2057 - val_accuracy: 0.9087
# Epoch 13/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.1764 - accuracy: 0.9231 - val_loss: 0.2061 - val_accuracy: 0.9082
# Epoch 14/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.1736 - accuracy: 0.9250 - val_loss: 0.2057 - val_accuracy: 0.9087
# Epoch 15/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.1698 - accuracy: 0.9265 - val_loss: 0.2080 - val_accuracy: 0.9083
# Epoch 16/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.1670 - accuracy: 0.9279 - val_loss: 0.2105 - val_accuracy: 0.9076
# 2 validation loss: 0.204863041639328
# 2 validation accuracy: 0.9087536334991455
# 4582/4582 [==============================] - 48s 10ms/step
# MODEL: 3
# Model: "model_10"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_31 (InputLayer)          [(None, 30)]         0           []
#
#  input_32 (InputLayer)          [(None, 30)]         0           []
#
#  embedding_10 (Embedding)       (None, 30, 300)      1159500     ['input_31[0][0]',
#                                                                   'input_32[0][0]']
#
#  lstm_10 (LSTM)                 (None, 75)           112800      ['embedding_10[0][0]',
#                                                                   'embedding_10[1][0]']
#
#  lambda_10 (Lambda)             (None, 75)           0           ['lstm_10[1][0]']
#
#  add_21 (Add)                   (None, 75)           0           ['lstm_10[0][0]',
#                                                                   'lambda_10[0][0]']
#
#  input_33 (InputLayer)          [(None, 25)]         0           []
#
#  multiply_10 (Multiply)         (None, 75)           0           ['add_21[0][0]',
#                                                                   'add_21[0][0]']
#
#  add_20 (Add)                   (None, 75)           0           ['lstm_10[0][0]',
#                                                                   'lstm_10[1][0]']
#
#  batch_normalization_30 (BatchN  (None, 25)          100         ['input_33[0][0]']
#  ormalization)
#
#  concatenate_20 (Concatenate)   (None, 150)          0           ['multiply_10[0][0]',
#                                                                   'add_20[0][0]']
#
#  dense_30 (Dense)               (None, 200)          5200        ['batch_normalization_30[0][0]']
#
#  dropout_31 (Dropout)           (None, 150)          0           ['concatenate_20[0][0]']
#
#  dropout_30 (Dropout)           (None, 200)          0           ['dense_30[0][0]']
#
#  concatenate_21 (Concatenate)   (None, 350)          0           ['dropout_31[0][0]',
#                                                                   'dropout_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 350)         1400        ['concatenate_21[0][0]']
#  ormalization)
#
#  gaussian_noise_10 (GaussianNoi  (None, 350)         0           ['batch_normalization_31[0][0]']
#  se)
#
#  dense_31 (Dense)               (None, 150)          52650       ['gaussian_noise_10[0][0]']
#
#  dropout_32 (Dropout)           (None, 150)          0           ['dense_31[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 150)         600         ['dropout_32[0][0]']
#  ormalization)
#
#  dense_32 (Dense)               (None, 1)            151         ['batch_normalization_32[0][0]']
#
# ==================================================================================================
# Total params: 1,332,401
# Trainable params: 171,851
# Non-trainable params: 1,160,550
# __________________________________________________________________________________________________
# Epoch 1/25
# 711/711 [==============================] - 34s 39ms/step - loss: 0.2824 - accuracy: 0.8682 - val_loss: 0.2436 - val_accuracy: 0.8886
# Epoch 2/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.2429 - accuracy: 0.8885 - val_loss: 0.2283 - val_accuracy: 0.8980
# Epoch 3/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.2293 - accuracy: 0.8961 - val_loss: 0.2201 - val_accuracy: 0.9010
# Epoch 4/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.2195 - accuracy: 0.9013 - val_loss: 0.2185 - val_accuracy: 0.9045
# Epoch 5/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.2125 - accuracy: 0.9052 - val_loss: 0.2125 - val_accuracy: 0.9059
# Epoch 6/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.2065 - accuracy: 0.9083 - val_loss: 0.2115 - val_accuracy: 0.9067
# Epoch 7/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.2007 - accuracy: 0.9115 - val_loss: 0.2083 - val_accuracy: 0.9084
# Epoch 8/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.1959 - accuracy: 0.9139 - val_loss: 0.2077 - val_accuracy: 0.9094
# Epoch 9/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.1918 - accuracy: 0.9158 - val_loss: 0.2068 - val_accuracy: 0.9097
# Epoch 10/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.1876 - accuracy: 0.9176 - val_loss: 0.2069 - val_accuracy: 0.9103
# Epoch 11/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.1839 - accuracy: 0.9197 - val_loss: 0.2067 - val_accuracy: 0.9098
# Epoch 12/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.1799 - accuracy: 0.9217 - val_loss: 0.2074 - val_accuracy: 0.9105
# Epoch 13/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.1762 - accuracy: 0.9236 - val_loss: 0.2069 - val_accuracy: 0.9108
# Epoch 14/25
# 711/711 [==============================] - 26s 36ms/step - loss: 0.1733 - accuracy: 0.9243 - val_loss: 0.2103 - val_accuracy: 0.9087
# Epoch 15/25
# 711/711 [==============================] - 26s 36ms/step - loss: 0.1707 - accuracy: 0.9260 - val_loss: 0.2084 - val_accuracy: 0.9106
# Epoch 16/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.1671 - accuracy: 0.9280 - val_loss: 0.2091 - val_accuracy: 0.9089
# 3 validation loss: 0.20668475329875946
# 3 validation accuracy: 0.9108313322067261
# 4582/4582 [==============================] - 49s 10ms/step
# MODEL: 4
# Model: "model_11"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_34 (InputLayer)          [(None, 30)]         0           []
#
#  input_35 (InputLayer)          [(None, 30)]         0           []
#
#  embedding_11 (Embedding)       (None, 30, 300)      1159500     ['input_34[0][0]',
#                                                                   'input_35[0][0]']
#
#  lstm_11 (LSTM)                 (None, 75)           112800      ['embedding_11[0][0]',
#                                                                   'embedding_11[1][0]']
#
#  lambda_11 (Lambda)             (None, 75)           0           ['lstm_11[1][0]']
#
#  add_23 (Add)                   (None, 75)           0           ['lstm_11[0][0]',
#                                                                   'lambda_11[0][0]']
#
#  input_36 (InputLayer)          [(None, 25)]         0           []
#
#  multiply_11 (Multiply)         (None, 75)           0           ['add_23[0][0]',
#                                                                   'add_23[0][0]']
#
#  add_22 (Add)                   (None, 75)           0           ['lstm_11[0][0]',
#                                                                   'lstm_11[1][0]']
#
#  batch_normalization_33 (BatchN  (None, 25)          100         ['input_36[0][0]']
#  ormalization)
#
#  concatenate_22 (Concatenate)   (None, 150)          0           ['multiply_11[0][0]',
#                                                                   'add_22[0][0]']
#
#  dense_33 (Dense)               (None, 200)          5200        ['batch_normalization_33[0][0]']
#
#  dropout_34 (Dropout)           (None, 150)          0           ['concatenate_22[0][0]']
#
#  dropout_33 (Dropout)           (None, 200)          0           ['dense_33[0][0]']
#
#  concatenate_23 (Concatenate)   (None, 350)          0           ['dropout_34[0][0]',
#                                                                   'dropout_33[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 350)         1400        ['concatenate_23[0][0]']
#  ormalization)
#
#  gaussian_noise_11 (GaussianNoi  (None, 350)         0           ['batch_normalization_34[0][0]']
#  se)
#
#  dense_34 (Dense)               (None, 150)          52650       ['gaussian_noise_11[0][0]']
#
#  dropout_35 (Dropout)           (None, 150)          0           ['dense_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 150)         600         ['dropout_35[0][0]']
#  ormalization)
#
#  dense_35 (Dense)               (None, 1)            151         ['batch_normalization_35[0][0]']
#
# ==================================================================================================
# Total params: 1,332,401
# Trainable params: 171,851
# Non-trainable params: 1,160,550
# __________________________________________________________________________________________________
# Epoch 1/25
# 711/711 [==============================] - 34s 40ms/step - loss: 0.2794 - accuracy: 0.8695 - val_loss: 0.2548 - val_accuracy: 0.8805
# Epoch 2/25
# 711/711 [==============================] - 27s 38ms/step - loss: 0.2408 - accuracy: 0.8901 - val_loss: 0.2329 - val_accuracy: 0.8929
# Epoch 3/25
# 711/711 [==============================] - 27s 38ms/step - loss: 0.2269 - accuracy: 0.8976 - val_loss: 0.2225 - val_accuracy: 0.8995
# Epoch 4/25
# 711/711 [==============================] - 27s 38ms/step - loss: 0.2181 - accuracy: 0.9025 - val_loss: 0.2192 - val_accuracy: 0.9018
# Epoch 5/25
# 711/711 [==============================] - 27s 38ms/step - loss: 0.2106 - accuracy: 0.9067 - val_loss: 0.2183 - val_accuracy: 0.9006
# Epoch 6/25
# 711/711 [==============================] - 27s 37ms/step - loss: 0.2048 - accuracy: 0.9094 - val_loss: 0.2138 - val_accuracy: 0.9026
# Epoch 7/25
# 711/711 [==============================] - 27s 38ms/step - loss: 0.1997 - accuracy: 0.9124 - val_loss: 0.2142 - val_accuracy: 0.9045
# Epoch 8/25
# 711/711 [==============================] - 27s 38ms/step - loss: 0.1947 - accuracy: 0.9148 - val_loss: 0.2111 - val_accuracy: 0.9047
# Epoch 9/25
# 711/711 [==============================] - 27s 38ms/step - loss: 0.1904 - accuracy: 0.9166 - val_loss: 0.2103 - val_accuracy: 0.9054
# Epoch 10/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.1856 - accuracy: 0.9193 - val_loss: 0.2112 - val_accuracy: 0.9055
# Epoch 11/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.1829 - accuracy: 0.9208 - val_loss: 0.2106 - val_accuracy: 0.9063
# Epoch 12/25
# 711/711 [==============================] - 27s 38ms/step - loss: 0.1792 - accuracy: 0.9221 - val_loss: 0.2093 - val_accuracy: 0.9079
# Epoch 13/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.1760 - accuracy: 0.9239 - val_loss: 0.2105 - val_accuracy: 0.9065
# Epoch 14/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.1727 - accuracy: 0.9255 - val_loss: 0.2101 - val_accuracy: 0.9065
# Epoch 15/25
# 711/711 [==============================] - 26s 37ms/step - loss: 0.1695 - accuracy: 0.9267 - val_loss: 0.2101 - val_accuracy: 0.9066
# Epoch 16/25
# 711/711 [==============================] - 27s 38ms/step - loss: 0.1666 - accuracy: 0.9279 - val_loss: 0.2128 - val_accuracy: 0.9054
# Epoch 17/25
# 711/711 [==============================] - 27s 37ms/step - loss: 0.1639 - accuracy: 0.9293 - val_loss: 0.2122 - val_accuracy: 0.9064
# 4 validation loss: 0.20927013456821442
# 4 validation accuracy: 0.9078631401062012
# 4582/4582 [==============================] - 50s 11ms/step
# MODEL: 5
# Model: "model_12"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_37 (InputLayer)          [(None, 30)]         0           []
#
#  input_38 (InputLayer)          [(None, 30)]         0           []
#
#  embedding_12 (Embedding)       (None, 30, 300)      1159500     ['input_37[0][0]',
#                                                                   'input_38[0][0]']
#
#  lstm_12 (LSTM)                 (None, 75)           112800      ['embedding_12[0][0]',
#                                                                   'embedding_12[1][0]']
#
#  lambda_12 (Lambda)             (None, 75)           0           ['lstm_12[1][0]']
#
#  add_25 (Add)                   (None, 75)           0           ['lstm_12[0][0]',
#                                                                   'lambda_12[0][0]']
#
#  input_39 (InputLayer)          [(None, 25)]         0           []
#
#  multiply_12 (Multiply)         (None, 75)           0           ['add_25[0][0]',
#                                                                   'add_25[0][0]']
#
#  add_24 (Add)                   (None, 75)           0           ['lstm_12[0][0]',
#                                                                   'lstm_12[1][0]']
#
#  batch_normalization_36 (BatchN  (None, 25)          100         ['input_39[0][0]']
#  ormalization)
#
#  concatenate_24 (Concatenate)   (None, 150)          0           ['multiply_12[0][0]',
#                                                                   'add_24[0][0]']
#
#  dense_36 (Dense)               (None, 200)          5200        ['batch_normalization_36[0][0]']
#
#  dropout_37 (Dropout)           (None, 150)          0           ['concatenate_24[0][0]']
#
#  dropout_36 (Dropout)           (None, 200)          0           ['dense_36[0][0]']
#
#  concatenate_25 (Concatenate)   (None, 350)          0           ['dropout_37[0][0]',
#                                                                   'dropout_36[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 350)         1400        ['concatenate_25[0][0]']
#  ormalization)
#
#  gaussian_noise_12 (GaussianNoi  (None, 350)         0           ['batch_normalization_37[0][0]']
#  se)
#
#  dense_37 (Dense)               (None, 150)          52650       ['gaussian_noise_12[0][0]']
#
#  dropout_38 (Dropout)           (None, 150)          0           ['dense_37[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 150)         600         ['dropout_38[0][0]']
#  ormalization)
#
#  dense_38 (Dense)               (None, 1)            151         ['batch_normalization_38[0][0]']
#
# ==================================================================================================
# Total params: 1,332,401
# Trainable params: 171,851
# Non-trainable params: 1,160,550
# __________________________________________________________________________________________________
# Epoch 1/25
# 711/711 [==============================] - 34s 40ms/step - loss: 0.2805 - accuracy: 0.8686 - val_loss: 0.2563 - val_accuracy: 0.8804
# Epoch 2/25
# 711/711 [==============================] - 27s 38ms/step - loss: 0.2421 - accuracy: 0.8893 - val_loss: 0.2291 - val_accuracy: 0.8960
# Epoch 3/25
# 711/711 [==============================] - 27s 38ms/step - loss: 0.2286 - accuracy: 0.8969 - val_loss: 0.2257 - val_accuracy: 0.8972
# Epoch 4/25
# ...
#                                                                   'input_47[0][0]']
#
#  lstm_15 (LSTM)                 (None, 75)           112800      ['embedding_15[0][0]',
#                                                                   'embedding_15[1][0]']
#
#  lambda_15 (Lambda)             (None, 75)           0           ['lstm_15[1][0]']
#
#  add_31 (Add)                   (None, 75)           0           ['lstm_15[0][0]',
#                                                                   'lambda_15[0][0]']
#
#  input_48 (InputLayer)          [(None, 25)]         0           []
#
#  multiply_15 (Multiply)         (None, 75)           0           ['add_31[0][0]',
#                                                                   'add_31[0][0]']
#
#  add_30 (Add)                   (None, 75)           0           ['lstm_15[0][0]',
#                                                                   'lstm_15[1][0]']
#
#  batch_normalization_45 (BatchN  (None, 25)          100         ['input_48[0][0]']
#  ormalization)
#
#  concatenate_30 (Concatenate)   (None, 150)          0           ['multiply_15[0][0]',
#                                                                   'add_30[0][0]']
#
#  dense_45 (Dense)               (None, 200)          5200        ['batch_normalization_45[0][0]']
#
#  dropout_46 (Dropout)           (None, 150)          0           ['concatenate_30[0][0]']
#
#  dropout_45 (Dropout)           (None, 200)          0           ['dense_45[0][0]']
#
#  concatenate_31 (Concatenate)   (None, 350)          0           ['dropout_46[0][0]',
#                                                                   'dropout_45[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 350)         1400        ['concatenate_31[0][0]']
#  ormalization)
#
#  gaussian_noise_15 (GaussianNoi  (None, 350)         0           ['batch_normalization_46[0][0]']
#  se)
#
#  dense_46 (Dense)               (None, 150)          52650       ['gaussian_noise_15[0][0]']
#
#  dropout_47 (Dropout)           (None, 150)          0           ['dense_46[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 150)         600         ['dropout_47[0][0]']
#  ormalization)
#
#  dense_47 (Dense)               (None, 1)            151         ['batch_normalization_47[0][0]']
#
# ==================================================================================================
# Total params: 1,332,401
# Trainable params: 171,851
# Non-trainable params: 1,160,550
# __________________________________________________________________________________________________
# Epoch 1/25
# 711/711 [==============================] - 34s 40ms/step - loss: 0.2799 - accuracy: 0.8695 - val_loss: 0.2406 - val_accuracy: 0.8880
# Epoch 2/25
# 711/711 [==============================] - 28s 39ms/step - loss: 0.2422 - accuracy: 0.8895 - val_loss: 0.2257 - val_accuracy: 0.8978
# Epoch 3/25
# 711/711 [==============================] - 27s 38ms/step - loss: 0.2284 - accuracy: 0.8966 - val_loss: 0.2206 - val_accuracy: 0.9009
# Epoch 4/25
# 711/711 [==============================] - 27s 38ms/step - loss: 0.2201 - accuracy: 0.9015 - val_loss: 0.2130 - val_accuracy: 0.9044
# Epoch 5/25
# 711/711 [==============================] - 27s 38ms/step - loss: 0.2126 - accuracy: 0.9053 - val_loss: 0.2100 - val_accuracy: 0.9057
# Epoch 6/25
# 711/711 [==============================] - 27s 38ms/step - loss: 0.2069 - accuracy: 0.9086 - val_loss: 0.2077 - val_accuracy: 0.9071
# Epoch 7/25
# 711/711 [==============================] - 27s 38ms/step - loss: 0.2016 - accuracy: 0.9106 - val_loss: 0.2079 - val_accuracy: 0.9070
# Epoch 8/25
# 711/711 [==============================] - 27s 38ms/step - loss: 0.1960 - accuracy: 0.9137 - val_loss: 0.2063 - val_accuracy: 0.9081
# Epoch 9/25
# 711/711 [==============================] - 27s 38ms/step - loss: 0.1920 - accuracy: 0.9155 - val_loss: 0.2053 - val_accuracy: 0.9092
# Epoch 10/25
# 711/711 [==============================] - 27s 38ms/step - loss: 0.1877 - accuracy: 0.9177 - val_loss: 0.2065 - val_accuracy: 0.9083
# Epoch 11/25
# 711/711 [==============================] - 27s 39ms/step - loss: 0.1842 - accuracy: 0.9197 - val_loss: 0.2049 - val_accuracy: 0.9100
# Epoch 12/25
# 711/711 [==============================] - 27s 38ms/step - loss: 0.1804 - accuracy: 0.9213 - val_loss: 0.2040 - val_accuracy: 0.9096
# Epoch 13/25
# 711/711 [==============================] - 27s 38ms/step - loss: 0.1773 - accuracy: 0.9228 - val_loss: 0.2037 - val_accuracy: 0.9094
# Epoch 14/25
# 711/711 [==============================] - 27s 38ms/step - loss: 0.1739 - accuracy: 0.9247 - val_loss: 0.2057 - val_accuracy: 0.9094
# Epoch 15/25
# 711/711 [==============================] - 27s 38ms/step - loss: 0.1712 - accuracy: 0.9258 - val_loss: 0.2082 - val_accuracy: 0.9098
# Epoch 16/25
# 711/711 [==============================] - 27s 38ms/step - loss: 0.1681 - accuracy: 0.9273 - val_loss: 0.2063 - val_accuracy: 0.9101
# Epoch 17/25
# 711/711 [==============================] - 27s 38ms/step - loss: 0.1660 - accuracy: 0.9287 - val_loss: 0.2070 - val_accuracy: 0.9118
# Epoch 18/25
# 711/711 [==============================] - 27s 38ms/step - loss: 0.1629 - accuracy: 0.9300 - val_loss: 0.2103 - val_accuracy: 0.9079
# 8 validation loss: 0.20369476079940796
# 8 validation accuracy: 0.9118207097053528
# 4582/4582 [==============================] - 51s 11ms/step
# MODEL: 9
# Model: "model_16"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_49 (InputLayer)          [(None, 30)]         0           []
#
#  input_50 (InputLayer)          [(None, 30)]         0           []
#
#  embedding_16 (Embedding)       (None, 30, 300)      1159500     ['input_49[0][0]',
#                                                                   'input_50[0][0]']
#
#  lstm_16 (LSTM)                 (None, 75)           112800      ['embedding_16[0][0]',
#                                                                   'embedding_16[1][0]']
#
#  lambda_16 (Lambda)             (None, 75)           0           ['lstm_16[1][0]']
#
#  add_33 (Add)                   (None, 75)           0           ['lstm_16[0][0]',
#                                                                   'lambda_16[0][0]']
#
#  input_51 (InputLayer)          [(None, 25)]         0           []
#
#  multiply_16 (Multiply)         (None, 75)           0           ['add_33[0][0]',
#                                                                   'add_33[0][0]']
#
#  add_32 (Add)                   (None, 75)           0           ['lstm_16[0][0]',
#                                                                   'lstm_16[1][0]']
#
#  batch_normalization_48 (BatchN  (None, 25)          100         ['input_51[0][0]']
#  ormalization)
#
#  concatenate_32 (Concatenate)   (None, 150)          0           ['multiply_16[0][0]',
#                                                                   'add_32[0][0]']
#
#  dense_48 (Dense)               (None, 200)          5200        ['batch_normalization_48[0][0]']
#
#  dropout_49 (Dropout)           (None, 150)          0           ['concatenate_32[0][0]']
#
#  dropout_48 (Dropout)           (None, 200)          0           ['dense_48[0][0]']
#
#  concatenate_33 (Concatenate)   (None, 350)          0           ['dropout_49[0][0]',
#                                                                   'dropout_48[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 350)         1400        ['concatenate_33[0][0]']
#  ormalization)
#
#  gaussian_noise_16 (GaussianNoi  (None, 350)         0           ['batch_normalization_49[0][0]']
#  se)
#
#  dense_49 (Dense)               (None, 150)          52650       ['gaussian_noise_16[0][0]']
#
#  dropout_50 (Dropout)           (None, 150)          0           ['dense_49[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 150)         600         ['dropout_50[0][0]']
#  ormalization)
#
#  dense_50 (Dense)               (None, 1)            151         ['batch_normalization_50[0][0]']
#
# ==================================================================================================
# Total params: 1,332,401
# Trainable params: 171,851
# Non-trainable params: 1,160,550
# __________________________________________________________________________________________________
# Epoch 1/25
# 711/711 [==============================] - 34s 41ms/step - loss: 0.2807 - accuracy: 0.8685 - val_loss: 0.2494 - val_accuracy: 0.8845
# Epoch 2/25
# 711/711 [==============================] - 28s 39ms/step - loss: 0.2417 - accuracy: 0.8891 - val_loss: 0.2315 - val_accuracy: 0.8951
# Epoch 3/25
# 711/711 [==============================] - 27s 39ms/step - loss: 0.2291 - accuracy: 0.8964 - val_loss: 0.2232 - val_accuracy: 0.9004
# Epoch 4/25
# 711/711 [==============================] - 27s 39ms/step - loss: 0.2200 - accuracy: 0.9012 - val_loss: 0.2190 - val_accuracy: 0.9016
# Epoch 5/25
# 711/711 [==============================] - 28s 39ms/step - loss: 0.2122 - accuracy: 0.9051 - val_loss: 0.2131 - val_accuracy: 0.9063
# Epoch 6/25
# 711/711 [==============================] - 28s 39ms/step - loss: 0.2068 - accuracy: 0.9078 - val_loss: 0.2120 - val_accuracy: 0.9064
# Epoch 7/25
# 711/711 [==============================] - 28s 39ms/step - loss: 0.2013 - accuracy: 0.9106 - val_loss: 0.2096 - val_accuracy: 0.9069
# Epoch 8/25
# 711/711 [==============================] - 28s 39ms/step - loss: 0.1966 - accuracy: 0.9135 - val_loss: 0.2092 - val_accuracy: 0.9078
# Epoch 9/25
# 711/711 [==============================] - 28s 39ms/step - loss: 0.1923 - accuracy: 0.9155 - val_loss: 0.2087 - val_accuracy: 0.9081
# Epoch 10/25
# 711/711 [==============================] - 28s 39ms/step - loss: 0.1879 - accuracy: 0.9176 - val_loss: 0.2063 - val_accuracy: 0.9083
# Epoch 11/25
# 711/711 [==============================] - 27s 38ms/step - loss: 0.1839 - accuracy: 0.9196 - val_loss: 0.2084 - val_accuracy: 0.9081
# Epoch 12/25
# 711/711 [==============================] - 27s 38ms/step - loss: 0.1802 - accuracy: 0.9215 - val_loss: 0.2079 - val_accuracy: 0.9099
# Epoch 13/25
# 711/711 [==============================] - 27s 38ms/step - loss: 0.1770 - accuracy: 0.9235 - val_loss: 0.2089 - val_accuracy: 0.9066
# Epoch 14/25
# 711/711 [==============================] - 28s 39ms/step - loss: 0.1737 - accuracy: 0.9241 - val_loss: 0.2075 - val_accuracy: 0.9098
# Epoch 15/25
# 711/711 [==============================] - 28s 39ms/step - loss: 0.1708 - accuracy: 0.9264 - val_loss: 0.2099 - val_accuracy: 0.9080
# 9 validation loss: 0.20632466673851013
# 9 validation accuracy: 0.9098666906356812
# 4582/4582 [==============================] - 52s 11ms/step
