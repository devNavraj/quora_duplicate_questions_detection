# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/quora_duplicate_questions_detection/
# Out:
# /content/drive/MyDrive/quora_duplicate_questions_detection

# %%
# !ls
# Out:
#  bert			       __init__.py
#  bilstm_nn_test1.ipynb	       lstm_feature_test1.ipynb
#  bilstm_nn_test2.ipynb	       lstm_test1.ipynb
#  classifier.py		       model.png
#  cnn_features_test1.ipynb      models
#  cnn_test1.ipynb	       models4.ipynb
# 'Copy of deep_nn.ipynb'        models5.ipynb
# 'Copy of nlp_features.ipynb'   model_tfidf.ipynb
#  data			       nlp_features.ipynb
#  deep_nn.ipynb		       nn_plot
#  deep_nn_test1.ipynb	       non_nlp_features.ipynb
#  deep_nn_test2.ipynb	       predictions
#  deep_nn_test3.ipynb	       __pycache__
#  feature_engineering.ipynb     tfidf_model.ipynb
#  graphs			       Untitled.ipynb
#  gru_simple.ipynb	       utils.py
#  gru_test1.ipynb	       word2vec_features.ipynb

# %%
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import StratifiedKFold
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Dense, Input, LSTM, Embedding, Dropout
from keras.layers.core import Lambda
from keras.layers.merge import concatenate, add, multiply
from keras.models import Model, Sequential
from keras.layers import BatchNormalization
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers.noise import GaussianNoise
from keras import backend as K
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
np.random.seed(0)
WNL = WordNetLemmatizer()
STOP_WORDS = set(stopwords.words('english'))
MAX_SEQUENCE_LENGTH = 30
MIN_WORD_OCCURRENCE = 100
REPLACE_WORD = "rare"
EMBEDDING_DIM = 300
NUM_FOLDS = 10
BATCH_SIZE = 256
EMBEDDING_FILE = "data/glove.840B.300d.txt"

# %%
def cutter(word):
    if len(word) < 4:
        return word
    return WNL.lemmatize(WNL.lemmatize(word, "n"), "v")

# %%
def preprocess(string):
    string = string.lower().replace(",000,000", "m").replace(",000", "k").replace("′", "'").replace("’", "'") \
        .replace("won't", "will not").replace("cannot", "can not").replace("can't", "can not") \
        .replace("n't", " not").replace("what's", "what is").replace("it's", "it is") \
        .replace("'ve", " have").replace("i'm", "i am").replace("'re", " are") \
        .replace("he's", "he is").replace("she's", "she is").replace("'s", " own") \
        .replace("%", " percent ").replace("₹", " rupee ").replace("$", " dollar ") \
        .replace("€", " euro ").replace("'ll", " will").replace("=", " equal ").replace("+", " plus ")
    string = re.sub('[“”\(\'…\)\!\^\"\.;:,\-\?？\{\}\[\]\\/\*@]', ' ', string)
    string = re.sub(r"([0-9]+)000000", r"\1m", string)
    string = re.sub(r"([0-9]+)000", r"\1k", string)
    string = ' '.join([cutter(w) for w in string.split()])
    return string

# %%
def get_embedding():
    embeddings_index = {}
    f = open(EMBEDDING_FILE, encoding="utf8")
    for line in f:
        values = line.split()
        word = values[0]
        if len(values) == EMBEDDING_DIM + 1 and word in top_words:
            coefs = np.asarray(values[1:], dtype="float32")
            embeddings_index[word] = coefs
    f.close()
    return embeddings_index

# %%
def is_numeric(s):
    return any(i.isdigit() for i in s)

# %%
def prepare(q):
    new_q = []
    surplus_q = []
    numbers_q = []
    new_rare = True
    for w in q.split()[::-1]:
        if w in top_words:
            new_q = [w] + new_q
            new_rare = True
        elif w not in STOP_WORDS:
            if new_rare:
                new_q = ["rare"] + new_q
                new_rare = False
            if is_numeric(w):
                numbers_q = [w] + numbers_q
            else:
                surplus_q = [w] + surplus_q
        else:
            new_rare = True
        if len(new_q) == MAX_SEQUENCE_LENGTH:
            break
    new_q = " ".join(new_q)
    return new_q, set(surplus_q), set(numbers_q)

# %%
def extract_features(df):
    q1s = np.array([""] * len(df), dtype=object)
    q2s = np.array([""] * len(df), dtype=object)
    features = np.zeros((len(df), 4))

    for i, (q1, q2) in enumerate(list(zip(df["question1"], df["question2"]))):
        q1s[i], surplus1, numbers1 = prepare(q1)
        q2s[i], surplus2, numbers2 = prepare(q2)
        features[i, 0] = len(surplus1.intersection(surplus2))
        features[i, 1] = len(surplus1.union(surplus2))
        features[i, 2] = len(numbers1.intersection(numbers2))
        features[i, 3] = len(numbers1.union(numbers2))

    return q1s, q2s, features

# %%
train = pd.read_csv("data/train.csv")
test = pd.read_csv("data/test.csv")

# %%
train["question1"] = train["question1"].fillna("").apply(preprocess)
train["question2"] = train["question2"].fillna("").apply(preprocess)

# %%
print("Creating the vocabulary of words occurred more than", MIN_WORD_OCCURRENCE)
all_questions = pd.Series(train["question1"].tolist() + train["question2"].tolist()).unique()
vectorizer = CountVectorizer(lowercase=False, token_pattern="\S+", min_df=MIN_WORD_OCCURRENCE)
vectorizer.fit(all_questions)
top_words = set(vectorizer.vocabulary_.keys())
top_words.add(REPLACE_WORD)
# Out:
# Creating the vocabulary of words occurred more than 100

# %%
embeddings_index = get_embedding()
print("Words are not found in the embedding:", top_words - embeddings_index.keys())
top_words = embeddings_index.keys()
# Out:
# Words are not found in the embedding: {'quorans', '\\frac', 'c#', 'kvpy', 'oneplus', 'brexit', '\\sqrt', 'demonetisation', 'iisc', 'redmi', 'paytm'}

# %%
print("Train questions are being prepared for LSTM...")
q1s_train, q2s_train, train_q_features = extract_features(train)
# Out:
# Train questions are being prepared for LSTM...

# %%
tokenizer = Tokenizer(filters="")
tokenizer.fit_on_texts(np.append(q1s_train, q2s_train))
word_index = tokenizer.word_index

# %%
data_1 = pad_sequences(tokenizer.texts_to_sequences(q1s_train), maxlen=MAX_SEQUENCE_LENGTH)
data_2 = pad_sequences(tokenizer.texts_to_sequences(q2s_train), maxlen=MAX_SEQUENCE_LENGTH)
labels = np.array(train["is_duplicate"])

# %%
nb_words = len(word_index) + 1
embedding_matrix = np.zeros((nb_words, EMBEDDING_DIM))

# %%
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %%
#print("Train features are being merged with NLP and Non-NLP features...")
#train_nlp_features = pd.read_csv("data/nlp_features_train.csv")
#train_non_nlp_features = pd.read_csv("data/non_nlp_features_train.csv")
#features_train = np.hstack((train_q_features, train_nlp_features, train_non_nlp_features))
# Out:
# Train features are being merged with NLP and Non-NLP features...

# %%
print("Same steps are being applied for test...")
test["question1"] = test["question1"].fillna("").apply(preprocess)
test["question2"] = test["question2"].fillna("").apply(preprocess)

q1s_test, q2s_test, test_q_features = extract_features(test)

test_data_1 = pad_sequences(tokenizer.texts_to_sequences(q1s_test), maxlen=MAX_SEQUENCE_LENGTH)
test_data_2 = pad_sequences(tokenizer.texts_to_sequences(q2s_test), maxlen=MAX_SEQUENCE_LENGTH)

#test_nlp_features = pd.read_csv("data/nlp_features_test.csv")
#test_non_nlp_features = pd.read_csv("data/non_nlp_features_test.csv")
#features_test = np.hstack((test_q_features, test_nlp_features, test_non_nlp_features))
# Out:
# Same steps are being applied for test...

# %%
stratified_kf = StratifiedKFold(n_splits=NUM_FOLDS, shuffle=True)
model_count = 0

# %%
for idx_train, idx_val in stratified_kf.split(train["is_duplicate"], train["is_duplicate"]):
    print("MODEL:", model_count)
    data_1_train = data_1[idx_train]
    data_2_train = data_2[idx_train]
    labels_train = labels[idx_train]
    #f_train = features_train[idx_train]

    data_1_val = data_1[idx_val]
    data_2_val = data_2[idx_val]
    labels_val = labels[idx_val]
    #f_val = features_train[idx_val]

    embedding_layer = Embedding(nb_words,
                                EMBEDDING_DIM,
                                weights=[embedding_matrix],
                                input_length=MAX_SEQUENCE_LENGTH,
                                trainable=False)
    lstm_layer = Sequential()
    # Adding Embedding layer
    lstm_layer.add(embedding_layer)          

    # Adding 2 Lstm layers
    lstm_layer.add(LSTM(32, return_sequences=True))
    lstm_layer.add(Dropout(0.2))

    lstm_layer.add(LSTM(64, return_sequences=False))
    lstm_layer.add(Dropout(0.2))


    # Adding Dense layer
    lstm_layer.add(Dense(128,activation="linear"))
    lstm_layer.add(Dropout(0.3))

    sequence_1_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype="int32")
    x1 = lstm_layer(sequence_1_input)

    sequence_2_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype="int32")
    y1 = lstm_layer(sequence_2_input)

    #features_input = Input(shape=(f_train.shape[1],), dtype="float32")
    #features_dense = BatchNormalization()(features_input)
    #features_dense = Dense(200, activation="relu")(features_dense)
    #features_dense = Dropout(0.2)(features_dense)

    lamda_function=Lambda(lambda tensor:K.abs(tensor[0]-tensor[1]),name="Absolute_distance")
    abs_distance_vector=lamda_function([x1,y1])

    lamda_function2=Lambda(lambda tensor:K.abs(tensor[0]*tensor[1]),name="Hamadard_multiplication") #abs() returns absolute value
    hamadard_vector=lamda_function2([x1,y1])

    merged = add([abs_distance_vector, hamadard_vector])

    out = Dense(1, activation="sigmoid")(merged)

    model = Model(inputs=[sequence_1_input, sequence_2_input], outputs=out)
    model.compile(loss="binary_crossentropy", optimizer="adam", metrics=['accuracy'])
    plot_model(model, to_file='nn_plot/simpleLSTM.png', show_shapes=True, expand_nested=True)

    early_stopping = EarlyStopping(monitor="val_loss", patience=5)
    best_model_path = "models/simpletest1/best_model" + str(model_count) + ".h5"
    model_checkpoint = ModelCheckpoint(best_model_path, save_best_only=True, save_weights_only=True)

    model_history = model.fit([data_1_train, data_2_train], labels_train, 
                     batch_size=BATCH_SIZE, epochs=25, shuffle=True,
                     validation_data=([data_1_val, data_2_val], labels_val),
                     callbacks=[early_stopping, model_checkpoint], verbose=1)

    model.load_weights(best_model_path)
    print(model_count, "validation loss:", min(model_history.history["val_loss"]))
    print(model_count, "validation accuracy:", max(model_history.history["val_accuracy"]))
    # Accuracy Graph
    fig = plt.figure(dpi = 100)
    plt.title("Accuracy")
    plt.plot(model_history.history["accuracy"], color = "g", label = "Train")
    plt.plot(model_history.history["val_accuracy"], color = "b", label = "Test")
    plt.legend(loc = "best")
    plt.savefig("graphs/simpletest1/accuracyLSTM" + str(model_count) + ".png")
    # Loss Graph
    fig = plt.figure(dpi = 100)
    plt.title("Loss")
    plt.plot(model_history.history["loss"], color = "g", label = "Train")
    plt.plot(model_history.history["val_loss"], color = "b", label = "Test")
    plt.legend(loc = "best")
    plt.savefig("graphs/simpletest1/lossLSTM" + str(model_count) + ".png")
    preds = model.predict([test_data_1, test_data_2], batch_size=BATCH_SIZE, verbose=1)

    submission = pd.DataFrame({"test_id": test["test_id"], "is_duplicate": preds.ravel()})
    submission.to_csv("predictions/simpletest1/preds" + str(model_count) + ".csv", index=False)

    model_count += 1
# Out:
# MODEL: 0
# Epoch 1/25
# 1422/1422 [==============================] - 70s 41ms/step - loss: 0.5395 - accuracy: 0.7252 - val_loss: 0.5047 - val_accuracy: 0.7484
# Epoch 2/25
# 1422/1422 [==============================] - 56s 39ms/step - loss: 0.4940 - accuracy: 0.7570 - val_loss: 0.4765 - val_accuracy: 0.7663
# Epoch 3/25
# 1422/1422 [==============================] - 56s 39ms/step - loss: 0.4737 - accuracy: 0.7698 - val_loss: 0.4566 - val_accuracy: 0.7830
# Epoch 4/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.4608 - accuracy: 0.7781 - val_loss: 0.4464 - val_accuracy: 0.7880
# Epoch 5/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.4509 - accuracy: 0.7838 - val_loss: 0.4435 - val_accuracy: 0.7916
# Epoch 6/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.4432 - accuracy: 0.7883 - val_loss: 0.4408 - val_accuracy: 0.7905
# Epoch 7/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.4364 - accuracy: 0.7926 - val_loss: 0.4364 - val_accuracy: 0.7923
# Epoch 8/25
# 1422/1422 [==============================] - 55s 38ms/step - loss: 0.4304 - accuracy: 0.7964 - val_loss: 0.4336 - val_accuracy: 0.7944
# Epoch 9/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.4256 - accuracy: 0.7985 - val_loss: 0.4366 - val_accuracy: 0.7946
# Epoch 10/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.4202 - accuracy: 0.8021 - val_loss: 0.4313 - val_accuracy: 0.7955
# Epoch 11/25
# 1422/1422 [==============================] - 53s 37ms/step - loss: 0.4150 - accuracy: 0.8046 - val_loss: 0.4309 - val_accuracy: 0.7942
# Epoch 12/25
# 1422/1422 [==============================] - 53s 37ms/step - loss: 0.4116 - accuracy: 0.8065 - val_loss: 0.4252 - val_accuracy: 0.7968
# Epoch 13/25
# 1422/1422 [==============================] - 52s 37ms/step - loss: 0.4084 - accuracy: 0.8086 - val_loss: 0.4284 - val_accuracy: 0.7954
# Epoch 14/25
# 1422/1422 [==============================] - 53s 37ms/step - loss: 0.4041 - accuracy: 0.8113 - val_loss: 0.4249 - val_accuracy: 0.7990
# Epoch 15/25
# 1422/1422 [==============================] - 52s 36ms/step - loss: 0.4010 - accuracy: 0.8126 - val_loss: 0.4273 - val_accuracy: 0.7962
# Epoch 16/25
# 1422/1422 [==============================] - 52s 36ms/step - loss: 0.3981 - accuracy: 0.8144 - val_loss: 0.4261 - val_accuracy: 0.7992
# Epoch 17/25
# 1422/1422 [==============================] - 52s 37ms/step - loss: 0.3953 - accuracy: 0.8161 - val_loss: 0.4239 - val_accuracy: 0.8009
# Epoch 18/25
# 1422/1422 [==============================] - 52s 37ms/step - loss: 0.3921 - accuracy: 0.8178 - val_loss: 0.4321 - val_accuracy: 0.7928
# Epoch 19/25
# 1422/1422 [==============================] - 52s 37ms/step - loss: 0.3898 - accuracy: 0.8190 - val_loss: 0.4256 - val_accuracy: 0.7958
# Epoch 20/25
# 1422/1422 [==============================] - 52s 37ms/step - loss: 0.3867 - accuracy: 0.8210 - val_loss: 0.4276 - val_accuracy: 0.7971
# Epoch 21/25
# 1422/1422 [==============================] - 52s 36ms/step - loss: 0.3859 - accuracy: 0.8211 - val_loss: 0.4312 - val_accuracy: 0.7927
# Epoch 22/25
# 1422/1422 [==============================] - 53s 37ms/step - loss: 0.3822 - accuracy: 0.8228 - val_loss: 0.4234 - val_accuracy: 0.7994
# Epoch 23/25
# 1422/1422 [==============================] - 52s 36ms/step - loss: 0.3789 - accuracy: 0.8248 - val_loss: 0.4276 - val_accuracy: 0.7970
# Epoch 24/25
# 1422/1422 [==============================] - 52s 36ms/step - loss: 0.3777 - accuracy: 0.8257 - val_loss: 0.4303 - val_accuracy: 0.7945
# Epoch 25/25
# 1422/1422 [==============================] - 52s 37ms/step - loss: 0.3757 - accuracy: 0.8273 - val_loss: 0.4303 - val_accuracy: 0.7950
# 0 validation loss: 0.4233500361442566
# 0 validation accuracy: 0.8009349703788757
# 9164/9164 [==============================] - 86s 9ms/step
# MODEL: 1
# Epoch 1/25
# 1422/1422 [==============================] - 67s 41ms/step - loss: 0.5401 - accuracy: 0.7252 - val_loss: 0.5096 - val_accuracy: 0.7452
# Epoch 2/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.4947 - accuracy: 0.7566 - val_loss: 0.4859 - val_accuracy: 0.7624
# Epoch 3/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.4753 - accuracy: 0.7695 - val_loss: 0.4822 - val_accuracy: 0.7628
# Epoch 4/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.4619 - accuracy: 0.7767 - val_loss: 0.4645 - val_accuracy: 0.7762
# Epoch 5/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.4518 - accuracy: 0.7834 - val_loss: 0.4593 - val_accuracy: 0.7794
# Epoch 6/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.4436 - accuracy: 0.7887 - val_loss: 0.4452 - val_accuracy: 0.7890
# Epoch 7/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.4365 - accuracy: 0.7927 - val_loss: 0.4479 - val_accuracy: 0.7861
# Epoch 8/25
# 1422/1422 [==============================] - 53s 37ms/step - loss: 0.4310 - accuracy: 0.7952 - val_loss: 0.4410 - val_accuracy: 0.7927
# Epoch 9/25
# 1422/1422 [==============================] - 53s 37ms/step - loss: 0.4252 - accuracy: 0.7989 - val_loss: 0.4391 - val_accuracy: 0.7922
# Epoch 10/25
# 1422/1422 [==============================] - 52s 36ms/step - loss: 0.4203 - accuracy: 0.8016 - val_loss: 0.4367 - val_accuracy: 0.7951
# Epoch 11/25
# 1422/1422 [==============================] - 51s 36ms/step - loss: 0.4161 - accuracy: 0.8036 - val_loss: 0.4299 - val_accuracy: 0.7975
# Epoch 12/25
# 1422/1422 [==============================] - 51s 36ms/step - loss: 0.4115 - accuracy: 0.8062 - val_loss: 0.4265 - val_accuracy: 0.7994
# Epoch 13/25
# 1422/1422 [==============================] - 50s 35ms/step - loss: 0.4084 - accuracy: 0.8088 - val_loss: 0.4338 - val_accuracy: 0.7950
# Epoch 14/25
# 1422/1422 [==============================] - 50s 35ms/step - loss: 0.4043 - accuracy: 0.8110 - val_loss: 0.4328 - val_accuracy: 0.7940
# Epoch 15/25
# 1422/1422 [==============================] - 50s 35ms/step - loss: 0.4006 - accuracy: 0.8128 - val_loss: 0.4314 - val_accuracy: 0.7943
# Epoch 16/25
# 1422/1422 [==============================] - 50s 35ms/step - loss: 0.3986 - accuracy: 0.8142 - val_loss: 0.4360 - val_accuracy: 0.7911
# Epoch 17/25
# 1422/1422 [==============================] - 50s 35ms/step - loss: 0.3958 - accuracy: 0.8162 - val_loss: 0.4315 - val_accuracy: 0.7927
# 1 validation loss: 0.42646098136901855
# 1 validation accuracy: 0.7994014024734497
# 9164/9164 [==============================] - 87s 9ms/step
# MODEL: 2
# Epoch 1/25
# 1422/1422 [==============================] - 67s 42ms/step - loss: 0.5379 - accuracy: 0.7257 - val_loss: 0.4973 - val_accuracy: 0.7570
# Epoch 2/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.4928 - accuracy: 0.7579 - val_loss: 0.4779 - val_accuracy: 0.7665
# Epoch 3/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.4727 - accuracy: 0.7710 - val_loss: 0.4624 - val_accuracy: 0.7775
# Epoch 4/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.4595 - accuracy: 0.7789 - val_loss: 0.4597 - val_accuracy: 0.7789
# Epoch 5/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.4499 - accuracy: 0.7840 - val_loss: 0.4437 - val_accuracy: 0.7901
# Epoch 6/25
# 1422/1422 [==============================] - 53s 38ms/step - loss: 0.4418 - accuracy: 0.7889 - val_loss: 0.4436 - val_accuracy: 0.7900
# Epoch 7/25
# 1422/1422 [==============================] - 53s 37ms/step - loss: 0.4342 - accuracy: 0.7930 - val_loss: 0.4378 - val_accuracy: 0.7925
# Epoch 8/25
# 1422/1422 [==============================] - 52s 37ms/step - loss: 0.4299 - accuracy: 0.7961 - val_loss: 0.4363 - val_accuracy: 0.7937
# Epoch 9/25
# 1422/1422 [==============================] - 51s 36ms/step - loss: 0.4234 - accuracy: 0.7993 - val_loss: 0.4394 - val_accuracy: 0.7912
# Epoch 10/25
# 1422/1422 [==============================] - 51s 36ms/step - loss: 0.4191 - accuracy: 0.8022 - val_loss: 0.4316 - val_accuracy: 0.7954
# Epoch 11/25
# 1422/1422 [==============================] - 51s 36ms/step - loss: 0.4140 - accuracy: 0.8050 - val_loss: 0.4358 - val_accuracy: 0.7900
# Epoch 12/25
# 1422/1422 [==============================] - 51s 36ms/step - loss: 0.4104 - accuracy: 0.8073 - val_loss: 0.4368 - val_accuracy: 0.7933
# Epoch 13/25
# 1422/1422 [==============================] - 50s 35ms/step - loss: 0.4072 - accuracy: 0.8096 - val_loss: 0.4328 - val_accuracy: 0.7942
# Epoch 14/25
# 1422/1422 [==============================] - 50s 35ms/step - loss: 0.4034 - accuracy: 0.8114 - val_loss: 0.4341 - val_accuracy: 0.7919
# Epoch 15/25
# 1422/1422 [==============================] - 51s 36ms/step - loss: 0.3997 - accuracy: 0.8135 - val_loss: 0.4339 - val_accuracy: 0.7930
# 2 validation loss: 0.43158867955207825
# 2 validation accuracy: 0.7954438924789429
# 9164/9164 [==============================] - 88s 9ms/step
# MODEL: 3
# Epoch 1/25
# 1422/1422 [==============================] - 66s 41ms/step - loss: 0.5391 - accuracy: 0.7250 - val_loss: 0.5082 - val_accuracy: 0.7443
# Epoch 2/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.4940 - accuracy: 0.7575 - val_loss: 0.4820 - val_accuracy: 0.7626
# Epoch 3/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.4735 - accuracy: 0.7701 - val_loss: 0.4575 - val_accuracy: 0.7817
# Epoch 4/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.4596 - accuracy: 0.7786 - val_loss: 0.4606 - val_accuracy: 0.7800
# Epoch 5/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.4501 - accuracy: 0.7841 - val_loss: 0.4516 - val_accuracy: 0.7850
# Epoch 6/25
# 1422/1422 [==============================] - 53s 38ms/step - loss: 0.4417 - accuracy: 0.7887 - val_loss: 0.4400 - val_accuracy: 0.7948
# Epoch 7/25
# 1422/1422 [==============================] - 53s 37ms/step - loss: 0.4345 - accuracy: 0.7922 - val_loss: 0.4434 - val_accuracy: 0.7899
# Epoch 8/25
# 1422/1422 [==============================] - 53s 37ms/step - loss: 0.4290 - accuracy: 0.7967 - val_loss: 0.4337 - val_accuracy: 0.7957
# Epoch 9/25
# 1422/1422 [==============================] - 53s 37ms/step - loss: 0.4235 - accuracy: 0.7998 - val_loss: 0.4337 - val_accuracy: 0.7958
# Epoch 10/25
# 1422/1422 [==============================] - 53s 37ms/step - loss: 0.4181 - accuracy: 0.8030 - val_loss: 0.4303 - val_accuracy: 0.7976
# Epoch 11/25
# 1422/1422 [==============================] - 52s 37ms/step - loss: 0.4143 - accuracy: 0.8049 - val_loss: 0.4275 - val_accuracy: 0.7970
# Epoch 12/25
# 1422/1422 [==============================] - 52s 36ms/step - loss: 0.4107 - accuracy: 0.8069 - val_loss: 0.4264 - val_accuracy: 0.8008
# Epoch 13/25
# 1422/1422 [==============================] - 52s 36ms/step - loss: 0.4057 - accuracy: 0.8101 - val_loss: 0.4271 - val_accuracy: 0.7980
# Epoch 14/25
# 1422/1422 [==============================] - 52s 36ms/step - loss: 0.4028 - accuracy: 0.8115 - val_loss: 0.4289 - val_accuracy: 0.7952
# Epoch 15/25
# 1422/1422 [==============================] - 52s 37ms/step - loss: 0.3994 - accuracy: 0.8134 - val_loss: 0.4255 - val_accuracy: 0.7987
# Epoch 16/25
# 1422/1422 [==============================] - 52s 37ms/step - loss: 0.3958 - accuracy: 0.8147 - val_loss: 0.4226 - val_accuracy: 0.8016
# Epoch 17/25
# 1422/1422 [==============================] - 52s 36ms/step - loss: 0.3931 - accuracy: 0.8165 - val_loss: 0.4266 - val_accuracy: 0.7992
# Epoch 18/25
# 1422/1422 [==============================] - 51s 36ms/step - loss: 0.3899 - accuracy: 0.8193 - val_loss: 0.4284 - val_accuracy: 0.7972
# Epoch 19/25
# 1422/1422 [==============================] - 52s 36ms/step - loss: 0.3883 - accuracy: 0.8195 - val_loss: 0.4272 - val_accuracy: 0.7981
# Epoch 20/25
# 1422/1422 [==============================] - 51s 36ms/step - loss: 0.3858 - accuracy: 0.8206 - val_loss: 0.4213 - val_accuracy: 0.8030
# Epoch 21/25
# 1422/1422 [==============================] - 51s 36ms/step - loss: 0.3829 - accuracy: 0.8224 - val_loss: 0.4302 - val_accuracy: 0.7962
# Epoch 22/25
# 1422/1422 [==============================] - 50s 36ms/step - loss: 0.3808 - accuracy: 0.8240 - val_loss: 0.4312 - val_accuracy: 0.7941
# Epoch 23/25
# 1422/1422 [==============================] - 50s 35ms/step - loss: 0.3784 - accuracy: 0.8245 - val_loss: 0.4283 - val_accuracy: 0.7973
# Epoch 24/25
# 1422/1422 [==============================] - 50s 35ms/step - loss: 0.3769 - accuracy: 0.8262 - val_loss: 0.4270 - val_accuracy: 0.7968
# Epoch 25/25
# 1422/1422 [==============================] - 50s 35ms/step - loss: 0.3738 - accuracy: 0.8275 - val_loss: 0.4296 - val_accuracy: 0.7983
# 3 validation loss: 0.4212641716003418
# 3 validation accuracy: 0.8029879331588745
# 9164/9164 [==============================] - 89s 10ms/step
# MODEL: 4
# Epoch 1/25
# 1422/1422 [==============================] - 67s 42ms/step - loss: 0.5401 - accuracy: 0.7251 - val_loss: 0.5265 - val_accuracy: 0.7125
# Epoch 2/25
# 1422/1422 [==============================] - 56s 39ms/step - loss: 0.4959 - accuracy: 0.7575 - val_loss: 0.4922 - val_accuracy: 0.7494
# Epoch 3/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.4757 - accuracy: 0.7694 - val_loss: 0.4642 - val_accuracy: 0.7818
# Epoch 4/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.4619 - accuracy: 0.7775 - val_loss: 0.4696 - val_accuracy: 0.7719
# Epoch 5/25
# 1422/1422 [==============================] - 53s 37ms/step - loss: 0.4513 - accuracy: 0.7840 - val_loss: 0.4496 - val_accuracy: 0.7912
# Epoch 6/25
# 1422/1422 [==============================] - 53s 37ms/step - loss: 0.4434 - accuracy: 0.7887 - val_loss: 0.4495 - val_accuracy: 0.7911
# Epoch 7/25
# 1422/1422 [==============================] - 53s 38ms/step - loss: 0.4364 - accuracy: 0.7933 - val_loss: 0.4357 - val_accuracy: 0.7977
# Epoch 8/25
# 1422/1422 [==============================] - 52s 37ms/step - loss: 0.4312 - accuracy: 0.7954 - val_loss: 0.4378 - val_accuracy: 0.7954
# Epoch 9/25
# 1422/1422 [==============================] - 53s 37ms/step - loss: 0.4256 - accuracy: 0.7985 - val_loss: 0.4377 - val_accuracy: 0.7940
# Epoch 10/25
# 1422/1422 [==============================] - 53s 37ms/step - loss: 0.4199 - accuracy: 0.8019 - val_loss: 0.4305 - val_accuracy: 0.7972
# Epoch 11/25
# 1422/1422 [==============================] - 53s 37ms/step - loss: 0.4155 - accuracy: 0.8041 - val_loss: 0.4265 - val_accuracy: 0.8004
# Epoch 12/25
# 1422/1422 [==============================] - 52s 37ms/step - loss: 0.4120 - accuracy: 0.8067 - val_loss: 0.4239 - val_accuracy: 0.7988
# Epoch 13/25
# 1422/1422 [==============================] - 52s 37ms/step - loss: 0.4085 - accuracy: 0.8080 - val_loss: 0.4201 - val_accuracy: 0.8032
# Epoch 14/25
# 1422/1422 [==============================] - 52s 37ms/step - loss: 0.4048 - accuracy: 0.8108 - val_loss: 0.4241 - val_accuracy: 0.7982
# Epoch 15/25
# 1422/1422 [==============================] - 52s 37ms/step - loss: 0.4020 - accuracy: 0.8118 - val_loss: 0.4262 - val_accuracy: 0.7989
# Epoch 16/25
# 1422/1422 [==============================] - 52s 37ms/step - loss: 0.3983 - accuracy: 0.8141 - val_loss: 0.4219 - val_accuracy: 0.8003
# Epoch 17/25
# 1422/1422 [==============================] - 52s 37ms/step - loss: 0.3953 - accuracy: 0.8159 - val_loss: 0.4239 - val_accuracy: 0.7990
# Epoch 18/25
# 1422/1422 [==============================] - 52s 37ms/step - loss: 0.3927 - accuracy: 0.8179 - val_loss: 0.4215 - val_accuracy: 0.7997
# 4 validation loss: 0.42011797428131104
# 4 validation accuracy: 0.803161084651947
# 9164/9164 [==============================] - 88s 9ms/step
# MODEL: 5
# Epoch 1/25
# 1422/1422 [==============================] - 68s 42ms/step - loss: 0.5394 - accuracy: 0.7245 - val_loss: 0.5089 - val_accuracy: 0.7414
# Epoch 2/25
# 1422/1422 [==============================] - 57s 40ms/step - loss: 0.4933 - accuracy: 0.7577 - val_loss: 0.4951 - val_accuracy: 0.7493
# Epoch 3/25
# 1422/1422 [==============================] - 56s 40ms/step - loss: 0.4728 - accuracy: 0.7698 - val_loss: 0.4836 - val_accuracy: 0.7626
# Epoch 4/25
# 1422/1422 [==============================] - 56s 39ms/step - loss: 0.4601 - accuracy: 0.7774 - val_loss: 0.4576 - val_accuracy: 0.7825
# Epoch 5/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.4504 - accuracy: 0.7835 - val_loss: 0.4530 - val_accuracy: 0.7860
# Epoch 6/25
# 1422/1422 [==============================] - 53s 38ms/step - loss: 0.4425 - accuracy: 0.7885 - val_loss: 0.4538 - val_accuracy: 0.7830
# Epoch 7/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.4346 - accuracy: 0.7932 - val_loss: 0.4481 - val_accuracy: 0.7880
# Epoch 8/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.4287 - accuracy: 0.7962 - val_loss: 0.4450 - val_accuracy: 0.7898
# Epoch 9/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.4236 - accuracy: 0.8001 - val_loss: 0.4400 - val_accuracy: 0.7939
# Epoch 10/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.4197 - accuracy: 0.8024 - val_loss: 0.4391 - val_accuracy: 0.7930
# Epoch 11/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.4147 - accuracy: 0.8047 - val_loss: 0.4365 - val_accuracy: 0.7925
# Epoch 12/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.4112 - accuracy: 0.8071 - val_loss: 0.4372 - val_accuracy: 0.7897
# Epoch 13/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.4074 - accuracy: 0.8094 - val_loss: 0.4350 - val_accuracy: 0.7918
# Epoch 14/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.4031 - accuracy: 0.8116 - val_loss: 0.4334 - val_accuracy: 0.7940
# Epoch 15/25
# 1422/1422 [==============================] - 53s 38ms/step - loss: 0.4006 - accuracy: 0.8132 - val_loss: 0.4384 - val_accuracy: 0.7907
# Epoch 16/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.3971 - accuracy: 0.8143 - val_loss: 0.4317 - val_accuracy: 0.7953
# Epoch 17/25
# 1422/1422 [==============================] - 53s 38ms/step - loss: 0.3952 - accuracy: 0.8161 - val_loss: 0.4355 - val_accuracy: 0.7902
# Epoch 18/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.3928 - accuracy: 0.8174 - val_loss: 0.4319 - val_accuracy: 0.7929
# Epoch 19/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.3893 - accuracy: 0.8193 - val_loss: 0.4371 - val_accuracy: 0.7897
# Epoch 20/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.3869 - accuracy: 0.8200 - val_loss: 0.4421 - val_accuracy: 0.7859
# Epoch 21/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.3845 - accuracy: 0.8220 - val_loss: 0.4341 - val_accuracy: 0.7948
# 5 validation loss: 0.4317045509815216
# 5 validation accuracy: 0.7952707409858704
# 9164/9164 [==============================] - 96s 10ms/step
# MODEL: 6
# Epoch 1/25
# 1422/1422 [==============================] - 69s 42ms/step - loss: 0.5395 - accuracy: 0.7239 - val_loss: 0.4995 - val_accuracy: 0.7519
# Epoch 2/25
# 1422/1422 [==============================] - 57s 40ms/step - loss: 0.4924 - accuracy: 0.7578 - val_loss: 0.4839 - val_accuracy: 0.7586
# Epoch 3/25
# 1422/1422 [==============================] - 56s 39ms/step - loss: 0.4726 - accuracy: 0.7709 - val_loss: 0.4620 - val_accuracy: 0.7788
# Epoch 4/25
# 1422/1422 [==============================] - 56s 39ms/step - loss: 0.4602 - accuracy: 0.7780 - val_loss: 0.4577 - val_accuracy: 0.7821
# Epoch 5/25
# 1422/1422 [==============================] - 56s 39ms/step - loss: 0.4497 - accuracy: 0.7846 - val_loss: 0.4420 - val_accuracy: 0.7916
# Epoch 6/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.4413 - accuracy: 0.7896 - val_loss: 0.4398 - val_accuracy: 0.7962
# Epoch 7/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.4346 - accuracy: 0.7930 - val_loss: 0.4381 - val_accuracy: 0.7903
# Epoch 8/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.4287 - accuracy: 0.7972 - val_loss: 0.4344 - val_accuracy: 0.7965
# Epoch 9/25
# 1422/1422 [==============================] - 53s 37ms/step - loss: 0.4244 - accuracy: 0.8000 - val_loss: 0.4414 - val_accuracy: 0.7909
# Epoch 10/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.4196 - accuracy: 0.8016 - val_loss: 0.4304 - val_accuracy: 0.7970
# Epoch 11/25
# 1422/1422 [==============================] - 53s 37ms/step - loss: 0.4145 - accuracy: 0.8049 - val_loss: 0.4338 - val_accuracy: 0.7947
# Epoch 12/25
# 1422/1422 [==============================] - 51s 36ms/step - loss: 0.4106 - accuracy: 0.8076 - val_loss: 0.4325 - val_accuracy: 0.7940
# Epoch 13/25
# 1422/1422 [==============================] - 52s 37ms/step - loss: 0.4073 - accuracy: 0.8090 - val_loss: 0.4229 - val_accuracy: 0.7996
# Epoch 14/25
# 1422/1422 [==============================] - 52s 36ms/step - loss: 0.4033 - accuracy: 0.8113 - val_loss: 0.4340 - val_accuracy: 0.7914
# Epoch 15/25
# 1422/1422 [==============================] - 51s 36ms/step - loss: 0.4005 - accuracy: 0.8131 - val_loss: 0.4273 - val_accuracy: 0.7969
# Epoch 16/25
# 1422/1422 [==============================] - 51s 36ms/step - loss: 0.3977 - accuracy: 0.8149 - val_loss: 0.4237 - val_accuracy: 0.8000
# Epoch 17/25
# 1422/1422 [==============================] - 51s 36ms/step - loss: 0.3950 - accuracy: 0.8162 - val_loss: 0.4332 - val_accuracy: 0.7914
# Epoch 18/25
# 1422/1422 [==============================] - 52s 36ms/step - loss: 0.3914 - accuracy: 0.8182 - val_loss: 0.4365 - val_accuracy: 0.7880
# 6 validation loss: 0.42289674282073975
# 6 validation accuracy: 0.7999950647354126
# 9164/9164 [==============================] - 94s 10ms/step
# MODEL: 7
# Epoch 1/25
# 1422/1422 [==============================] - 69s 43ms/step - loss: 0.5356 - accuracy: 0.7275 - val_loss: 0.5213 - val_accuracy: 0.7224
# Epoch 2/25
# 1422/1422 [==============================] - 59s 42ms/step - loss: 0.4902 - accuracy: 0.7593 - val_loss: 0.4737 - val_accuracy: 0.7730
# Epoch 3/25
# 1422/1422 [==============================] - 58s 41ms/step - loss: 0.4711 - accuracy: 0.7716 - val_loss: 0.4678 - val_accuracy: 0.7762
# Epoch 4/25
# 1422/1422 [==============================] - 58s 41ms/step - loss: 0.4586 - accuracy: 0.7791 - val_loss: 0.4575 - val_accuracy: 0.7829
# Epoch 5/25
# 1422/1422 [==============================] - 57s 40ms/step - loss: 0.4494 - accuracy: 0.7843 - val_loss: 0.4530 - val_accuracy: 0.7863
# Epoch 6/25
# 1422/1422 [==============================] - 57s 40ms/step - loss: 0.4413 - accuracy: 0.7892 - val_loss: 0.4439 - val_accuracy: 0.7896
# Epoch 7/25
# 1422/1422 [==============================] - 56s 40ms/step - loss: 0.4349 - accuracy: 0.7930 - val_loss: 0.4419 - val_accuracy: 0.7919
# Epoch 8/25
# 1422/1422 [==============================] - 56s 39ms/step - loss: 0.4291 - accuracy: 0.7962 - val_loss: 0.4428 - val_accuracy: 0.7868
# Epoch 9/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.4241 - accuracy: 0.8003 - val_loss: 0.4366 - val_accuracy: 0.7909
# Epoch 10/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.4192 - accuracy: 0.8018 - val_loss: 0.4389 - val_accuracy: 0.7895
# Epoch 11/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.4149 - accuracy: 0.8052 - val_loss: 0.4393 - val_accuracy: 0.7879
# Epoch 12/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.4109 - accuracy: 0.8073 - val_loss: 0.4346 - val_accuracy: 0.7896
# Epoch 13/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.4072 - accuracy: 0.8090 - val_loss: 0.4363 - val_accuracy: 0.7890
# Epoch 14/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.4034 - accuracy: 0.8124 - val_loss: 0.4415 - val_accuracy: 0.7856
# Epoch 15/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.4004 - accuracy: 0.8130 - val_loss: 0.4341 - val_accuracy: 0.7917
# Epoch 16/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.3970 - accuracy: 0.8158 - val_loss: 0.4337 - val_accuracy: 0.7929
# Epoch 17/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.3937 - accuracy: 0.8174 - val_loss: 0.4337 - val_accuracy: 0.7918
# Epoch 18/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.3918 - accuracy: 0.8183 - val_loss: 0.4425 - val_accuracy: 0.7839
# Epoch 19/25
# 1422/1422 [==============================] - 53s 38ms/step - loss: 0.3887 - accuracy: 0.8197 - val_loss: 0.4395 - val_accuracy: 0.7870
# Epoch 20/25
# 1422/1422 [==============================] - 53s 37ms/step - loss: 0.3865 - accuracy: 0.8211 - val_loss: 0.4340 - val_accuracy: 0.7920
# Epoch 21/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.3833 - accuracy: 0.8228 - val_loss: 0.4424 - val_accuracy: 0.7867
# 7 validation loss: 0.4336998462677002
# 7 validation accuracy: 0.7929209470748901
# 9164/9164 [==============================] - 89s 9ms/step
# MODEL: 8
# Epoch 1/25
# 1422/1422 [==============================] - 67s 42ms/step - loss: 0.5419 - accuracy: 0.7242 - val_loss: 0.5163 - val_accuracy: 0.7298
# Epoch 2/25
# 1422/1422 [==============================] - 56s 39ms/step - loss: 0.4935 - accuracy: 0.7583 - val_loss: 0.4840 - val_accuracy: 0.7647
# Epoch 3/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.4745 - accuracy: 0.7701 - val_loss: 0.4665 - val_accuracy: 0.7782
# Epoch 4/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.4619 - accuracy: 0.7773 - val_loss: 0.4675 - val_accuracy: 0.7756
# Epoch 5/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.4512 - accuracy: 0.7837 - val_loss: 0.4548 - val_accuracy: 0.7847
# Epoch 6/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.4435 - accuracy: 0.7886 - val_loss: 0.4434 - val_accuracy: 0.7933
# Epoch 7/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.4361 - accuracy: 0.7927 - val_loss: 0.4381 - val_accuracy: 0.7932
# Epoch 8/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.4302 - accuracy: 0.7966 - val_loss: 0.4423 - val_accuracy: 0.7926
# Epoch 9/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.4249 - accuracy: 0.7995 - val_loss: 0.4346 - val_accuracy: 0.7955
# Epoch 10/25
# 1422/1422 [==============================] - 53s 38ms/step - loss: 0.4205 - accuracy: 0.8018 - val_loss: 0.4359 - val_accuracy: 0.7936
# Epoch 11/25
# 1422/1422 [==============================] - 52s 37ms/step - loss: 0.4151 - accuracy: 0.8052 - val_loss: 0.4277 - val_accuracy: 0.7982
# Epoch 12/25
# 1422/1422 [==============================] - 52s 36ms/step - loss: 0.4106 - accuracy: 0.8073 - val_loss: 0.4230 - val_accuracy: 0.7986
# Epoch 13/25
# 1422/1422 [==============================] - 51s 36ms/step - loss: 0.4077 - accuracy: 0.8095 - val_loss: 0.4278 - val_accuracy: 0.7973
# Epoch 14/25
# 1422/1422 [==============================] - 51s 36ms/step - loss: 0.4037 - accuracy: 0.8118 - val_loss: 0.4291 - val_accuracy: 0.7950
# Epoch 15/25
# 1422/1422 [==============================] - 51s 36ms/step - loss: 0.4012 - accuracy: 0.8131 - val_loss: 0.4230 - val_accuracy: 0.7993
# Epoch 16/25
# 1422/1422 [==============================] - 51s 36ms/step - loss: 0.3975 - accuracy: 0.8149 - val_loss: 0.4241 - val_accuracy: 0.7982
# Epoch 17/25
# 1422/1422 [==============================] - 51s 36ms/step - loss: 0.3943 - accuracy: 0.8171 - val_loss: 0.4207 - val_accuracy: 0.7989
# Epoch 18/25
# 1422/1422 [==============================] - 51s 36ms/step - loss: 0.3913 - accuracy: 0.8181 - val_loss: 0.4273 - val_accuracy: 0.7956
# Epoch 19/25
# 1422/1422 [==============================] - 51s 36ms/step - loss: 0.3894 - accuracy: 0.8194 - val_loss: 0.4227 - val_accuracy: 0.7983
# Epoch 20/25
# 1422/1422 [==============================] - 51s 36ms/step - loss: 0.3861 - accuracy: 0.8215 - val_loss: 0.4385 - val_accuracy: 0.7861
# Epoch 21/25
# 1422/1422 [==============================] - 51s 36ms/step - loss: 0.3839 - accuracy: 0.8224 - val_loss: 0.4343 - val_accuracy: 0.7914
# Epoch 22/25
# 1422/1422 [==============================] - 51s 36ms/step - loss: 0.3812 - accuracy: 0.8238 - val_loss: 0.4282 - val_accuracy: 0.7950
# 8 validation loss: 0.42066776752471924
# 8 validation accuracy: 0.7993024587631226
# 9164/9164 [==============================] - 88s 9ms/step
# MODEL: 9
# Epoch 1/25
# 1422/1422 [==============================] - 67s 41ms/step - loss: 0.5386 - accuracy: 0.7259 - val_loss: 0.5219 - val_accuracy: 0.7273
# Epoch 2/25
# 1422/1422 [==============================] - 56s 39ms/step - loss: 0.4936 - accuracy: 0.7577 - val_loss: 0.5017 - val_accuracy: 0.7405
# Epoch 3/25
# 1422/1422 [==============================] - 55s 38ms/step - loss: 0.4745 - accuracy: 0.7692 - val_loss: 0.4912 - val_accuracy: 0.7528
# Epoch 4/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.4615 - accuracy: 0.7770 - val_loss: 0.4711 - val_accuracy: 0.7697
# Epoch 5/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.4522 - accuracy: 0.7833 - val_loss: 0.4547 - val_accuracy: 0.7822
# Epoch 6/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.4439 - accuracy: 0.7877 - val_loss: 0.4596 - val_accuracy: 0.7820
# Epoch 7/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.4370 - accuracy: 0.7920 - val_loss: 0.4492 - val_accuracy: 0.7864
# Epoch 8/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.4312 - accuracy: 0.7959 - val_loss: 0.4380 - val_accuracy: 0.7943
# Epoch 9/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.4256 - accuracy: 0.7987 - val_loss: 0.4396 - val_accuracy: 0.7935
# Epoch 10/25
# 1422/1422 [==============================] - 53s 38ms/step - loss: 0.4211 - accuracy: 0.8025 - val_loss: 0.4390 - val_accuracy: 0.7928
# Epoch 11/25
# 1422/1422 [==============================] - 53s 37ms/step - loss: 0.4170 - accuracy: 0.8036 - val_loss: 0.4390 - val_accuracy: 0.7939
# Epoch 12/25
# 1422/1422 [==============================] - 53s 37ms/step - loss: 0.4121 - accuracy: 0.8076 - val_loss: 0.4334 - val_accuracy: 0.7969
# Epoch 13/25
# 1422/1422 [==============================] - 53s 37ms/step - loss: 0.4085 - accuracy: 0.8093 - val_loss: 0.4375 - val_accuracy: 0.7933
# Epoch 14/25
# 1422/1422 [==============================] - 52s 37ms/step - loss: 0.4047 - accuracy: 0.8110 - val_loss: 0.4366 - val_accuracy: 0.7941
# Epoch 15/25
# 1422/1422 [==============================] - 52s 37ms/step - loss: 0.4016 - accuracy: 0.8121 - val_loss: 0.4294 - val_accuracy: 0.7978
# Epoch 16/25
# 1422/1422 [==============================] - 52s 37ms/step - loss: 0.3990 - accuracy: 0.8141 - val_loss: 0.4378 - val_accuracy: 0.7923
# Epoch 17/25
# 1422/1422 [==============================] - 52s 37ms/step - loss: 0.3952 - accuracy: 0.8164 - val_loss: 0.4274 - val_accuracy: 0.7985
# Epoch 18/25
# 1422/1422 [==============================] - 52s 37ms/step - loss: 0.3930 - accuracy: 0.8178 - val_loss: 0.4357 - val_accuracy: 0.7929
# Epoch 19/25
# 1422/1422 [==============================] - 52s 37ms/step - loss: 0.3904 - accuracy: 0.8190 - val_loss: 0.4375 - val_accuracy: 0.7956
# Epoch 20/25
# 1422/1422 [==============================] - 52s 37ms/step - loss: 0.3881 - accuracy: 0.8206 - val_loss: 0.4351 - val_accuracy: 0.7965
# Epoch 21/25
# 1422/1422 [==============================] - 52s 37ms/step - loss: 0.3845 - accuracy: 0.8216 - val_loss: 0.4336 - val_accuracy: 0.7949
# Epoch 22/25
# 1422/1422 [==============================] - 52s 37ms/step - loss: 0.3833 - accuracy: 0.8228 - val_loss: 0.4374 - val_accuracy: 0.7930
# 9 validation loss: 0.42740336060523987
# 9 validation accuracy: 0.7985357046127319
# 9164/9164 [==============================] - 90s 10ms/step
