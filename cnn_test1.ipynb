# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/quora_duplicate_questions_detection/
# Out:
# /content/drive/.shortcut-targets-by-id/1NfDfMFFEa6jbcf5EQ_tVWbvhytT96tlt/quora_duplicate_questions_detection

# %%
# !ls
# Out:
#  bert			       lstm_test1.ipynb
#  bilstm_nn_test1.ipynb	       model.png
#  bilstm_nn_test2.ipynb	       models
#  classifier.py		       models4.ipynb
#  cnn_test1.ipynb	       models5.ipynb
# 'Copy of deep_nn.ipynb'        model_tfidf.ipynb
# 'Copy of nlp_features.ipynb'   nlp_features.ipynb
#  data			       nn_plot
#  deep_nn.ipynb		       non_nlp_features.ipynb
#  deep_nn_test1.ipynb	       predictions
#  deep_nn_test2.ipynb	       __pycache__
#  deep_nn_test3.ipynb	       tfidf_model.ipynb
#  feature_engineering.ipynb     Untitled.ipynb
#  graphs			       utils.py
#  __init__.py		       word2vec_features.ipynb

# %%
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import StratifiedKFold
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Dense, Input, LSTM, Embedding, Dropout
from keras.layers import MaxPool1D,Conv1D,Flatten,Activation,Lambda
from keras.layers.core import Lambda
from keras.layers.merge import concatenate, add, multiply
from keras.models import Model, Sequential
from keras.layers import BatchNormalization
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers.noise import GaussianNoise
from keras import backend as K
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
np.random.seed(0)
WNL = WordNetLemmatizer()
STOP_WORDS = set(stopwords.words('english'))
MAX_SEQUENCE_LENGTH = 30
MIN_WORD_OCCURRENCE = 100
REPLACE_WORD = "rare"
EMBEDDING_DIM = 300
NUM_FOLDS = 10
BATCH_SIZE = 512
EMBEDDING_FILE = "data/glove.840B.300d.txt"

# %%
def cutter(word):
    if len(word) < 4:
        return word
    return WNL.lemmatize(WNL.lemmatize(word, "n"), "v")

# %%
def preprocess(string):
    string = string.lower().replace(",000,000", "m").replace(",000", "k").replace("′", "'").replace("’", "'") \
        .replace("won't", "will not").replace("cannot", "can not").replace("can't", "can not") \
        .replace("n't", " not").replace("what's", "what is").replace("it's", "it is") \
        .replace("'ve", " have").replace("i'm", "i am").replace("'re", " are") \
        .replace("he's", "he is").replace("she's", "she is").replace("'s", " own") \
        .replace("%", " percent ").replace("₹", " rupee ").replace("$", " dollar ") \
        .replace("€", " euro ").replace("'ll", " will").replace("=", " equal ").replace("+", " plus ")
    string = re.sub('[“”\(\'…\)\!\^\"\.;:,\-\?？\{\}\[\]\\/\*@]', ' ', string)
    string = re.sub(r"([0-9]+)000000", r"\1m", string)
    string = re.sub(r"([0-9]+)000", r"\1k", string)
    string = ' '.join([cutter(w) for w in string.split()])
    return string

# %%
def get_embedding():
    embeddings_index = {}
    f = open(EMBEDDING_FILE, encoding="utf8")
    for line in f:
        values = line.split()
        word = values[0]
        if len(values) == EMBEDDING_DIM + 1 and word in top_words:
            coefs = np.asarray(values[1:], dtype="float32")
            embeddings_index[word] = coefs
    f.close()
    return embeddings_index

# %%
def is_numeric(s):
    return any(i.isdigit() for i in s)

# %%
def prepare(q):
    new_q = []
    surplus_q = []
    numbers_q = []
    new_rare = True
    for w in q.split()[::-1]:
        if w in top_words:
            new_q = [w] + new_q
            new_rare = True
        elif w not in STOP_WORDS:
            if new_rare:
                new_q = ["rare"] + new_q
                new_rare = False
            if is_numeric(w):
                numbers_q = [w] + numbers_q
            else:
                surplus_q = [w] + surplus_q
        else:
            new_rare = True
        if len(new_q) == MAX_SEQUENCE_LENGTH:
            break
    new_q = " ".join(new_q)
    return new_q, set(surplus_q), set(numbers_q)

# %%
def extract_features(df):
    q1s = np.array([""] * len(df), dtype=object)
    q2s = np.array([""] * len(df), dtype=object)
    features = np.zeros((len(df), 4))

    for i, (q1, q2) in enumerate(list(zip(df["question1"], df["question2"]))):
        q1s[i], surplus1, numbers1 = prepare(q1)
        q2s[i], surplus2, numbers2 = prepare(q2)
        features[i, 0] = len(surplus1.intersection(surplus2))
        features[i, 1] = len(surplus1.union(surplus2))
        features[i, 2] = len(numbers1.intersection(numbers2))
        features[i, 3] = len(numbers1.union(numbers2))

    return q1s, q2s, features

# %%
train = pd.read_csv("data/train.csv")
test = pd.read_csv("data/test.csv")

# %%
train["question1"] = train["question1"].fillna("").apply(preprocess)
train["question2"] = train["question2"].fillna("").apply(preprocess)

# %%
print("Creating the vocabulary of words occurred more than", MIN_WORD_OCCURRENCE)
all_questions = pd.Series(train["question1"].tolist() + train["question2"].tolist()).unique()
vectorizer = CountVectorizer(lowercase=False, token_pattern="\S+", min_df=MIN_WORD_OCCURRENCE)
vectorizer.fit(all_questions)
top_words = set(vectorizer.vocabulary_.keys())
top_words.add(REPLACE_WORD)
# Out:
# Creating the vocabulary of words occurred more than 100

# %%
embeddings_index = get_embedding()
print("Words are not found in the embedding:", top_words - embeddings_index.keys())
top_words = embeddings_index.keys()
# Out:
# Words are not found in the embedding: {'redmi', 'brexit', '\\sqrt', 'iisc', 'quorans', '\\frac', 'demonetisation', 'c#', 'kvpy', 'paytm', 'oneplus'}

# %%
print("Train questions are being prepared for LSTM...")
q1s_train, q2s_train, train_q_features = extract_features(train)
# Out:
# Train questions are being prepared for LSTM...

# %%
tokenizer = Tokenizer(filters="")
tokenizer.fit_on_texts(np.append(q1s_train, q2s_train))
word_index = tokenizer.word_index

# %%
data_1 = pad_sequences(tokenizer.texts_to_sequences(q1s_train), maxlen=MAX_SEQUENCE_LENGTH)
data_2 = pad_sequences(tokenizer.texts_to_sequences(q2s_train), maxlen=MAX_SEQUENCE_LENGTH)
labels = np.array(train["is_duplicate"])

# %%
nb_words = len(word_index) + 1
embedding_matrix = np.zeros((nb_words, EMBEDDING_DIM))

# %%
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %%
print("Train features are being merged with NLP and Non-NLP features...")
train_nlp_features = pd.read_csv("data/nlp_features_train.csv")
train_non_nlp_features = pd.read_csv("data/non_nlp_features_train.csv")
features_train = np.hstack((train_q_features, train_nlp_features, train_non_nlp_features))
# Out:
# Train features are being merged with NLP and Non-NLP features...

# %%
print("Same steps are being applied for test...")
test["question1"] = test["question1"].fillna("").apply(preprocess)
test["question2"] = test["question2"].fillna("").apply(preprocess)

q1s_test, q2s_test, test_q_features = extract_features(test)

test_data_1 = pad_sequences(tokenizer.texts_to_sequences(q1s_test), maxlen=MAX_SEQUENCE_LENGTH)
test_data_2 = pad_sequences(tokenizer.texts_to_sequences(q2s_test), maxlen=MAX_SEQUENCE_LENGTH)

test_nlp_features = pd.read_csv("data/nlp_features_test.csv")
test_non_nlp_features = pd.read_csv("data/non_nlp_features_test.csv")
features_test = np.hstack((test_q_features, test_nlp_features, test_non_nlp_features))
# Out:
# Same steps are being applied for test...

# %%
stratified_kf = StratifiedKFold(n_splits=NUM_FOLDS, shuffle=True)
model_count = 0

# %%
for idx_train, idx_val in stratified_kf.split(train["is_duplicate"], train["is_duplicate"]):
    print("MODEL:", model_count)
    data_1_train = data_1[idx_train]
    data_2_train = data_2[idx_train]
    labels_train = labels[idx_train]
    #f_train = features_train[idx_train]

    data_1_val = data_1[idx_val]
    data_2_val = data_2[idx_val]
    labels_val = labels[idx_val]
    #f_val = features_train[idx_val]

    embedding_layer = Embedding(nb_words,
                                EMBEDDING_DIM,
                                weights=[embedding_matrix],
                                input_length=MAX_SEQUENCE_LENGTH,
                                trainable=False)
    CNN4_network=Sequential([embedding_layer,
                        Conv1D(32,3,activation="relu",padding='same'),
                       Dropout(0.2),
                       MaxPool1D(2),
                       Conv1D(64,5,activation="relu",padding='same'),
                       Dropout(0.2),
                       MaxPool1D(2),
                       Conv1D(64,5,activation="relu",padding='same'),
                       Dropout(0.2),
                       MaxPool1D(2),
                       Conv1D(32,3,activation="relu",padding='same'),
                       Dropout(0.2),
                       MaxPool1D(2),
                       Flatten(),
                       Dense(128,activation="linear"),
                       Dropout(0.3)
                       ])

    sequence_1_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype="int32")
    x1 = CNN4_network(sequence_1_input)

    sequence_2_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype="int32")
    y1 = CNN4_network(sequence_2_input)

    #features_input = Input(shape=(f_train.shape[1],), dtype="float32")
    #features_dense = BatchNormalization()(features_input)
    #features_dense = Dense(200, activation="relu")(features_dense)
    #features_dense = Dropout(0.2)(features_dense)

    lamda_function=Lambda(lambda tensor:K.abs(tensor[0]-tensor[1]),name="Absolute_distance")
    abs_distance_vector=lamda_function([x1,y1])

    lamda_function2=Lambda(lambda tensor:K.abs(tensor[0]*tensor[1]),name="Hamadard_multiplication") #abs() returns absolute value
    hamadard_vector=lamda_function2([x1,y1])

    merged = add([abs_distance_vector, hamadard_vector])

    out = Dense(1, activation="sigmoid")(merged)

    model = Model(inputs=[sequence_1_input, sequence_2_input], outputs=out)
    model.compile(loss="binary_crossentropy", optimizer="adam", metrics=['accuracy'])
    plot_model(model, to_file='nn_plot/cnn.png', show_shapes=True, expand_nested=True)

    early_stopping = EarlyStopping(monitor="val_loss", patience=5)
    best_model_path = "models/cnn/best_model" + str(model_count) + ".h5"
    model_checkpoint = ModelCheckpoint(best_model_path, save_best_only=True, save_weights_only=True)

    model_history = model.fit([data_1_train, data_2_train], labels_train, 
                     batch_size=BATCH_SIZE, epochs=25, shuffle=True,
                     validation_data=([data_1_val, data_2_val], labels_val),
                     callbacks=[early_stopping, model_checkpoint], verbose=1)

    model.load_weights(best_model_path)
    print(model_count, "validation loss:", min(model_history.history["val_loss"]))
    print(model_count, "validation accuracy:", max(model_history.history["val_accuracy"]))
    # Accuracy Graph
    fig = plt.figure(dpi = 100)
    plt.title("Accuracy")
    plt.plot(model_history.history["accuracy"], color = "g", label = "Train")
    plt.plot(model_history.history["val_accuracy"], color = "b", label = "Test")
    plt.legend(loc = "best")
    plt.savefig("graphs/simpletest1/cnn" + str(model_count) + ".png")
    # Loss Graph
    fig = plt.figure(dpi = 100)
    plt.title("Loss")
    plt.plot(model_history.history["loss"], color = "g", label = "Train")
    plt.plot(model_history.history["val_loss"], color = "b", label = "Test")
    plt.legend(loc = "best")
    plt.savefig("graphs/simpletest1/lossCNN" + str(model_count) + ".png")
    preds = model.predict([test_data_1, test_data_2], batch_size=BATCH_SIZE, verbose=1)

    submission = pd.DataFrame({"test_id": test["test_id"], "is_duplicate": preds.ravel()})
    submission.to_csv("predictions/cnn/preds" + str(model_count) + ".csv", index=False)

    model_count += 1
# Out:
# MODEL: 0
# Epoch 1/25
# 711/711 [==============================] - 22s 28ms/step - loss: 0.5537 - accuracy: 0.7153 - val_loss: 0.5755 - val_accuracy: 0.7338
# Epoch 2/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.5138 - accuracy: 0.7465 - val_loss: 0.5514 - val_accuracy: 0.7491
# Epoch 3/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4988 - accuracy: 0.7563 - val_loss: 0.5333 - val_accuracy: 0.7496
# Epoch 4/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4897 - accuracy: 0.7618 - val_loss: 0.5255 - val_accuracy: 0.7653
# Epoch 5/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4816 - accuracy: 0.7674 - val_loss: 0.5208 - val_accuracy: 0.7689
# Epoch 6/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4757 - accuracy: 0.7705 - val_loss: 0.5087 - val_accuracy: 0.7683
# Epoch 7/25
# 711/711 [==============================] - 19s 27ms/step - loss: 0.4714 - accuracy: 0.7731 - val_loss: 0.5099 - val_accuracy: 0.7722
# Epoch 8/25
# 711/711 [==============================] - 20s 29ms/step - loss: 0.4671 - accuracy: 0.7762 - val_loss: 0.5034 - val_accuracy: 0.7704
# Epoch 9/25
# 711/711 [==============================] - 20s 27ms/step - loss: 0.4635 - accuracy: 0.7787 - val_loss: 0.5047 - val_accuracy: 0.7719
# Epoch 10/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4607 - accuracy: 0.7798 - val_loss: 0.4976 - val_accuracy: 0.7779
# Epoch 11/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4573 - accuracy: 0.7821 - val_loss: 0.4941 - val_accuracy: 0.7783
# Epoch 12/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4547 - accuracy: 0.7830 - val_loss: 0.4932 - val_accuracy: 0.7791
# Epoch 13/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4528 - accuracy: 0.7840 - val_loss: 0.4937 - val_accuracy: 0.7762
# Epoch 14/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4509 - accuracy: 0.7858 - val_loss: 0.4886 - val_accuracy: 0.7817
# Epoch 15/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4473 - accuracy: 0.7882 - val_loss: 0.4904 - val_accuracy: 0.7766
# Epoch 16/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4461 - accuracy: 0.7885 - val_loss: 0.4868 - val_accuracy: 0.7793
# Epoch 17/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4442 - accuracy: 0.7895 - val_loss: 0.4868 - val_accuracy: 0.7786
# Epoch 18/25
# 711/711 [==============================] - 20s 27ms/step - loss: 0.4422 - accuracy: 0.7911 - val_loss: 0.4901 - val_accuracy: 0.7789
# Epoch 19/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4402 - accuracy: 0.7915 - val_loss: 0.4775 - val_accuracy: 0.7826
# Epoch 20/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4390 - accuracy: 0.7928 - val_loss: 0.4842 - val_accuracy: 0.7814
# Epoch 21/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4373 - accuracy: 0.7939 - val_loss: 0.4906 - val_accuracy: 0.7755
# Epoch 22/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4366 - accuracy: 0.7940 - val_loss: 0.4867 - val_accuracy: 0.7740
# Epoch 23/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4347 - accuracy: 0.7948 - val_loss: 0.5010 - val_accuracy: 0.7624
# Epoch 24/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4340 - accuracy: 0.7951 - val_loss: 0.4865 - val_accuracy: 0.7733
# 0 validation loss: 0.477508008480072
# 0 validation accuracy: 0.7826312780380249
# 4582/4582 [==============================] - 32s 7ms/step
# MODEL: 1
# Epoch 1/25
# 711/711 [==============================] - 22s 28ms/step - loss: 0.5521 - accuracy: 0.7157 - val_loss: 0.5730 - val_accuracy: 0.7441
# Epoch 2/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.5125 - accuracy: 0.7485 - val_loss: 0.5453 - val_accuracy: 0.7482
# Epoch 3/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4978 - accuracy: 0.7578 - val_loss: 0.5349 - val_accuracy: 0.7525
# Epoch 4/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4886 - accuracy: 0.7637 - val_loss: 0.5219 - val_accuracy: 0.7630
# Epoch 5/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4815 - accuracy: 0.7677 - val_loss: 0.5174 - val_accuracy: 0.7636
# Epoch 6/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4758 - accuracy: 0.7713 - val_loss: 0.5167 - val_accuracy: 0.7635
# Epoch 7/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4713 - accuracy: 0.7740 - val_loss: 0.5134 - val_accuracy: 0.7689
# Epoch 8/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4668 - accuracy: 0.7768 - val_loss: 0.5090 - val_accuracy: 0.7704
# Epoch 9/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4631 - accuracy: 0.7789 - val_loss: 0.4985 - val_accuracy: 0.7709
# Epoch 10/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4597 - accuracy: 0.7808 - val_loss: 0.5076 - val_accuracy: 0.7657
# Epoch 11/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4563 - accuracy: 0.7827 - val_loss: 0.5034 - val_accuracy: 0.7665
# Epoch 12/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4534 - accuracy: 0.7843 - val_loss: 0.5065 - val_accuracy: 0.7626
# Epoch 13/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4505 - accuracy: 0.7860 - val_loss: 0.4970 - val_accuracy: 0.7697
# Epoch 14/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4479 - accuracy: 0.7870 - val_loss: 0.4972 - val_accuracy: 0.7659
# Epoch 15/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4457 - accuracy: 0.7887 - val_loss: 0.5025 - val_accuracy: 0.7592
# Epoch 16/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4440 - accuracy: 0.7899 - val_loss: 0.4998 - val_accuracy: 0.7582
# Epoch 17/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4422 - accuracy: 0.7915 - val_loss: 0.5008 - val_accuracy: 0.7615
# Epoch 18/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4407 - accuracy: 0.7920 - val_loss: 0.5039 - val_accuracy: 0.7585
# 1 validation loss: 0.4970313012599945
# 1 validation accuracy: 0.7709317803382874
# 4582/4582 [==============================] - 32s 7ms/step
# MODEL: 2
# Epoch 1/25
# 711/711 [==============================] - 22s 28ms/step - loss: 0.5542 - accuracy: 0.7144 - val_loss: 0.5856 - val_accuracy: 0.7286
# Epoch 2/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.5133 - accuracy: 0.7479 - val_loss: 0.5565 - val_accuracy: 0.7467
# Epoch 3/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4973 - accuracy: 0.7579 - val_loss: 0.5391 - val_accuracy: 0.7602
# Epoch 4/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4879 - accuracy: 0.7632 - val_loss: 0.5406 - val_accuracy: 0.7528
# Epoch 5/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4808 - accuracy: 0.7679 - val_loss: 0.5327 - val_accuracy: 0.7661
# Epoch 6/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4740 - accuracy: 0.7717 - val_loss: 0.5219 - val_accuracy: 0.7702
# Epoch 7/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4691 - accuracy: 0.7749 - val_loss: 0.5061 - val_accuracy: 0.7710
# Epoch 8/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4654 - accuracy: 0.7769 - val_loss: 0.5141 - val_accuracy: 0.7643
# Epoch 9/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4615 - accuracy: 0.7788 - val_loss: 0.5145 - val_accuracy: 0.7641
# Epoch 10/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4579 - accuracy: 0.7817 - val_loss: 0.5076 - val_accuracy: 0.7639
# Epoch 11/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4547 - accuracy: 0.7832 - val_loss: 0.5089 - val_accuracy: 0.7632
# Epoch 12/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4519 - accuracy: 0.7842 - val_loss: 0.5131 - val_accuracy: 0.7585
# 2 validation loss: 0.5061261653900146
# 2 validation accuracy: 0.7709812521934509
# 4582/4582 [==============================] - 32s 7ms/step
# MODEL: 3
# Epoch 1/25
# 711/711 [==============================] - 22s 29ms/step - loss: 0.5510 - accuracy: 0.7166 - val_loss: 0.5784 - val_accuracy: 0.7452
# Epoch 2/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.5113 - accuracy: 0.7475 - val_loss: 0.5511 - val_accuracy: 0.7556
# Epoch 3/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4975 - accuracy: 0.7567 - val_loss: 0.5293 - val_accuracy: 0.7622
# Epoch 4/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4875 - accuracy: 0.7631 - val_loss: 0.5221 - val_accuracy: 0.7604
# Epoch 5/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4803 - accuracy: 0.7676 - val_loss: 0.5198 - val_accuracy: 0.7632
# Epoch 6/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4751 - accuracy: 0.7703 - val_loss: 0.5109 - val_accuracy: 0.7629
# Epoch 7/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4705 - accuracy: 0.7736 - val_loss: 0.5161 - val_accuracy: 0.7604
# Epoch 8/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4663 - accuracy: 0.7768 - val_loss: 0.5063 - val_accuracy: 0.7696
# Epoch 9/25
# 711/711 [==============================] - 20s 29ms/step - loss: 0.4628 - accuracy: 0.7789 - val_loss: 0.5060 - val_accuracy: 0.7684
# Epoch 10/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4598 - accuracy: 0.7806 - val_loss: 0.5084 - val_accuracy: 0.7652
# Epoch 11/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4572 - accuracy: 0.7818 - val_loss: 0.4991 - val_accuracy: 0.7687
# Epoch 12/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4536 - accuracy: 0.7840 - val_loss: 0.5003 - val_accuracy: 0.7665
# Epoch 13/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4521 - accuracy: 0.7844 - val_loss: 0.4947 - val_accuracy: 0.7700
# Epoch 14/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4499 - accuracy: 0.7866 - val_loss: 0.4971 - val_accuracy: 0.7676
# Epoch 15/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4480 - accuracy: 0.7876 - val_loss: 0.4962 - val_accuracy: 0.7672
# Epoch 16/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4450 - accuracy: 0.7887 - val_loss: 0.5007 - val_accuracy: 0.7657
# Epoch 17/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4441 - accuracy: 0.7900 - val_loss: 0.4963 - val_accuracy: 0.7707
# Epoch 18/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4428 - accuracy: 0.7907 - val_loss: 0.4958 - val_accuracy: 0.7688
# 3 validation loss: 0.4946848452091217
# 3 validation accuracy: 0.7707338929176331
# 4582/4582 [==============================] - 32s 7ms/step
# MODEL: 4
# Epoch 1/25
# 711/711 [==============================] - 22s 29ms/step - loss: 0.5527 - accuracy: 0.7147 - val_loss: 0.5634 - val_accuracy: 0.7442
# Epoch 2/25
# 711/711 [==============================] - 20s 29ms/step - loss: 0.5130 - accuracy: 0.7464 - val_loss: 0.5533 - val_accuracy: 0.7546
# Epoch 3/25
# 711/711 [==============================] - 20s 29ms/step - loss: 0.4982 - accuracy: 0.7556 - val_loss: 0.5361 - val_accuracy: 0.7604
# Epoch 4/25
# 711/711 [==============================] - 20s 29ms/step - loss: 0.4873 - accuracy: 0.7621 - val_loss: 0.5236 - val_accuracy: 0.7573
# Epoch 5/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4806 - accuracy: 0.7668 - val_loss: 0.5163 - val_accuracy: 0.7675
# Epoch 6/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4739 - accuracy: 0.7705 - val_loss: 0.5028 - val_accuracy: 0.7718
# Epoch 7/25
# 711/711 [==============================] - 20s 29ms/step - loss: 0.4683 - accuracy: 0.7739 - val_loss: 0.4989 - val_accuracy: 0.7719
# Epoch 8/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4629 - accuracy: 0.7772 - val_loss: 0.4992 - val_accuracy: 0.7699
# Epoch 9/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4601 - accuracy: 0.7787 - val_loss: 0.5163 - val_accuracy: 0.7624
# Epoch 10/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4570 - accuracy: 0.7809 - val_loss: 0.4988 - val_accuracy: 0.7725
# Epoch 11/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4543 - accuracy: 0.7827 - val_loss: 0.5051 - val_accuracy: 0.7644
# Epoch 12/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4516 - accuracy: 0.7845 - val_loss: 0.4992 - val_accuracy: 0.7684
# Epoch 13/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4494 - accuracy: 0.7852 - val_loss: 0.5055 - val_accuracy: 0.7627
# Epoch 14/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4468 - accuracy: 0.7869 - val_loss: 0.5004 - val_accuracy: 0.7677
# Epoch 15/25
# 711/711 [==============================] - 20s 29ms/step - loss: 0.4451 - accuracy: 0.7878 - val_loss: 0.4977 - val_accuracy: 0.7663
# Epoch 16/25
# 711/711 [==============================] - 21s 29ms/step - loss: 0.4421 - accuracy: 0.7900 - val_loss: 0.4918 - val_accuracy: 0.7674
# Epoch 17/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4417 - accuracy: 0.7900 - val_loss: 0.5002 - val_accuracy: 0.7549
# Epoch 18/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4395 - accuracy: 0.7911 - val_loss: 0.5022 - val_accuracy: 0.7594
# Epoch 19/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4385 - accuracy: 0.7924 - val_loss: 0.4922 - val_accuracy: 0.7666
# Epoch 20/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4373 - accuracy: 0.7932 - val_loss: 0.5060 - val_accuracy: 0.7515
# Epoch 21/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4351 - accuracy: 0.7934 - val_loss: 0.5017 - val_accuracy: 0.7514
# 4 validation loss: 0.49176523089408875
# 4 validation accuracy: 0.772539496421814
# 4582/4582 [==============================] - 33s 7ms/step
# MODEL: 5
# Epoch 1/25
# 711/711 [==============================] - 22s 29ms/step - loss: 0.5508 - accuracy: 0.7167 - val_loss: 0.5694 - val_accuracy: 0.7448
# Epoch 2/25
# 711/711 [==============================] - 20s 29ms/step - loss: 0.5122 - accuracy: 0.7480 - val_loss: 0.5588 - val_accuracy: 0.7501
# Epoch 3/25
# 711/711 [==============================] - 20s 29ms/step - loss: 0.4982 - accuracy: 0.7576 - val_loss: 0.5495 - val_accuracy: 0.7603
# Epoch 4/25
# 711/711 [==============================] - 20s 29ms/step - loss: 0.4885 - accuracy: 0.7639 - val_loss: 0.5366 - val_accuracy: 0.7601
# Epoch 5/25
# 711/711 [==============================] - 20s 29ms/step - loss: 0.4810 - accuracy: 0.7677 - val_loss: 0.5246 - val_accuracy: 0.7671
# Epoch 6/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4755 - accuracy: 0.7709 - val_loss: 0.5288 - val_accuracy: 0.7677
# Epoch 7/25
# 711/711 [==============================] - 20s 29ms/step - loss: 0.4704 - accuracy: 0.7744 - val_loss: 0.5168 - val_accuracy: 0.7669
# Epoch 8/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4668 - accuracy: 0.7762 - val_loss: 0.5191 - val_accuracy: 0.7715
# Epoch 9/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4631 - accuracy: 0.7788 - val_loss: 0.5172 - val_accuracy: 0.7670
# Epoch 10/25
# 711/711 [==============================] - 20s 29ms/step - loss: 0.4596 - accuracy: 0.7802 - val_loss: 0.5067 - val_accuracy: 0.7719
# Epoch 11/25
# 711/711 [==============================] - 21s 29ms/step - loss: 0.4562 - accuracy: 0.7829 - val_loss: 0.5054 - val_accuracy: 0.7753
# Epoch 12/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4527 - accuracy: 0.7861 - val_loss: 0.5069 - val_accuracy: 0.7716
# Epoch 13/25
# 711/711 [==============================] - 20s 29ms/step - loss: 0.4501 - accuracy: 0.7870 - val_loss: 0.4996 - val_accuracy: 0.7736
# Epoch 14/25
# 711/711 [==============================] - 20s 29ms/step - loss: 0.4474 - accuracy: 0.7884 - val_loss: 0.4955 - val_accuracy: 0.7757
# Epoch 15/25
# 711/711 [==============================] - 20s 29ms/step - loss: 0.4458 - accuracy: 0.7894 - val_loss: 0.4915 - val_accuracy: 0.7724
# Epoch 16/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4436 - accuracy: 0.7903 - val_loss: 0.5009 - val_accuracy: 0.7676
# Epoch 17/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4412 - accuracy: 0.7917 - val_loss: 0.4918 - val_accuracy: 0.7763
# Epoch 18/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4399 - accuracy: 0.7923 - val_loss: 0.4938 - val_accuracy: 0.7713
# Epoch 19/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4384 - accuracy: 0.7936 - val_loss: 0.4965 - val_accuracy: 0.7715
# Epoch 20/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4372 - accuracy: 0.7935 - val_loss: 0.4972 - val_accuracy: 0.7629
# 5 validation loss: 0.49152812361717224
# 5 validation accuracy: 0.7762744426727295
# 4582/4582 [==============================] - 33s 7ms/step
# MODEL: 6
# Epoch 1/25
# 711/711 [==============================] - 23s 29ms/step - loss: 0.5512 - accuracy: 0.7160 - val_loss: 0.5716 - val_accuracy: 0.7422
# Epoch 2/25
# 711/711 [==============================] - 20s 29ms/step - loss: 0.5107 - accuracy: 0.7489 - val_loss: 0.5512 - val_accuracy: 0.7484
# Epoch 3/25
# 711/711 [==============================] - 20s 29ms/step - loss: 0.4948 - accuracy: 0.7594 - val_loss: 0.5357 - val_accuracy: 0.7547
# Epoch 4/25
# 711/711 [==============================] - 21s 29ms/step - loss: 0.4854 - accuracy: 0.7643 - val_loss: 0.5218 - val_accuracy: 0.7630
# Epoch 5/25
# 711/711 [==============================] - 21s 29ms/step - loss: 0.4783 - accuracy: 0.7698 - val_loss: 0.5154 - val_accuracy: 0.7631
# Epoch 6/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4720 - accuracy: 0.7732 - val_loss: 0.5176 - val_accuracy: 0.7596
# Epoch 7/25
# 711/711 [==============================] - 20s 29ms/step - loss: 0.4664 - accuracy: 0.7769 - val_loss: 0.5051 - val_accuracy: 0.7723
# Epoch 8/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4626 - accuracy: 0.7789 - val_loss: 0.5079 - val_accuracy: 0.7706
# Epoch 9/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4591 - accuracy: 0.7809 - val_loss: 0.5078 - val_accuracy: 0.7681
# Epoch 10/25
# 711/711 [==============================] - 21s 29ms/step - loss: 0.4558 - accuracy: 0.7835 - val_loss: 0.4986 - val_accuracy: 0.7766
# Epoch 11/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4524 - accuracy: 0.7862 - val_loss: 0.5083 - val_accuracy: 0.7664
# Epoch 12/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4497 - accuracy: 0.7870 - val_loss: 0.5028 - val_accuracy: 0.7660
# Epoch 13/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4479 - accuracy: 0.7877 - val_loss: 0.5024 - val_accuracy: 0.7666
# Epoch 14/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4456 - accuracy: 0.7888 - val_loss: 0.5003 - val_accuracy: 0.7668
# Epoch 15/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4438 - accuracy: 0.7903 - val_loss: 0.5049 - val_accuracy: 0.7626
# 6 validation loss: 0.49857160449028015
# 6 validation accuracy: 0.7766454815864563
# 4582/4582 [==============================] - 33s 7ms/step
# MODEL: 7
# Epoch 1/25
# 711/711 [==============================] - 23s 29ms/step - loss: 0.5532 - accuracy: 0.7133 - val_loss: 0.5671 - val_accuracy: 0.7480
# Epoch 2/25
# 711/711 [==============================] - 21s 29ms/step - loss: 0.5115 - accuracy: 0.7484 - val_loss: 0.5498 - val_accuracy: 0.7536
# Epoch 3/25
# 711/711 [==============================] - 21s 29ms/step - loss: 0.4972 - accuracy: 0.7583 - val_loss: 0.5342 - val_accuracy: 0.7565
# Epoch 4/25
# 711/711 [==============================] - 21s 29ms/step - loss: 0.4880 - accuracy: 0.7636 - val_loss: 0.5296 - val_accuracy: 0.7661
# Epoch 5/25
# 711/711 [==============================] - 21s 29ms/step - loss: 0.4807 - accuracy: 0.7682 - val_loss: 0.5294 - val_accuracy: 0.7633
# Epoch 6/25
# 711/711 [==============================] - 21s 29ms/step - loss: 0.4752 - accuracy: 0.7711 - val_loss: 0.5235 - val_accuracy: 0.7671
# Epoch 7/25
# 711/711 [==============================] - 21s 29ms/step - loss: 0.4695 - accuracy: 0.7746 - val_loss: 0.5198 - val_accuracy: 0.7680
# Epoch 8/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4657 - accuracy: 0.7772 - val_loss: 0.5230 - val_accuracy: 0.7639
# Epoch 9/25
# 711/711 [==============================] - 21s 29ms/step - loss: 0.4611 - accuracy: 0.7795 - val_loss: 0.5074 - val_accuracy: 0.7740
# Epoch 10/25
# 711/711 [==============================] - 21s 29ms/step - loss: 0.4580 - accuracy: 0.7819 - val_loss: 0.4949 - val_accuracy: 0.7764
# Epoch 11/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4555 - accuracy: 0.7831 - val_loss: 0.5018 - val_accuracy: 0.7754
# Epoch 12/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4523 - accuracy: 0.7852 - val_loss: 0.4987 - val_accuracy: 0.7747
# Epoch 13/25
# 711/711 [==============================] - 21s 29ms/step - loss: 0.4499 - accuracy: 0.7861 - val_loss: 0.4911 - val_accuracy: 0.7741
# Epoch 14/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4477 - accuracy: 0.7868 - val_loss: 0.4994 - val_accuracy: 0.7677
# Epoch 15/25
# 711/711 [==============================] - 20s 29ms/step - loss: 0.4454 - accuracy: 0.7890 - val_loss: 0.5032 - val_accuracy: 0.7680
# Epoch 16/25
# 711/711 [==============================] - 20s 29ms/step - loss: 0.4435 - accuracy: 0.7899 - val_loss: 0.4999 - val_accuracy: 0.7661
# Epoch 17/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4417 - accuracy: 0.7907 - val_loss: 0.4989 - val_accuracy: 0.7712
# Epoch 18/25
# 711/711 [==============================] - 20s 29ms/step - loss: 0.4407 - accuracy: 0.7915 - val_loss: 0.4952 - val_accuracy: 0.7690
# 7 validation loss: 0.4910871386528015
# 7 validation accuracy: 0.776447594165802
# 4582/4582 [==============================] - 33s 7ms/step
# MODEL: 8
# Epoch 1/25
# 711/711 [==============================] - 22s 29ms/step - loss: 0.5519 - accuracy: 0.7157 - val_loss: 0.5684 - val_accuracy: 0.7369
# Epoch 2/25
# 711/711 [==============================] - 21s 29ms/step - loss: 0.5122 - accuracy: 0.7486 - val_loss: 0.5508 - val_accuracy: 0.7554
# Epoch 3/25
# 711/711 [==============================] - 21s 29ms/step - loss: 0.4988 - accuracy: 0.7571 - val_loss: 0.5349 - val_accuracy: 0.7566
# Epoch 4/25
# 711/711 [==============================] - 20s 29ms/step - loss: 0.4885 - accuracy: 0.7641 - val_loss: 0.5376 - val_accuracy: 0.7481
# Epoch 5/25
# 711/711 [==============================] - 21s 29ms/step - loss: 0.4809 - accuracy: 0.7678 - val_loss: 0.5138 - val_accuracy: 0.7656
# Epoch 6/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4754 - accuracy: 0.7715 - val_loss: 0.5170 - val_accuracy: 0.7674
# Epoch 7/25
# 711/711 [==============================] - 21s 29ms/step - loss: 0.4702 - accuracy: 0.7746 - val_loss: 0.5134 - val_accuracy: 0.7698
# Epoch 8/25
# 711/711 [==============================] - 21s 29ms/step - loss: 0.4660 - accuracy: 0.7771 - val_loss: 0.4993 - val_accuracy: 0.7730
# Epoch 9/25
# 711/711 [==============================] - 20s 29ms/step - loss: 0.4621 - accuracy: 0.7798 - val_loss: 0.5058 - val_accuracy: 0.7709
# Epoch 10/25
# 711/711 [==============================] - 20s 29ms/step - loss: 0.4584 - accuracy: 0.7817 - val_loss: 0.5062 - val_accuracy: 0.7703
# Epoch 11/25
# 711/711 [==============================] - 21s 29ms/step - loss: 0.4549 - accuracy: 0.7842 - val_loss: 0.4971 - val_accuracy: 0.7718
# Epoch 12/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4533 - accuracy: 0.7851 - val_loss: 0.5020 - val_accuracy: 0.7702
# Epoch 13/25
# 711/711 [==============================] - 21s 29ms/step - loss: 0.4503 - accuracy: 0.7858 - val_loss: 0.4923 - val_accuracy: 0.7670
# Epoch 14/25
# 711/711 [==============================] - 20s 29ms/step - loss: 0.4481 - accuracy: 0.7869 - val_loss: 0.4992 - val_accuracy: 0.7681
# Epoch 15/25
# 711/711 [==============================] - 20s 28ms/step - loss: 0.4470 - accuracy: 0.7880 - val_loss: 0.4935 - val_accuracy: 0.7711
# Epoch 16/25
# 711/711 [==============================] - 20s 29ms/step - loss: 0.4440 - accuracy: 0.7896 - val_loss: 0.4989 - val_accuracy: 0.7644
# Epoch 17/25
# 711/711 [==============================] - 21s 29ms/step - loss: 0.4421 - accuracy: 0.7906 - val_loss: 0.4899 - val_accuracy: 0.7683
# Epoch 18/25
# 711/711 [==============================] - 20s 29ms/step - loss: 0.4404 - accuracy: 0.7921 - val_loss: 0.4949 - val_accuracy: 0.7629
# Epoch 19/25
# 711/711 [==============================] - 20s 29ms/step - loss: 0.4394 - accuracy: 0.7928 - val_loss: 0.4941 - val_accuracy: 0.7622
# Epoch 20/25
# 711/711 [==============================] - 20s 29ms/step - loss: 0.4378 - accuracy: 0.7934 - val_loss: 0.4994 - val_accuracy: 0.7580
# Epoch 21/25
# 711/711 [==============================] - 20s 29ms/step - loss: 0.4368 - accuracy: 0.7943 - val_loss: 0.4943 - val_accuracy: 0.7594
# Epoch 22/25
# 711/711 [==============================] - 20s 29ms/step - loss: 0.4359 - accuracy: 0.7943 - val_loss: 0.4901 - val_accuracy: 0.7609
# 8 validation loss: 0.4899323284626007
# 8 validation accuracy: 0.7730342149734497
# 4582/4582 [==============================] - 33s 7ms/step
# MODEL: 9
# Epoch 1/25
# 711/711 [==============================] - 23s 30ms/step - loss: 0.5534 - accuracy: 0.7150 - val_loss: 0.5721 - val_accuracy: 0.7401
# Epoch 2/25
# 711/711 [==============================] - 21s 29ms/step - loss: 0.5132 - accuracy: 0.7482 - val_loss: 0.5471 - val_accuracy: 0.7482
# Epoch 3/25
# 711/711 [==============================] - 21s 29ms/step - loss: 0.4991 - accuracy: 0.7572 - val_loss: 0.5331 - val_accuracy: 0.7474
# Epoch 4/25
# 711/711 [==============================] - 20s 29ms/step - loss: 0.4896 - accuracy: 0.7624 - val_loss: 0.5351 - val_accuracy: 0.7595
# Epoch 5/25
# 711/711 [==============================] - 21s 29ms/step - loss: 0.4812 - accuracy: 0.7687 - val_loss: 0.5331 - val_accuracy: 0.7553
# Epoch 6/25
# 711/711 [==============================] - 21s 29ms/step - loss: 0.4760 - accuracy: 0.7712 - val_loss: 0.5218 - val_accuracy: 0.7584
# Epoch 7/25
# 711/711 [==============================] - 21s 30ms/step - loss: 0.4708 - accuracy: 0.7746 - val_loss: 0.5084 - val_accuracy: 0.7646
# Epoch 8/25
# 711/711 [==============================] - 21s 30ms/step - loss: 0.4667 - accuracy: 0.7779 - val_loss: 0.5083 - val_accuracy: 0.7721
# Epoch 9/25
# 711/711 [==============================] - 20s 29ms/step - loss: 0.4627 - accuracy: 0.7798 - val_loss: 0.5120 - val_accuracy: 0.7673
# Epoch 10/25
# 711/711 [==============================] - 21s 29ms/step - loss: 0.4594 - accuracy: 0.7811 - val_loss: 0.5128 - val_accuracy: 0.7683
# Epoch 11/25
# 711/711 [==============================] - 21s 30ms/step - loss: 0.4555 - accuracy: 0.7837 - val_loss: 0.5079 - val_accuracy: 0.7697
# Epoch 12/25
# 711/711 [==============================] - 21s 29ms/step - loss: 0.4532 - accuracy: 0.7861 - val_loss: 0.5094 - val_accuracy: 0.7675
# Epoch 13/25
# 711/711 [==============================] - 21s 30ms/step - loss: 0.4507 - accuracy: 0.7867 - val_loss: 0.5026 - val_accuracy: 0.7709
# Epoch 14/25
# 711/711 [==============================] - 21s 29ms/step - loss: 0.4493 - accuracy: 0.7872 - val_loss: 0.5085 - val_accuracy: 0.7671
# Epoch 15/25
# 711/711 [==============================] - 21s 29ms/step - loss: 0.4481 - accuracy: 0.7882 - val_loss: 0.5016 - val_accuracy: 0.7721
# Epoch 16/25
# 711/711 [==============================] - 21s 30ms/step - loss: 0.4459 - accuracy: 0.7894 - val_loss: 0.4969 - val_accuracy: 0.7693
# Epoch 17/25
# 711/711 [==============================] - 21s 29ms/step - loss: 0.4443 - accuracy: 0.7903 - val_loss: 0.5005 - val_accuracy: 0.7625
# Epoch 18/25
# 711/711 [==============================] - 21s 29ms/step - loss: 0.4418 - accuracy: 0.7920 - val_loss: 0.4914 - val_accuracy: 0.7703
# Epoch 19/25
# 711/711 [==============================] - 21s 29ms/step - loss: 0.4401 - accuracy: 0.7923 - val_loss: 0.4982 - val_accuracy: 0.7626
# Epoch 20/25
# 711/711 [==============================] - 20s 29ms/step - loss: 0.4387 - accuracy: 0.7939 - val_loss: 0.4989 - val_accuracy: 0.7650
# Epoch 21/25
# 711/711 [==============================] - 21s 29ms/step - loss: 0.4370 - accuracy: 0.7954 - val_loss: 0.4997 - val_accuracy: 0.7660
# Epoch 22/25
# 711/711 [==============================] - 21s 29ms/step - loss: 0.4360 - accuracy: 0.7956 - val_loss: 0.5006 - val_accuracy: 0.7619
# Epoch 23/25
# 711/711 [==============================] - 21s 29ms/step - loss: 0.4357 - accuracy: 0.7957 - val_loss: 0.4941 - val_accuracy: 0.7627
# 9 validation loss: 0.49142125248908997
# 9 validation accuracy: 0.7721437811851501
# 4582/4582 [==============================] - 34s 7ms/step

# %%
'''With recurrent_dropout=0.2 get "not use cuDNN kernel" warning and time increases
to ~ 1 min per epoch & get following results for first fold:
validation loss: 0.20543508231639862
Wall time: 15min 58s - for complete run of 15 epochs & validation

with no recurrent_dropout cuDNN kernel is used ~ 9 seconds per epoch
validation loss: 0.20922143757343292
Wall time: 3min 10s'''
for idx_train, idx_val in stratified_kf.split(train["is_duplicate"], train["is_duplicate"]):
    print("MODEL:", model_count)
    data_1_train = data_1[idx_train]
    data_2_train = data_2[idx_train]
    labels_train = labels[idx_train]
    f_train = features_train[idx_train]

    data_1_val = data_1[idx_val]
    data_2_val = data_2[idx_val]
    labels_val = labels[idx_val]
    f_val = features_train[idx_val]

    embedding_layer = Embedding(nb_words,
                                EMBEDDING_DIM,
                                weights=[embedding_matrix],
                                input_length=MAX_SEQUENCE_LENGTH,
                                trainable=False)

    # lstm_layer = LSTM(75, recurrent_dropout=0.2)
    lstm_layer = LSTM(75)

    sequence_1_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype="int32")
    embedded_sequences_1 = embedding_layer(sequence_1_input)
    x1 = lstm_layer(embedded_sequences_1)

    sequence_2_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype="int32")
    embedded_sequences_2 = embedding_layer(sequence_2_input)
    y1 = lstm_layer(embedded_sequences_2)

    features_input = Input(shape=(f_train.shape[1],), dtype="float32")
    features_dense = BatchNormalization()(features_input)
    features_dense = Dense(200, activation="relu")(features_dense)
    features_dense = Dropout(0.2)(features_dense)

    addition = add([x1, y1])
    minus_y1 = Lambda(lambda x: -x)(y1)
    merged = add([x1, minus_y1])
    merged = multiply([merged, merged])
    merged = concatenate([merged, addition])
    merged = Dropout(0.4)(merged)

    merged = concatenate([merged, features_dense])
    merged = BatchNormalization()(merged)
    merged = GaussianNoise(0.1)(merged)

    merged = Dense(150, activation="relu")(merged)
    merged = Dropout(0.2)(merged)
    merged = BatchNormalization()(merged)

    out = Dense(1, activation="sigmoid")(merged)

    model = Model(inputs=[sequence_1_input, sequence_2_input, features_input], outputs=out)
    model.compile(loss="binary_crossentropy", optimizer="nadam", metrics=['accuracy'])
    early_stopping = EarlyStopping(monitor="val_loss", patience=5)
    best_model_path = "models/test1/best_model" + str(model_count) + ".h5"
    model_checkpoint = ModelCheckpoint(best_model_path, save_best_only=True, save_weights_only=True)

    model_history = model.fit([data_1_train, data_2_train, f_train], labels_train, 
                     batch_size=BATCH_SIZE, epochs=25, shuffle=True,
                     validation_data=([data_1_val, data_2_val, f_val], labels_val),
                     callbacks=[early_stopping, model_checkpoint], verbose=1)

    model.load_weights(best_model_path)
    print(model_count, "validation loss:", min(model_history.history["val_loss"]))

    preds = model.predict([test_data_1, test_data_2, features_test], batch_size=BATCH_SIZE, verbose=1)

    submission = pd.DataFrame({"test_id": test["test_id"], "is_duplicate": preds.ravel()})
    submission.to_csv("predictions/test1/preds" + str(model_count) + ".csv", index=False)

    model_count += 1
# Out:
# MODEL: 0
# Epoch 1/25
# 1422/1422 [==============================] - 45s 28ms/step - loss: 0.2728 - accuracy: 0.8719 - val_loss: 0.2362 - val_accuracy: 0.8898
# Epoch 2/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.2396 - accuracy: 0.8911 - val_loss: 0.2208 - val_accuracy: 0.9014
# Epoch 3/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.2270 - accuracy: 0.8977 - val_loss: 0.2132 - val_accuracy: 0.9054
# Epoch 4/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.2183 - accuracy: 0.9023 - val_loss: 0.2115 - val_accuracy: 0.9058
# Epoch 5/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.2101 - accuracy: 0.9067 - val_loss: 0.2062 - val_accuracy: 0.9098
# Epoch 6/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.2045 - accuracy: 0.9100 - val_loss: 0.2045 - val_accuracy: 0.9094
# Epoch 7/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.1992 - accuracy: 0.9125 - val_loss: 0.2044 - val_accuracy: 0.9097
# Epoch 8/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.1944 - accuracy: 0.9145 - val_loss: 0.2042 - val_accuracy: 0.9107
# Epoch 9/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.1900 - accuracy: 0.9170 - val_loss: 0.2012 - val_accuracy: 0.9110
# Epoch 10/25
# 1422/1422 [==============================] - 38s 27ms/step - loss: 0.1863 - accuracy: 0.9184 - val_loss: 0.2017 - val_accuracy: 0.9115
# Epoch 11/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.1820 - accuracy: 0.9207 - val_loss: 0.2012 - val_accuracy: 0.9118
# Epoch 12/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.1781 - accuracy: 0.9226 - val_loss: 0.2008 - val_accuracy: 0.9116
# Epoch 13/25
# 1422/1422 [==============================] - 38s 27ms/step - loss: 0.1747 - accuracy: 0.9242 - val_loss: 0.2024 - val_accuracy: 0.9117
# Epoch 14/25
# 1422/1422 [==============================] - 38s 27ms/step - loss: 0.1719 - accuracy: 0.9255 - val_loss: 0.2052 - val_accuracy: 0.9115
# Epoch 15/25
# 1422/1422 [==============================] - 38s 27ms/step - loss: 0.1687 - accuracy: 0.9274 - val_loss: 0.2041 - val_accuracy: 0.9123
# Epoch 16/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.1655 - accuracy: 0.9291 - val_loss: 0.2070 - val_accuracy: 0.9119
# Epoch 17/25
# 1422/1422 [==============================] - 38s 27ms/step - loss: 0.1628 - accuracy: 0.9301 - val_loss: 0.2083 - val_accuracy: 0.9109
# 0 validation loss: 0.20082151889801025
# 9164/9164 [==============================] - 70s 8ms/step
# MODEL: 1
# Epoch 1/25
# 1422/1422 [==============================] - 45s 28ms/step - loss: 0.2741 - accuracy: 0.8718 - val_loss: 0.2373 - val_accuracy: 0.8922
# Epoch 2/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.2399 - accuracy: 0.8912 - val_loss: 0.2245 - val_accuracy: 0.8993
# Epoch 3/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.2264 - accuracy: 0.8985 - val_loss: 0.2178 - val_accuracy: 0.9021
# Epoch 4/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.2169 - accuracy: 0.9033 - val_loss: 0.2145 - val_accuracy: 0.9036
# Epoch 5/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.2103 - accuracy: 0.9069 - val_loss: 0.2124 - val_accuracy: 0.9048
# Epoch 6/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.2041 - accuracy: 0.9102 - val_loss: 0.2095 - val_accuracy: 0.9068
# Epoch 7/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.1982 - accuracy: 0.9131 - val_loss: 0.2071 - val_accuracy: 0.9070
# Epoch 8/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.1931 - accuracy: 0.9158 - val_loss: 0.2059 - val_accuracy: 0.9077
# Epoch 9/25
# 1422/1422 [==============================] - 38s 27ms/step - loss: 0.1886 - accuracy: 0.9176 - val_loss: 0.2074 - val_accuracy: 0.9071
# Epoch 10/25
# 1422/1422 [==============================] - 38s 27ms/step - loss: 0.1843 - accuracy: 0.9201 - val_loss: 0.2081 - val_accuracy: 0.9060
# Epoch 11/25
# 1422/1422 [==============================] - 38s 27ms/step - loss: 0.1806 - accuracy: 0.9217 - val_loss: 0.2080 - val_accuracy: 0.9069
# Epoch 12/25
# 1422/1422 [==============================] - 38s 27ms/step - loss: 0.1767 - accuracy: 0.9231 - val_loss: 0.2066 - val_accuracy: 0.9079
# Epoch 13/25
# 1422/1422 [==============================] - 38s 27ms/step - loss: 0.1734 - accuracy: 0.9253 - val_loss: 0.2091 - val_accuracy: 0.9082
# 1 validation loss: 0.20586013793945312
# 9164/9164 [==============================] - 70s 8ms/step
# MODEL: 2
# Epoch 1/25
# 1422/1422 [==============================] - 46s 28ms/step - loss: 0.2736 - accuracy: 0.8729 - val_loss: 0.2411 - val_accuracy: 0.8878
# Epoch 2/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.2395 - accuracy: 0.8913 - val_loss: 0.2256 - val_accuracy: 0.8988
# Epoch 3/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.2267 - accuracy: 0.8981 - val_loss: 0.2157 - val_accuracy: 0.9026
# Epoch 4/25
# 1422/1422 [==============================] - 38s 27ms/step - loss: 0.2177 - accuracy: 0.9027 - val_loss: 0.2191 - val_accuracy: 0.9002
# Epoch 5/25
# 1422/1422 [==============================] - 39s 28ms/step - loss: 0.2107 - accuracy: 0.9069 - val_loss: 0.2096 - val_accuracy: 0.9061
# Epoch 6/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.2039 - accuracy: 0.9096 - val_loss: 0.2075 - val_accuracy: 0.9070
# Epoch 7/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.1991 - accuracy: 0.9126 - val_loss: 0.2053 - val_accuracy: 0.9087
# Epoch 8/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.1942 - accuracy: 0.9153 - val_loss: 0.2045 - val_accuracy: 0.9088
# Epoch 9/25
# 1422/1422 [==============================] - 38s 27ms/step - loss: 0.1901 - accuracy: 0.9173 - val_loss: 0.2052 - val_accuracy: 0.9085
# Epoch 10/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.1857 - accuracy: 0.9190 - val_loss: 0.2037 - val_accuracy: 0.9086
# Epoch 11/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.1814 - accuracy: 0.9213 - val_loss: 0.2035 - val_accuracy: 0.9104
# Epoch 12/25
# 1422/1422 [==============================] - 38s 27ms/step - loss: 0.1785 - accuracy: 0.9227 - val_loss: 0.2054 - val_accuracy: 0.9087
# Epoch 13/25
# 1422/1422 [==============================] - 38s 27ms/step - loss: 0.1743 - accuracy: 0.9252 - val_loss: 0.2062 - val_accuracy: 0.9098
# Epoch 14/25
# 1422/1422 [==============================] - 38s 27ms/step - loss: 0.1720 - accuracy: 0.9260 - val_loss: 0.2082 - val_accuracy: 0.9073
# Epoch 15/25
# 1422/1422 [==============================] - 38s 27ms/step - loss: 0.1681 - accuracy: 0.9280 - val_loss: 0.2087 - val_accuracy: 0.9097
# Epoch 16/25
# 1422/1422 [==============================] - 38s 27ms/step - loss: 0.1654 - accuracy: 0.9292 - val_loss: 0.2072 - val_accuracy: 0.9097
# 2 validation loss: 0.2034732848405838
# 9164/9164 [==============================] - 70s 8ms/step
# MODEL: 3
# Epoch 1/25
# 1422/1422 [==============================] - 46s 28ms/step - loss: 0.2725 - accuracy: 0.8730 - val_loss: 0.2391 - val_accuracy: 0.8890
# Epoch 2/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.2390 - accuracy: 0.8911 - val_loss: 0.2250 - val_accuracy: 0.8970
# Epoch 3/25
# 1422/1422 [==============================] - 41s 29ms/step - loss: 0.2267 - accuracy: 0.8982 - val_loss: 0.2209 - val_accuracy: 0.9009
# Epoch 4/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.2174 - accuracy: 0.9031 - val_loss: 0.2108 - val_accuracy: 0.9061
# Epoch 5/25
# 1422/1422 [==============================] - 39s 28ms/step - loss: 0.2104 - accuracy: 0.9067 - val_loss: 0.2099 - val_accuracy: 0.9066
# Epoch 6/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.2039 - accuracy: 0.9102 - val_loss: 0.2102 - val_accuracy: 0.9064
# Epoch 7/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.1982 - accuracy: 0.9128 - val_loss: 0.2103 - val_accuracy: 0.9069
# Epoch 8/25
# 1422/1422 [==============================] - 39s 28ms/step - loss: 0.1934 - accuracy: 0.9155 - val_loss: 0.2066 - val_accuracy: 0.9078
# Epoch 9/25
# 1422/1422 [==============================] - 39s 28ms/step - loss: 0.1887 - accuracy: 0.9177 - val_loss: 0.2044 - val_accuracy: 0.9095
# Epoch 10/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.1839 - accuracy: 0.9195 - val_loss: 0.2073 - val_accuracy: 0.9077
# Epoch 11/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.1811 - accuracy: 0.9210 - val_loss: 0.2032 - val_accuracy: 0.9084
# Epoch 12/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.1766 - accuracy: 0.9234 - val_loss: 0.2068 - val_accuracy: 0.9087
# Epoch 13/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.1729 - accuracy: 0.9257 - val_loss: 0.2078 - val_accuracy: 0.9092
# Epoch 14/25
# 1422/1422 [==============================] - 38s 27ms/step - loss: 0.1701 - accuracy: 0.9264 - val_loss: 0.2055 - val_accuracy: 0.9099
# Epoch 15/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.1671 - accuracy: 0.9278 - val_loss: 0.2079 - val_accuracy: 0.9085
# Epoch 16/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.1647 - accuracy: 0.9290 - val_loss: 0.2070 - val_accuracy: 0.9083
# 3 validation loss: 0.20318163931369781
# 9164/9164 [==============================] - 72s 8ms/step
# MODEL: 4
# Epoch 1/25
# 1422/1422 [==============================] - 46s 28ms/step - loss: 0.2762 - accuracy: 0.8711 - val_loss: 0.2386 - val_accuracy: 0.8920
# Epoch 2/25
# 1422/1422 [==============================] - 39s 28ms/step - loss: 0.2410 - accuracy: 0.8904 - val_loss: 0.2218 - val_accuracy: 0.8983
# Epoch 3/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.2277 - accuracy: 0.8975 - val_loss: 0.2159 - val_accuracy: 0.9045
# Epoch 4/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.2195 - accuracy: 0.9017 - val_loss: 0.2086 - val_accuracy: 0.9070
# Epoch 5/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.2119 - accuracy: 0.9061 - val_loss: 0.2049 - val_accuracy: 0.9079
# Epoch 6/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.2057 - accuracy: 0.9090 - val_loss: 0.2043 - val_accuracy: 0.9084
# Epoch 7/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.2001 - accuracy: 0.9116 - val_loss: 0.2043 - val_accuracy: 0.9076
# Epoch 8/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.1952 - accuracy: 0.9142 - val_loss: 0.2011 - val_accuracy: 0.9099
# Epoch 9/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.1910 - accuracy: 0.9166 - val_loss: 0.2029 - val_accuracy: 0.9091
# Epoch 10/25
# 1422/1422 [==============================] - 39s 28ms/step - loss: 0.1862 - accuracy: 0.9187 - val_loss: 0.2006 - val_accuracy: 0.9109
# Epoch 11/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.1821 - accuracy: 0.9206 - val_loss: 0.2017 - val_accuracy: 0.9115
# Epoch 12/25
# 1422/1422 [==============================] - 39s 28ms/step - loss: 0.1788 - accuracy: 0.9222 - val_loss: 0.2003 - val_accuracy: 0.9106
# Epoch 13/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.1766 - accuracy: 0.9231 - val_loss: 0.2058 - val_accuracy: 0.9090
# Epoch 14/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.1726 - accuracy: 0.9253 - val_loss: 0.2037 - val_accuracy: 0.9104
# Epoch 15/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.1696 - accuracy: 0.9268 - val_loss: 0.2009 - val_accuracy: 0.9113
# Epoch 16/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.1661 - accuracy: 0.9286 - val_loss: 0.2029 - val_accuracy: 0.9104
# Epoch 17/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.1638 - accuracy: 0.9296 - val_loss: 0.2048 - val_accuracy: 0.9105
# 4 validation loss: 0.20028147101402283
# 9164/9164 [==============================] - 71s 8ms/step
# MODEL: 5
# Epoch 1/25
# 1422/1422 [==============================] - 46s 28ms/step - loss: 0.2732 - accuracy: 0.8728 - val_loss: 0.2401 - val_accuracy: 0.8886
# Epoch 2/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.2394 - accuracy: 0.8911 - val_loss: 0.2280 - val_accuracy: 0.8951
# Epoch 3/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.2263 - accuracy: 0.8984 - val_loss: 0.2221 - val_accuracy: 0.8994
# Epoch 4/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.2177 - accuracy: 0.9028 - val_loss: 0.2146 - val_accuracy: 0.9029
# Epoch 5/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.2099 - accuracy: 0.9070 - val_loss: 0.2124 - val_accuracy: 0.9048
# Epoch 6/25
# 1422/1422 [==============================] - 41s 29ms/step - loss: 0.2036 - accuracy: 0.9105 - val_loss: 0.2075 - val_accuracy: 0.9068
# Epoch 7/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.1984 - accuracy: 0.9134 - val_loss: 0.2068 - val_accuracy: 0.9068
# Epoch 8/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.1935 - accuracy: 0.9157 - val_loss: 0.2046 - val_accuracy: 0.9080
# Epoch 9/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.1886 - accuracy: 0.9175 - val_loss: 0.2046 - val_accuracy: 0.9076
# Epoch 10/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.1845 - accuracy: 0.9199 - val_loss: 0.2047 - val_accuracy: 0.9063
# Epoch 11/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.1803 - accuracy: 0.9219 - val_loss: 0.2040 - val_accuracy: 0.9080
# Epoch 12/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.1773 - accuracy: 0.9236 - val_loss: 0.2043 - val_accuracy: 0.9089
# Epoch 13/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.1737 - accuracy: 0.9251 - val_loss: 0.2042 - val_accuracy: 0.9090
# Epoch 14/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.1703 - accuracy: 0.9269 - val_loss: 0.2076 - val_accuracy: 0.9061
# Epoch 15/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.1673 - accuracy: 0.9279 - val_loss: 0.2082 - val_accuracy: 0.9081
# Epoch 16/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.1640 - accuracy: 0.9295 - val_loss: 0.2061 - val_accuracy: 0.9080
# 5 validation loss: 0.2039536088705063
# 9164/9164 [==============================] - 72s 8ms/step
# MODEL: 6
# Epoch 1/25
# 1422/1422 [==============================] - 46s 29ms/step - loss: 0.2730 - accuracy: 0.8727 - val_loss: 0.2386 - val_accuracy: 0.8936
# Epoch 2/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.2381 - accuracy: 0.8914 - val_loss: 0.2217 - val_accuracy: 0.9009
# Epoch 3/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.2262 - accuracy: 0.8988 - val_loss: 0.2142 - val_accuracy: 0.9037
# Epoch 4/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.2178 - accuracy: 0.9027 - val_loss: 0.2117 - val_accuracy: 0.9046
# Epoch 5/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.2101 - accuracy: 0.9070 - val_loss: 0.2100 - val_accuracy: 0.9065
# Epoch 6/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.2042 - accuracy: 0.9100 - val_loss: 0.2067 - val_accuracy: 0.9089
# Epoch 7/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.1985 - accuracy: 0.9129 - val_loss: 0.2081 - val_accuracy: 0.9081
# Epoch 8/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.1936 - accuracy: 0.9149 - val_loss: 0.2050 - val_accuracy: 0.9091
# Epoch 9/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.1891 - accuracy: 0.9173 - val_loss: 0.2052 - val_accuracy: 0.9091
# Epoch 10/25
# 1422/1422 [==============================] - 39s 28ms/step - loss: 0.1850 - accuracy: 0.9193 - val_loss: 0.2050 - val_accuracy: 0.9097
# Epoch 11/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.1816 - accuracy: 0.9215 - val_loss: 0.2049 - val_accuracy: 0.9097
# Epoch 12/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.1781 - accuracy: 0.9230 - val_loss: 0.2052 - val_accuracy: 0.9098
# Epoch 13/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.1745 - accuracy: 0.9249 - val_loss: 0.2052 - val_accuracy: 0.9102
# Epoch 14/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.1712 - accuracy: 0.9262 - val_loss: 0.2045 - val_accuracy: 0.9103
# Epoch 15/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.1688 - accuracy: 0.9275 - val_loss: 0.2050 - val_accuracy: 0.9115
# Epoch 16/25
# 1422/1422 [==============================] - 39s 28ms/step - loss: 0.1653 - accuracy: 0.9285 - val_loss: 0.2060 - val_accuracy: 0.9103
# Epoch 17/25
# 1422/1422 [==============================] - 39s 28ms/step - loss: 0.1631 - accuracy: 0.9301 - val_loss: 0.2083 - val_accuracy: 0.9107
# Epoch 18/25
# 1422/1422 [==============================] - 39s 28ms/step - loss: 0.1605 - accuracy: 0.9312 - val_loss: 0.2090 - val_accuracy: 0.9088
# Epoch 19/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.1572 - accuracy: 0.9330 - val_loss: 0.2100 - val_accuracy: 0.9105
# 6 validation loss: 0.20451121032238007
# 9164/9164 [==============================] - 72s 8ms/step
# MODEL: 7
# Epoch 1/25
# 1422/1422 [==============================] - 46s 29ms/step - loss: 0.2739 - accuracy: 0.8721 - val_loss: 0.2365 - val_accuracy: 0.8929
# Epoch 2/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.2398 - accuracy: 0.8910 - val_loss: 0.2288 - val_accuracy: 0.8946
# Epoch 3/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.2264 - accuracy: 0.8985 - val_loss: 0.2151 - val_accuracy: 0.9039
# Epoch 4/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.2177 - accuracy: 0.9027 - val_loss: 0.2104 - val_accuracy: 0.9064
# Epoch 5/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.2103 - accuracy: 0.9070 - val_loss: 0.2101 - val_accuracy: 0.9060
# Epoch 6/25
# 1422/1422 [==============================] - 39s 28ms/step - loss: 0.2042 - accuracy: 0.9101 - val_loss: 0.2103 - val_accuracy: 0.9058
# Epoch 7/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.1987 - accuracy: 0.9130 - val_loss: 0.2052 - val_accuracy: 0.9087
# Epoch 8/25
# 1422/1422 [==============================] - 39s 28ms/step - loss: 0.1938 - accuracy: 0.9151 - val_loss: 0.2067 - val_accuracy: 0.9078
# Epoch 9/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.1899 - accuracy: 0.9173 - val_loss: 0.2016 - val_accuracy: 0.9112
# Epoch 10/25
# 1422/1422 [==============================] - 39s 28ms/step - loss: 0.1855 - accuracy: 0.9187 - val_loss: 0.2030 - val_accuracy: 0.9105
# Epoch 11/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.1817 - accuracy: 0.9209 - val_loss: 0.2032 - val_accuracy: 0.9118
# Epoch 12/25
# 1422/1422 [==============================] - 39s 27ms/step - loss: 0.1780 - accuracy: 0.9231 - val_loss: 0.2024 - val_accuracy: 0.9109
# Epoch 13/25
# 1422/1422 [==============================] - 39s 28ms/step - loss: 0.1756 - accuracy: 0.9243 - val_loss: 0.2044 - val_accuracy: 0.9099
# Epoch 14/25
# 1422/1422 [==============================] - 39s 28ms/step - loss: 0.1714 - accuracy: 0.9259 - val_loss: 0.2057 - val_accuracy: 0.9094
# 7 validation loss: 0.20156125724315643
# 9164/9164 [==============================] - 73s 8ms/step
# MODEL: 8
# Epoch 1/25
# 1422/1422 [==============================] - 47s 29ms/step - loss: 0.2735 - accuracy: 0.8729 - val_loss: 0.2496 - val_accuracy: 0.8840
# Epoch 2/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.2395 - accuracy: 0.8909 - val_loss: 0.2292 - val_accuracy: 0.8959
# Epoch 3/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.2269 - accuracy: 0.8976 - val_loss: 0.2204 - val_accuracy: 0.9014
# Epoch 4/25
# 1422/1422 [==============================] - 41s 28ms/step - loss: 0.2177 - accuracy: 0.9026 - val_loss: 0.2167 - val_accuracy: 0.9033
# Epoch 5/25
# 1422/1422 [==============================] - 41s 29ms/step - loss: 0.2104 - accuracy: 0.9065 - val_loss: 0.2132 - val_accuracy: 0.9044
# Epoch 6/25
# 1422/1422 [==============================] - 41s 29ms/step - loss: 0.2044 - accuracy: 0.9099 - val_loss: 0.2120 - val_accuracy: 0.9059
# Epoch 7/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.1988 - accuracy: 0.9125 - val_loss: 0.2094 - val_accuracy: 0.9065
# Epoch 8/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.1945 - accuracy: 0.9147 - val_loss: 0.2120 - val_accuracy: 0.9048
# Epoch 9/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.1898 - accuracy: 0.9165 - val_loss: 0.2093 - val_accuracy: 0.9070
# Epoch 10/25
# 1422/1422 [==============================] - 41s 29ms/step - loss: 0.1849 - accuracy: 0.9192 - val_loss: 0.2082 - val_accuracy: 0.9073
# Epoch 11/25
# 1422/1422 [==============================] - 39s 28ms/step - loss: 0.1821 - accuracy: 0.9211 - val_loss: 0.2132 - val_accuracy: 0.9085
# Epoch 12/25
# 1422/1422 [==============================] - 39s 28ms/step - loss: 0.1781 - accuracy: 0.9225 - val_loss: 0.2110 - val_accuracy: 0.9081
# Epoch 13/25
# 1422/1422 [==============================] - 39s 28ms/step - loss: 0.1748 - accuracy: 0.9248 - val_loss: 0.2146 - val_accuracy: 0.9077
# Epoch 14/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.1717 - accuracy: 0.9262 - val_loss: 0.2129 - val_accuracy: 0.9084
# Epoch 15/25
# 1422/1422 [==============================] - 39s 28ms/step - loss: 0.1681 - accuracy: 0.9277 - val_loss: 0.2153 - val_accuracy: 0.9078
# 8 validation loss: 0.20820631086826324
# 9164/9164 [==============================] - 72s 8ms/step
# MODEL: 9
# Epoch 1/25
# 1422/1422 [==============================] - 47s 29ms/step - loss: 0.2737 - accuracy: 0.8725 - val_loss: 0.2408 - val_accuracy: 0.8900
# Epoch 2/25
# 1422/1422 [==============================] - 41s 29ms/step - loss: 0.2391 - accuracy: 0.8913 - val_loss: 0.2298 - val_accuracy: 0.8968
# Epoch 3/25
# 1422/1422 [==============================] - 41s 29ms/step - loss: 0.2260 - accuracy: 0.8987 - val_loss: 0.2214 - val_accuracy: 0.9010
# Epoch 4/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.2169 - accuracy: 0.9031 - val_loss: 0.2173 - val_accuracy: 0.9026
# Epoch 5/25
# 1422/1422 [==============================] - 41s 29ms/step - loss: 0.2098 - accuracy: 0.9071 - val_loss: 0.2156 - val_accuracy: 0.9029
# Epoch 6/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.2041 - accuracy: 0.9098 - val_loss: 0.2162 - val_accuracy: 0.9037
# Epoch 7/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.1992 - accuracy: 0.9118 - val_loss: 0.2104 - val_accuracy: 0.9063
# Epoch 8/25
# 1422/1422 [==============================] - 41s 29ms/step - loss: 0.1937 - accuracy: 0.9149 - val_loss: 0.2102 - val_accuracy: 0.9060
# Epoch 9/25
# 1422/1422 [==============================] - 41s 29ms/step - loss: 0.1896 - accuracy: 0.9171 - val_loss: 0.2089 - val_accuracy: 0.9074
# Epoch 10/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.1848 - accuracy: 0.9191 - val_loss: 0.2089 - val_accuracy: 0.9073
# Epoch 11/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.1821 - accuracy: 0.9211 - val_loss: 0.2083 - val_accuracy: 0.9076
# Epoch 12/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.1779 - accuracy: 0.9226 - val_loss: 0.2107 - val_accuracy: 0.9069
# Epoch 13/25
# 1422/1422 [==============================] - 39s 28ms/step - loss: 0.1739 - accuracy: 0.9248 - val_loss: 0.2145 - val_accuracy: 0.9062
# Epoch 14/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.1716 - accuracy: 0.9259 - val_loss: 0.2125 - val_accuracy: 0.9058
# Epoch 15/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.1675 - accuracy: 0.9279 - val_loss: 0.2108 - val_accuracy: 0.9073
# Epoch 16/25
# 1422/1422 [==============================] - 40s 28ms/step - loss: 0.1653 - accuracy: 0.9284 - val_loss: 0.2122 - val_accuracy: 0.9068
# 9 validation loss: 0.20832520723342896
# 9164/9164 [==============================] - 73s 8ms/step
