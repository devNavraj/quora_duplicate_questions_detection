# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/quora_duplicate_questions_detection/
# Out:
# /content/drive/.shortcut-targets-by-id/1NfDfMFFEa6jbcf5EQ_tVWbvhytT96tlt/quora_duplicate_questions_detection

# %%
# !ls
# Out:
#  bert			       lstm_feature_test1.ipynb
#  bilstm_nn_test1.ipynb	       lstm_test1.ipynb
#  bilstm_nn_test2.ipynb	       model.png
#  classifier.py		       models
#  cnn_features_test1.ipynb      models4.ipynb
#  cnn_test1.ipynb	       models5.ipynb
# 'Copy of deep_nn.ipynb'        model_tfidf.ipynb
# 'Copy of nlp_features.ipynb'   nlp_features.ipynb
#  data			       nn_plot
#  deep_nn.ipynb		       non_nlp_features.ipynb
#  deep_nn_test1.ipynb	       predictions
#  deep_nn_test2.ipynb	       __pycache__
#  deep_nn_test3.ipynb	       tfidf_model.ipynb
#  feature_engineering.ipynb     Untitled.ipynb
#  graphs			       utils.py
#  gru_test1.ipynb	       word2vec_features.ipynb
#  __init__.py

# %%
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import StratifiedKFold
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Dense, Input, LSTM, Embedding, Dropout
from keras.layers.core import Lambda
from keras.layers.merge import concatenate, add, multiply
from keras.models import Model, Sequential
from keras.layers import BatchNormalization
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers.noise import GaussianNoise
from keras import backend as K
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
np.random.seed(0)
WNL = WordNetLemmatizer()
STOP_WORDS = set(stopwords.words('english'))
MAX_SEQUENCE_LENGTH = 30
MIN_WORD_OCCURRENCE = 100
REPLACE_WORD = "rare"
EMBEDDING_DIM = 300
NUM_FOLDS = 10
BATCH_SIZE = 256
EMBEDDING_FILE = "data/glove.840B.300d.txt"

# %%
def cutter(word):
    if len(word) < 4:
        return word
    return WNL.lemmatize(WNL.lemmatize(word, "n"), "v")

# %%
def preprocess(string):
    string = string.lower().replace(",000,000", "m").replace(",000", "k").replace("′", "'").replace("’", "'") \
        .replace("won't", "will not").replace("cannot", "can not").replace("can't", "can not") \
        .replace("n't", " not").replace("what's", "what is").replace("it's", "it is") \
        .replace("'ve", " have").replace("i'm", "i am").replace("'re", " are") \
        .replace("he's", "he is").replace("she's", "she is").replace("'s", " own") \
        .replace("%", " percent ").replace("₹", " rupee ").replace("$", " dollar ") \
        .replace("€", " euro ").replace("'ll", " will").replace("=", " equal ").replace("+", " plus ")
    string = re.sub('[“”\(\'…\)\!\^\"\.;:,\-\?？\{\}\[\]\\/\*@]', ' ', string)
    string = re.sub(r"([0-9]+)000000", r"\1m", string)
    string = re.sub(r"([0-9]+)000", r"\1k", string)
    string = ' '.join([cutter(w) for w in string.split()])
    return string

# %%
def get_embedding():
    embeddings_index = {}
    f = open(EMBEDDING_FILE, encoding="utf8")
    for line in f:
        values = line.split()
        word = values[0]
        if len(values) == EMBEDDING_DIM + 1 and word in top_words:
            coefs = np.asarray(values[1:], dtype="float32")
            embeddings_index[word] = coefs
    f.close()
    return embeddings_index

# %%
def is_numeric(s):
    return any(i.isdigit() for i in s)

# %%
def prepare(q):
    new_q = []
    surplus_q = []
    numbers_q = []
    new_rare = True
    for w in q.split()[::-1]:
        if w in top_words:
            new_q = [w] + new_q
            new_rare = True
        elif w not in STOP_WORDS:
            if new_rare:
                new_q = ["rare"] + new_q
                new_rare = False
            if is_numeric(w):
                numbers_q = [w] + numbers_q
            else:
                surplus_q = [w] + surplus_q
        else:
            new_rare = True
        if len(new_q) == MAX_SEQUENCE_LENGTH:
            break
    new_q = " ".join(new_q)
    return new_q, set(surplus_q), set(numbers_q)

# %%
def extract_features(df):
    q1s = np.array([""] * len(df), dtype=object)
    q2s = np.array([""] * len(df), dtype=object)
    features = np.zeros((len(df), 4))

    for i, (q1, q2) in enumerate(list(zip(df["question1"], df["question2"]))):
        q1s[i], surplus1, numbers1 = prepare(q1)
        q2s[i], surplus2, numbers2 = prepare(q2)
        features[i, 0] = len(surplus1.intersection(surplus2))
        features[i, 1] = len(surplus1.union(surplus2))
        features[i, 2] = len(numbers1.intersection(numbers2))
        features[i, 3] = len(numbers1.union(numbers2))

    return q1s, q2s, features

# %%
train = pd.read_csv("data/train.csv")
test = pd.read_csv("data/test.csv")

# %%
train["question1"] = train["question1"].fillna("").apply(preprocess)
train["question2"] = train["question2"].fillna("").apply(preprocess)

# %%
print("Creating the vocabulary of words occurred more than", MIN_WORD_OCCURRENCE)
all_questions = pd.Series(train["question1"].tolist() + train["question2"].tolist()).unique()
vectorizer = CountVectorizer(lowercase=False, token_pattern="\S+", min_df=MIN_WORD_OCCURRENCE)
vectorizer.fit(all_questions)
top_words = set(vectorizer.vocabulary_.keys())
top_words.add(REPLACE_WORD)
# Out:
# Creating the vocabulary of words occurred more than 100

# %%
embeddings_index = get_embedding()
print("Words are not found in the embedding:", top_words - embeddings_index.keys())
top_words = embeddings_index.keys()
# Out:
# Words are not found in the embedding: {'quorans', 'redmi', 'kvpy', 'paytm', '\\frac', 'brexit', 'c#', 'iisc', 'oneplus', 'demonetisation', '\\sqrt'}

# %%
print("Train questions are being prepared for LSTM...")
q1s_train, q2s_train, train_q_features = extract_features(train)
# Out:
# Train questions are being prepared for LSTM...

# %%
tokenizer = Tokenizer(filters="")
tokenizer.fit_on_texts(np.append(q1s_train, q2s_train))
word_index = tokenizer.word_index

# %%
data_1 = pad_sequences(tokenizer.texts_to_sequences(q1s_train), maxlen=MAX_SEQUENCE_LENGTH)
data_2 = pad_sequences(tokenizer.texts_to_sequences(q2s_train), maxlen=MAX_SEQUENCE_LENGTH)
labels = np.array(train["is_duplicate"])

# %%
nb_words = len(word_index) + 1
embedding_matrix = np.zeros((nb_words, EMBEDDING_DIM))

# %%
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %%
print("Train features are being merged with NLP and Non-NLP features...")
train_nlp_features = pd.read_csv("data/nlp_features_train.csv")
train_non_nlp_features = pd.read_csv("data/non_nlp_features_train.csv")
features_train = np.hstack((train_q_features, train_nlp_features, train_non_nlp_features))
# Out:
# Train features are being merged with NLP and Non-NLP features...

# %%
print("Same steps are being applied for test...")
test["question1"] = test["question1"].fillna("").apply(preprocess)
test["question2"] = test["question2"].fillna("").apply(preprocess)

q1s_test, q2s_test, test_q_features = extract_features(test)

test_data_1 = pad_sequences(tokenizer.texts_to_sequences(q1s_test), maxlen=MAX_SEQUENCE_LENGTH)
test_data_2 = pad_sequences(tokenizer.texts_to_sequences(q2s_test), maxlen=MAX_SEQUENCE_LENGTH)

test_nlp_features = pd.read_csv("data/nlp_features_test.csv")
test_non_nlp_features = pd.read_csv("data/non_nlp_features_test.csv")
features_test = np.hstack((test_q_features, test_nlp_features, test_non_nlp_features))
# Out:
# Same steps are being applied for test...

# %%
stratified_kf = StratifiedKFold(n_splits=NUM_FOLDS, shuffle=True)
model_count = 0

# %%
for idx_train, idx_val in stratified_kf.split(train["is_duplicate"], train["is_duplicate"]):
    print("MODEL:", model_count)
    data_1_train = data_1[idx_train]
    data_2_train = data_2[idx_train]
    labels_train = labels[idx_train]
    f_train = features_train[idx_train]

    data_1_val = data_1[idx_val]
    data_2_val = data_2[idx_val]
    labels_val = labels[idx_val]
    f_val = features_train[idx_val]

    embedding_layer = Embedding(nb_words,
                                EMBEDDING_DIM,
                                weights=[embedding_matrix],
                                input_length=MAX_SEQUENCE_LENGTH,
                                trainable=False)
    lstm_layer = Sequential()
    # Adding Embedding layer
    lstm_layer.add(embedding_layer)          

    # Adding 2 Lstm layers
    lstm_layer.add(LSTM(32, return_sequences=True))
    lstm_layer.add(Dropout(0.2))

    lstm_layer.add(LSTM(64, return_sequences=False))
    lstm_layer.add(Dropout(0.2))


    # Adding Dense layer
    lstm_layer.add(Dense(128,activation="linear"))
    lstm_layer.add(Dropout(0.3))

    sequence_1_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype="int32")
    x1 = lstm_layer(sequence_1_input)

    sequence_2_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype="int32")
    y1 = lstm_layer(sequence_2_input)

    features_input = Input(shape=(f_train.shape[1],), dtype="float32")
    features_dense = BatchNormalization()(features_input)
    features_dense = Dense(200, activation="relu")(features_dense)
    features_dense = Dropout(0.2)(features_dense)

    lamda_function=Lambda(lambda tensor:K.abs(tensor[0]-tensor[1]),name="Absolute_distance")
    abs_distance_vector=lamda_function([x1,y1])

    lamda_function2=Lambda(lambda tensor:K.abs(tensor[0]*tensor[1]),name="Hamadard_multiplication") #abs() returns absolute value
    hamadard_vector=lamda_function2([x1,y1])

    merged = add([abs_distance_vector, hamadard_vector])
    merged = concatenate([merged, features_dense])
    merged = BatchNormalization()(merged)

    out = Dense(1, activation="sigmoid")(merged)

    model = Model(inputs=[sequence_1_input, sequence_2_input, features_input], outputs=out)
    model.compile(loss="binary_crossentropy", optimizer="adam", metrics=['accuracy'])
    plot_model(model, to_file='nn_plot/lstm_feature.png', show_shapes=True, expand_nested=True)

    early_stopping = EarlyStopping(monitor="val_loss", patience=5)
    best_model_path = "models/lstm_feature/best_model" + str(model_count) + ".h5"
    model_checkpoint = ModelCheckpoint(best_model_path, save_best_only=True, save_weights_only=True)

    model_history = model.fit([data_1_train, data_2_train, f_train], labels_train, 
                     batch_size=BATCH_SIZE, epochs=25, shuffle=True,
                     validation_data=([data_1_val, data_2_val, f_val], labels_val),
                     callbacks=[early_stopping, model_checkpoint], verbose=1)

    model.load_weights(best_model_path)
    print(model_count, "validation loss:", min(model_history.history["val_loss"]))
    print(model_count, "validation accuracy:", max(model_history.history["val_accuracy"]))
    # Accuracy Graph
    fig = plt.figure(dpi = 100)
    plt.title("Accuracy")
    plt.plot(model_history.history["accuracy"], color = "g", label = "Train")
    plt.plot(model_history.history["val_accuracy"], color = "b", label = "Test")
    plt.legend(loc = "best")
    plt.savefig("graphs/lstm_feature/accuracyLSTM" + str(model_count) + ".png")
    # Loss Graph
    fig = plt.figure(dpi = 100)
    plt.title("Loss")
    plt.plot(model_history.history["loss"], color = "g", label = "Train")
    plt.plot(model_history.history["val_loss"], color = "b", label = "Test")
    plt.legend(loc = "best")
    plt.savefig("graphs/lstm_feature/lossLSTM" + str(model_count) + ".png")
    preds = model.predict([test_data_1, test_data_2, features_test], batch_size=BATCH_SIZE, verbose=1)

    submission = pd.DataFrame({"test_id": test["test_id"], "is_duplicate": preds.ravel()})
    submission.to_csv("predictions/lstm_feature/preds" + str(model_count) + ".csv", index=False)

    model_count += 1
# Out:
# MODEL: 0
# Epoch 1/25
# 1422/1422 [==============================] - 73s 44ms/step - loss: 0.2844 - accuracy: 0.8661 - val_loss: 0.2570 - val_accuracy: 0.8802
# Epoch 2/25
# 1422/1422 [==============================] - 58s 41ms/step - loss: 0.2567 - accuracy: 0.8803 - val_loss: 0.2534 - val_accuracy: 0.8826
# Epoch 3/25
# 1422/1422 [==============================] - 58s 41ms/step - loss: 0.2499 - accuracy: 0.8842 - val_loss: 0.2420 - val_accuracy: 0.8890
# Epoch 4/25
# 1422/1422 [==============================] - 56s 39ms/step - loss: 0.2442 - accuracy: 0.8874 - val_loss: 0.2461 - val_accuracy: 0.8879
# Epoch 5/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.2399 - accuracy: 0.8904 - val_loss: 0.2455 - val_accuracy: 0.8872
# Epoch 6/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.2363 - accuracy: 0.8921 - val_loss: 0.2565 - val_accuracy: 0.8799
# Epoch 7/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.2333 - accuracy: 0.8938 - val_loss: 0.2600 - val_accuracy: 0.8778
# Epoch 8/25
# 1422/1422 [==============================] - 53s 37ms/step - loss: 0.2299 - accuracy: 0.8957 - val_loss: 0.2771 - val_accuracy: 0.8675
# 0 validation loss: 0.24197617173194885
# 0 validation accuracy: 0.8890400528907776
# 9164/9164 [==============================] - 96s 10ms/step
# MODEL: 1
# Epoch 1/25
# 1422/1422 [==============================] - 70s 43ms/step - loss: 0.2829 - accuracy: 0.8668 - val_loss: 0.2589 - val_accuracy: 0.8820
# Epoch 2/25
# 1422/1422 [==============================] - 57s 40ms/step - loss: 0.2559 - accuracy: 0.8812 - val_loss: 0.2516 - val_accuracy: 0.8862
# Epoch 3/25
# 1422/1422 [==============================] - 56s 39ms/step - loss: 0.2490 - accuracy: 0.8851 - val_loss: 0.2768 - val_accuracy: 0.8698
# Epoch 4/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.2433 - accuracy: 0.8881 - val_loss: 0.2507 - val_accuracy: 0.8849
# Epoch 5/25
# 1422/1422 [==============================] - 55s 38ms/step - loss: 0.2387 - accuracy: 0.8910 - val_loss: 0.2680 - val_accuracy: 0.8769
# Epoch 6/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.2350 - accuracy: 0.8929 - val_loss: 0.2657 - val_accuracy: 0.8751
# Epoch 7/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.2321 - accuracy: 0.8945 - val_loss: 0.2692 - val_accuracy: 0.8743
# Epoch 8/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.2294 - accuracy: 0.8956 - val_loss: 0.2479 - val_accuracy: 0.8872
# Epoch 9/25
# 1422/1422 [==============================] - 53s 37ms/step - loss: 0.2263 - accuracy: 0.8977 - val_loss: 0.2733 - val_accuracy: 0.8704
# Epoch 10/25
# 1422/1422 [==============================] - 53s 37ms/step - loss: 0.2237 - accuracy: 0.8988 - val_loss: 0.2650 - val_accuracy: 0.8777
# Epoch 11/25
# 1422/1422 [==============================] - 53s 37ms/step - loss: 0.2219 - accuracy: 0.9002 - val_loss: 0.2567 - val_accuracy: 0.8816
# Epoch 12/25
# 1422/1422 [==============================] - 53s 37ms/step - loss: 0.2200 - accuracy: 0.9008 - val_loss: 0.2868 - val_accuracy: 0.8643
# Epoch 13/25
# 1422/1422 [==============================] - 53s 37ms/step - loss: 0.2181 - accuracy: 0.9018 - val_loss: 0.2645 - val_accuracy: 0.8759
# 1 validation loss: 0.24787788093090057
# 1 validation accuracy: 0.8871601819992065
# 9164/9164 [==============================] - 109s 12ms/step
# MODEL: 2
# Epoch 1/25
# 1422/1422 [==============================] - 71s 44ms/step - loss: 0.2835 - accuracy: 0.8666 - val_loss: 0.2564 - val_accuracy: 0.8813
# Epoch 2/25
# 1422/1422 [==============================] - 60s 42ms/step - loss: 0.2571 - accuracy: 0.8805 - val_loss: 0.2538 - val_accuracy: 0.8832
# Epoch 3/25
# 1422/1422 [==============================] - 60s 42ms/step - loss: 0.2502 - accuracy: 0.8844 - val_loss: 0.2550 - val_accuracy: 0.8825
# Epoch 4/25
# 1422/1422 [==============================] - 59s 41ms/step - loss: 0.2450 - accuracy: 0.8872 - val_loss: 0.2400 - val_accuracy: 0.8912
# Epoch 5/25
# 1422/1422 [==============================] - 57s 40ms/step - loss: 0.2411 - accuracy: 0.8894 - val_loss: 0.2469 - val_accuracy: 0.8860
# Epoch 6/25
# 1422/1422 [==============================] - 58s 41ms/step - loss: 0.2374 - accuracy: 0.8914 - val_loss: 0.2364 - val_accuracy: 0.8939
# Epoch 7/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.2340 - accuracy: 0.8932 - val_loss: 0.2391 - val_accuracy: 0.8922
# Epoch 8/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.2314 - accuracy: 0.8946 - val_loss: 0.2435 - val_accuracy: 0.8883
# Epoch 9/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.2285 - accuracy: 0.8963 - val_loss: 0.2451 - val_accuracy: 0.8869
# Epoch 10/25
# 1422/1422 [==============================] - 55s 38ms/step - loss: 0.2261 - accuracy: 0.8976 - val_loss: 0.2357 - val_accuracy: 0.8924
# Epoch 11/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.2241 - accuracy: 0.8991 - val_loss: 0.2363 - val_accuracy: 0.8931
# Epoch 12/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.2213 - accuracy: 0.9000 - val_loss: 0.2381 - val_accuracy: 0.8920
# Epoch 13/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.2192 - accuracy: 0.9017 - val_loss: 0.2364 - val_accuracy: 0.8926
# Epoch 14/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.2175 - accuracy: 0.9022 - val_loss: 0.2458 - val_accuracy: 0.8866
# Epoch 15/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.2152 - accuracy: 0.9036 - val_loss: 0.2425 - val_accuracy: 0.8892
# 2 validation loss: 0.2356833517551422
# 2 validation accuracy: 0.8939127922058105
# 9164/9164 [==============================] - 113s 12ms/step
# MODEL: 3
# Epoch 1/25
# 1422/1422 [==============================] - 71s 44ms/step - loss: 0.2813 - accuracy: 0.8676 - val_loss: 0.2599 - val_accuracy: 0.8790
# Epoch 2/25
# 1422/1422 [==============================] - 61s 43ms/step - loss: 0.2568 - accuracy: 0.8803 - val_loss: 0.2527 - val_accuracy: 0.8833
# Epoch 3/25
# 1422/1422 [==============================] - 58s 41ms/step - loss: 0.2495 - accuracy: 0.8845 - val_loss: 0.2467 - val_accuracy: 0.8857
# Epoch 4/25
# 1422/1422 [==============================] - 56s 40ms/step - loss: 0.2441 - accuracy: 0.8879 - val_loss: 0.2478 - val_accuracy: 0.8860
# Epoch 5/25
# 1422/1422 [==============================] - 56s 39ms/step - loss: 0.2400 - accuracy: 0.8900 - val_loss: 0.2405 - val_accuracy: 0.8890
# Epoch 6/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.2364 - accuracy: 0.8921 - val_loss: 0.2502 - val_accuracy: 0.8836
# Epoch 7/25
# 1422/1422 [==============================] - 56s 39ms/step - loss: 0.2329 - accuracy: 0.8942 - val_loss: 0.2385 - val_accuracy: 0.8915
# Epoch 8/25
# 1422/1422 [==============================] - 56s 39ms/step - loss: 0.2300 - accuracy: 0.8955 - val_loss: 0.2500 - val_accuracy: 0.8826
# Epoch 9/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.2270 - accuracy: 0.8973 - val_loss: 0.2494 - val_accuracy: 0.8827
# Epoch 10/25
# 1422/1422 [==============================] - 55s 38ms/step - loss: 0.2243 - accuracy: 0.8983 - val_loss: 0.2501 - val_accuracy: 0.8826
# Epoch 11/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.2219 - accuracy: 0.9001 - val_loss: 0.2527 - val_accuracy: 0.8816
# Epoch 12/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.2198 - accuracy: 0.9013 - val_loss: 0.2520 - val_accuracy: 0.8808
# 3 validation loss: 0.23845987021923065
# 3 validation accuracy: 0.8915135264396667
# 9164/9164 [==============================] - 111s 12ms/step
# MODEL: 4
# Epoch 1/25
# 1422/1422 [==============================] - 69s 43ms/step - loss: 0.2836 - accuracy: 0.8661 - val_loss: 0.2554 - val_accuracy: 0.8808
# Epoch 2/25
# 1422/1422 [==============================] - 59s 41ms/step - loss: 0.2564 - accuracy: 0.8808 - val_loss: 0.2494 - val_accuracy: 0.8850
# Epoch 3/25
# 1422/1422 [==============================] - 59s 41ms/step - loss: 0.2493 - accuracy: 0.8851 - val_loss: 0.2428 - val_accuracy: 0.8889
# Epoch 4/25
# 1422/1422 [==============================] - 58s 41ms/step - loss: 0.2439 - accuracy: 0.8877 - val_loss: 0.2473 - val_accuracy: 0.8874
# Epoch 5/25
# 1422/1422 [==============================] - 58s 41ms/step - loss: 0.2394 - accuracy: 0.8905 - val_loss: 0.2405 - val_accuracy: 0.8901
# Epoch 6/25
# 1422/1422 [==============================] - 57s 40ms/step - loss: 0.2358 - accuracy: 0.8926 - val_loss: 0.2372 - val_accuracy: 0.8921
# Epoch 7/25
# 1422/1422 [==============================] - 56s 40ms/step - loss: 0.2324 - accuracy: 0.8939 - val_loss: 0.2573 - val_accuracy: 0.8781
# Epoch 8/25
# 1422/1422 [==============================] - 56s 40ms/step - loss: 0.2301 - accuracy: 0.8951 - val_loss: 0.2448 - val_accuracy: 0.8868
# Epoch 9/25
# 1422/1422 [==============================] - 56s 40ms/step - loss: 0.2275 - accuracy: 0.8971 - val_loss: 0.2512 - val_accuracy: 0.8835
# Epoch 10/25
# 1422/1422 [==============================] - 56s 39ms/step - loss: 0.2244 - accuracy: 0.8986 - val_loss: 0.2414 - val_accuracy: 0.8877
# Epoch 11/25
# 1422/1422 [==============================] - 56s 39ms/step - loss: 0.2225 - accuracy: 0.8993 - val_loss: 0.2488 - val_accuracy: 0.8834
# 4 validation loss: 0.23718123137950897
# 4 validation accuracy: 0.8921318650245667
# 9164/9164 [==============================] - 114s 12ms/step
# MODEL: 5
# Epoch 1/25
# 1422/1422 [==============================] - 69s 43ms/step - loss: 0.2826 - accuracy: 0.8667 - val_loss: 0.2627 - val_accuracy: 0.8764
# Epoch 2/25
# 1422/1422 [==============================] - 60s 42ms/step - loss: 0.2556 - accuracy: 0.8815 - val_loss: 0.2612 - val_accuracy: 0.8760
# Epoch 3/25
# 1422/1422 [==============================] - 59s 41ms/step - loss: 0.2486 - accuracy: 0.8849 - val_loss: 0.2450 - val_accuracy: 0.8867
# Epoch 4/25
# 1422/1422 [==============================] - 59s 41ms/step - loss: 0.2430 - accuracy: 0.8886 - val_loss: 0.2534 - val_accuracy: 0.8822
# Epoch 5/25
# 1422/1422 [==============================] - 58s 41ms/step - loss: 0.2391 - accuracy: 0.8910 - val_loss: 0.2478 - val_accuracy: 0.8847
# Epoch 6/25
# 1422/1422 [==============================] - 58s 41ms/step - loss: 0.2357 - accuracy: 0.8925 - val_loss: 0.2413 - val_accuracy: 0.8891
# Epoch 7/25
# 1422/1422 [==============================] - 58s 40ms/step - loss: 0.2329 - accuracy: 0.8943 - val_loss: 0.2462 - val_accuracy: 0.8855
# Epoch 8/25
# 1422/1422 [==============================] - 58s 40ms/step - loss: 0.2301 - accuracy: 0.8959 - val_loss: 0.2516 - val_accuracy: 0.8821
# Epoch 9/25
# 1422/1422 [==============================] - 58s 40ms/step - loss: 0.2270 - accuracy: 0.8974 - val_loss: 0.2520 - val_accuracy: 0.8810
# Epoch 10/25
# 1422/1422 [==============================] - 57s 40ms/step - loss: 0.2242 - accuracy: 0.8990 - val_loss: 0.2698 - val_accuracy: 0.8726
# Epoch 11/25
# 1422/1422 [==============================] - 57s 40ms/step - loss: 0.2223 - accuracy: 0.8998 - val_loss: 0.2550 - val_accuracy: 0.8791
# 5 validation loss: 0.24130818247795105
# 5 validation accuracy: 0.8891389966011047
# 9164/9164 [==============================] - 113s 12ms/step
# MODEL: 6
# Epoch 1/25
# 1422/1422 [==============================] - 71s 44ms/step - loss: 0.2835 - accuracy: 0.8665 - val_loss: 0.2516 - val_accuracy: 0.8846
# Epoch 2/25
# 1422/1422 [==============================] - 59s 42ms/step - loss: 0.2558 - accuracy: 0.8806 - val_loss: 0.2473 - val_accuracy: 0.8890
# Epoch 3/25
# 1422/1422 [==============================] - 58s 41ms/step - loss: 0.2487 - accuracy: 0.8852 - val_loss: 0.2409 - val_accuracy: 0.8921
# Epoch 4/25
# 1422/1422 [==============================] - 58s 40ms/step - loss: 0.2432 - accuracy: 0.8878 - val_loss: 0.2439 - val_accuracy: 0.8886
# Epoch 5/25
# 1422/1422 [==============================] - 57s 40ms/step - loss: 0.2387 - accuracy: 0.8907 - val_loss: 0.2466 - val_accuracy: 0.8861
# Epoch 6/25
# 1422/1422 [==============================] - 56s 40ms/step - loss: 0.2355 - accuracy: 0.8926 - val_loss: 0.2515 - val_accuracy: 0.8829
# Epoch 7/25
# 1422/1422 [==============================] - 56s 40ms/step - loss: 0.2324 - accuracy: 0.8942 - val_loss: 0.2430 - val_accuracy: 0.8876
# Epoch 8/25
# 1422/1422 [==============================] - 57s 40ms/step - loss: 0.2297 - accuracy: 0.8956 - val_loss: 0.2409 - val_accuracy: 0.8904
# 6 validation loss: 0.24088595807552338
# 6 validation accuracy: 0.8921318650245667
# 9164/9164 [==============================] - 115s 12ms/step
# MODEL: 7
# Epoch 1/25
# 1422/1422 [==============================] - 68s 42ms/step - loss: 0.2809 - accuracy: 0.8676 - val_loss: 0.2554 - val_accuracy: 0.8827
# Epoch 2/25
# 1422/1422 [==============================] - 56s 40ms/step - loss: 0.2565 - accuracy: 0.8806 - val_loss: 0.2494 - val_accuracy: 0.8856
# Epoch 3/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.2491 - accuracy: 0.8848 - val_loss: 0.2509 - val_accuracy: 0.8838
# Epoch 4/25
# 1422/1422 [==============================] - 55s 38ms/step - loss: 0.2440 - accuracy: 0.8878 - val_loss: 0.2522 - val_accuracy: 0.8844
# Epoch 5/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.2396 - accuracy: 0.8901 - val_loss: 0.2594 - val_accuracy: 0.8788
# Epoch 6/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.2359 - accuracy: 0.8924 - val_loss: 0.2444 - val_accuracy: 0.8878
# Epoch 7/25
# 1422/1422 [==============================] - 53s 37ms/step - loss: 0.2326 - accuracy: 0.8943 - val_loss: 0.2487 - val_accuracy: 0.8857
# Epoch 8/25
# 1422/1422 [==============================] - 53s 37ms/step - loss: 0.2294 - accuracy: 0.8957 - val_loss: 0.2608 - val_accuracy: 0.8766
# Epoch 9/25
# 1422/1422 [==============================] - 54s 38ms/step - loss: 0.2274 - accuracy: 0.8970 - val_loss: 0.2437 - val_accuracy: 0.8870
# Epoch 10/25
# 1422/1422 [==============================] - 53s 38ms/step - loss: 0.2246 - accuracy: 0.8985 - val_loss: 0.2581 - val_accuracy: 0.8780
# Epoch 11/25
# 1422/1422 [==============================] - 53s 38ms/step - loss: 0.2224 - accuracy: 0.8998 - val_loss: 0.2503 - val_accuracy: 0.8825
# Epoch 12/25
# 1422/1422 [==============================] - 53s 37ms/step - loss: 0.2199 - accuracy: 0.9011 - val_loss: 0.2745 - val_accuracy: 0.8671
# Epoch 13/25
# 1422/1422 [==============================] - 53s 37ms/step - loss: 0.2182 - accuracy: 0.9020 - val_loss: 0.2690 - val_accuracy: 0.8714
# Epoch 14/25
# 1422/1422 [==============================] - 53s 38ms/step - loss: 0.2154 - accuracy: 0.9034 - val_loss: 0.2505 - val_accuracy: 0.8846
# 7 validation loss: 0.24372945725917816
# 7 validation accuracy: 0.8877538442611694
# 9164/9164 [==============================] - 112s 12ms/step
# MODEL: 8
# Epoch 1/25
# 1422/1422 [==============================] - 69s 44ms/step - loss: 0.2814 - accuracy: 0.8669 - val_loss: 0.2630 - val_accuracy: 0.8756
# Epoch 2/25
# 1422/1422 [==============================] - 60s 42ms/step - loss: 0.2565 - accuracy: 0.8810 - val_loss: 0.2524 - val_accuracy: 0.8816
# Epoch 3/25
# 1422/1422 [==============================] - 58s 41ms/step - loss: 0.2509 - accuracy: 0.8839 - val_loss: 0.2494 - val_accuracy: 0.8839
# Epoch 4/25
# 1422/1422 [==============================] - 57s 40ms/step - loss: 0.2448 - accuracy: 0.8868 - val_loss: 0.2450 - val_accuracy: 0.8866
# Epoch 5/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.2401 - accuracy: 0.8902 - val_loss: 0.2651 - val_accuracy: 0.8767
# Epoch 6/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.2368 - accuracy: 0.8918 - val_loss: 0.2388 - val_accuracy: 0.8911
# Epoch 7/25
# 1422/1422 [==============================] - 55s 38ms/step - loss: 0.2333 - accuracy: 0.8940 - val_loss: 0.2401 - val_accuracy: 0.8897
# Epoch 8/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.2299 - accuracy: 0.8960 - val_loss: 0.2494 - val_accuracy: 0.8848
# Epoch 9/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.2274 - accuracy: 0.8970 - val_loss: 0.2571 - val_accuracy: 0.8797
# Epoch 10/25
# 1422/1422 [==============================] - 56s 39ms/step - loss: 0.2254 - accuracy: 0.8983 - val_loss: 0.2484 - val_accuracy: 0.8856
# Epoch 11/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.2226 - accuracy: 0.8996 - val_loss: 0.2414 - val_accuracy: 0.8894
# 8 validation loss: 0.23877876996994019
# 8 validation accuracy: 0.8911177515983582
# 9164/9164 [==============================] - 106s 11ms/step
# MODEL: 9
# Epoch 1/25
# 1422/1422 [==============================] - 69s 43ms/step - loss: 0.2812 - accuracy: 0.8676 - val_loss: 0.2607 - val_accuracy: 0.8786
# Epoch 2/25
# 1422/1422 [==============================] - 57s 40ms/step - loss: 0.2561 - accuracy: 0.8812 - val_loss: 0.2517 - val_accuracy: 0.8828
# Epoch 3/25
# 1422/1422 [==============================] - 56s 39ms/step - loss: 0.2490 - accuracy: 0.8850 - val_loss: 0.2484 - val_accuracy: 0.8854
# Epoch 4/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.2433 - accuracy: 0.8879 - val_loss: 0.2459 - val_accuracy: 0.8869
# Epoch 5/25
# 1422/1422 [==============================] - 56s 39ms/step - loss: 0.2396 - accuracy: 0.8901 - val_loss: 0.2449 - val_accuracy: 0.8872
# Epoch 6/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.2358 - accuracy: 0.8925 - val_loss: 0.2528 - val_accuracy: 0.8825
# Epoch 7/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.2325 - accuracy: 0.8940 - val_loss: 0.2492 - val_accuracy: 0.8839
# Epoch 8/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.2287 - accuracy: 0.8959 - val_loss: 0.2652 - val_accuracy: 0.8742
# Epoch 9/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.2264 - accuracy: 0.8971 - val_loss: 0.2588 - val_accuracy: 0.8781
# Epoch 10/25
# 1422/1422 [==============================] - 55s 39ms/step - loss: 0.2239 - accuracy: 0.8986 - val_loss: 0.2727 - val_accuracy: 0.8697
# 9 validation loss: 0.24489443004131317
# 9 validation accuracy: 0.8871849179267883
# 9164/9164 [==============================] - 111s 12ms/step
